# %% [markdown]
# ## Adquisición y preprocesamiento de la información
#
# <table>
#     <tr>
#       <td>Grado en Ingeniería de Datos e Inteligencia Artificial - Facultad de Informática - UCM
#       </td>
#       <td>
#       <img src="https://biblioteca.ucm.es/data/cont/media/www/pag-88746//escudo.jpg"  width=50/>
#       </td>
#      </tr>
# </table>
#
#
#
#
# ### Un poquito de Web Scraping
#
# cuando los datos no son fáciles de obtener de una página web debemos analizar directemente el código HTML de la práctica. Para esto podemos usar, entre otras, dos bibliotecas:
#
# - BeautifulSoup: el estándar para manejar directamente código HTML. Permite navegar por los elementos de la página de forma sencilla
# - Selenium: cuando la página requiere interactividad, y se quiere automatizar la pulsación de botones, selección de listas desplegables, etc.

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

url = "https://www.rffm.es/competiciones/clasificaciones?season=18&type=2&grouping=1&competition=15293079&group=16544990&round="


# error, no hay tablas, por eso usamos BeautifulSoup.
#dfs = pd.read_html(page.text)

page = requests.get(url)
soup = BeautifulSoup(page.text, 'html.parser')  # le pasamos el texto en HTML para que lo analice

soup
# Out:
# <!DOCTYPE html>
#
# <html lang="es">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Clasificaciones | Real Federación de Fútbol de Madrid</title>
# <meta content="Clasificaciones" name="description"/>
# <meta content="https://www.rffm.es/competiciones/clasificaciones" property="og:url">
# <meta content="article" property="og:type">
# <meta content="Clasificaciones | Real Federación de Fútbol de Madrid" property="og:title">
# <meta content="Clasificaciones" property="og:description"/>
# <meta content="" property="og:image"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@RFFM_oficial" name="twitter:site"/>
# <meta content="Clasificaciones" name="twitter:title"/>
# <meta content="Clasificaciones" name="twitter:description"/>
# <meta content="@RFFM_oficial" name="twitter:creator"/>
# <meta content="" name="twitter:image"/>
# <meta content="https://www.rffm.es" name="twitter:domain"/>
# <!-- style -->
# <link href="/css/style.min.css" rel="stylesheet"/>
# <!-- favicon -->
# <link href="/img/favicon.ico" rel="icon"/>
# <!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
# <script async="true" type="text/javascript">
#             (function () {
#                 var host = 'www.rffm.es';
#                 var element = document.createElement('script');
#                 var firstScript = document.getElementsByTagName('script')[0];
#                 var url = 'https://quantcast.mgr.consensu.org'
#                     .concat('/choice/', 'FmhpjPBxy0f8A', '/', host, '/choice.js')
#                 var uspTries = 0;
#                 var uspTriesLimit = 3;
#                 element.async = true;
#                 element.type = 'text/javascript';
#                 element.src = url;
#
#                 firstScript.parentNode.insertBefore(element, firstScript);
#
#                 function makeStub() {
#                     var TCF_LOCATOR_NAME = '__tcfapiLocator';
#                     var queue = [];
#                     var win = window;
#                     var cmpFrame;
#
#                     function addFrame() {
#                         var doc = win.document;
#                         var otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);
#
#                         if (!otherCMP) {
#                             if (doc.body) {
#                                 var iframe = doc.createElement('iframe');
#
#                                 iframe.style.cssText = 'display:none';
#                                 iframe.name = TCF_LOCATOR_NAME;
#                                 doc.body.appendChild(iframe);
#                             } else {
#                                 setTimeout(addFrame, 5);
#                             }
#                         }
#                         return !otherCMP;
#                     }
#
#                     function tcfAPIHandler() {
#                         var gdprApplies;
#                         var args = arguments;
#
#                         if (!args.length) {
#                             return queue;
#                         } else if (args[0] === 'setGdprApplies') {
#                             if (
#                                 args.length > 3 &&
#                                 args[2] === 2 &&
#                                 typeof args[3] === 'boolean'
#                             ) {
#                                 gdprApplies = args[3];
#                                 if (typeof args[2] === 'function') {
#                                     args[2]('set', true);
#                                 }
#                             }
#                         } else if (args[0] === 'ping') {
#                             var retr = {
#                                 gdprApplies: gdprApplies,
#                                 cmpLoaded: false,
#                                 cmpStatus: 'stub'
#                             };
#
#                             if (typeof args[2] === 'function') {
#                                 args[2](retr);
#                             }
#                         } else {
#                             queue.push(args);
#                         }
#                     }
#
#                     function postMessageEventHandler(event) {
#                         var msgIsString = typeof event.data === 'string';
#                         var json = {};
#
#                         try {
#                             if (msgIsString) {
#                                 json = JSON.parse(event.data);
#                             } else {
#                                 json = event.data;
#                             }
#                         } catch (ignore) {
#                         }
#
#                         var payload = json.__tcfapiCall;
#
#                         if (payload) {
#                             window.__tcfapi(
#                                 payload.command,
#                                 payload.version,
#                                 function (retValue, success) {
#                                     var returnMsg = {
#                                         __tcfapiReturn: {
#                                             returnValue: retValue,
#                                             success: success,
#                                             callId: payload.callId
#                                         }
#                                     };
#                                     if (msgIsString) {
#                                         returnMsg = JSON.stringify(returnMsg);
#                                     }
#                                     event.source.postMessage(returnMsg, '*');
#                                 },
#                                 payload.parameter
#                             );
#                         }
#                     }
#
#                     while (win) {
#                         try {
#                             if (win.frames[TCF_LOCATOR_NAME]) {
#                                 cmpFrame = win;
#                                 break;
#                             }
#                         } catch (ignore) {
#                         }
#
#                         if (win === window.top) {
#                             break;
#                         }
#                         win = win.parent;
#                     }
#                     if (!cmpFrame) {
#                         addFrame();
#                         win.__tcfapi = tcfAPIHandler;
#                         win.addEventListener('message', postMessageEventHandler, false);
#                     }
#                 };
#
#                 makeStub();
#
#                 var uspStubFunction = function () {
#                     var arg = arguments;
#                     if (typeof window.__uspapi !== uspStubFunction) {
#                         setTimeout(function () {
#                             if (typeof window.__uspapi !== 'undefined') {
#                                 window.__uspapi.apply(window.__uspapi, arg);
#                             }
#                         }, 500);
#                     }
#                 };
#
#                 var checkIfUspIsReady = function () {
#                     uspTries++;
#                     if (window.__uspapi === uspStubFunction && uspTries < uspTriesLimit) {
#                         console.warn('USP is not accessible');
#                     } else {
#                         clearInterval(uspInterval);
#                     }
#                 };
#
#                 if (typeof window.__uspapi === 'undefined') {
#                     window.__uspapi = uspStubFunction;
#                     var uspInterval = setInterval(checkIfUspIsReady, 6000);
#                 }
#             })();
#         </script>
# <!-- End Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-3953434-1"></script>
# <script>
#             window.dataLayer = window.dataLayer || [];
#
#             function gtag() {
#                 dataLayer.push(arguments);
#             }
#
#             gtag('js', new Date());
#             gtag('config', 'UA-3953434-1');
#         </script>
# <!-- Google Tag Manager -->
# <script>(function (w, d, s, l, i) {
#                 w[l] = w[l] || [];
#                 w[l].push({
#                     'gtm.start':
#                         new Date().getTime(), event: 'gtm.js'
#                 });
#                 var f = d.getElementsByTagName(s)[0],
#                     j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#                 j.async = true;
#                 j.src =
#                     'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#                 f.parentNode.insertBefore(j, f);
#             })(window, document, 'script', 'dataLayer', 'GTM-M4HNZ3H');</script>
# <!-- End Google Tag Manager -->
# <script async="" src="https://ced.sascdn.com/tag/3963/smart.js" type="application/javascript"></script>
# <script async="" src="https://tagmanager.smartadserver.com/3963/396538/smart.prebid.js" type="text/javascript"></script>
# <script async="" src="https://ads.sportslocalmedia.com/slm.prebid.rffm.js"></script>
# <script type="application/javascript">
#             var viewport_width = window.innerWidth;
#             var sas = sas || {};
#             sas.cmd = sas.cmd || [];
#             sas.cmd.push(function () {
#                 sas.setup({networkid: 3963, domain: "https://www3.smartadserver.com", async: true, renderMode: 2});
#             });
#             if(viewport_width>992){
#             sas.adCallConfig = {
#                 siteId: 396538,
#                 pageId: 1355583,
#                 formats: [
#                     {id: 98744, tagId: "Billboard"},
#                     {id: 98749, tagId: "Leaderboard1"},
#                     {id: 98750, tagId: "Leaderboard2"},
#                     {id: 103790, tagId: "Leaderboard3"},
#                     {id: 98742, tagId: "RobaSimple"},
#                     {id: 98720, tagId: "RobaDoble"},
#                     {id: 98722, tagId: "Intext"}
#                 ],
#                 target: '',
#                 schain: '1.0,1!allinagency.com,396538,1,,'
#             };
#             } else {
#                 sas.adCallConfig = {
#                 siteId: 396538,
#                 pageId: 1355583,
#                 formats: [
#                     {id: 98744, tagId: "Billboard"},
#                     {id: 98749, tagId: "Leaderboard1"},
#                     {id: 98750, tagId: "Leaderboard2"},
#                     {id: 103790, tagId: "Leaderboard3"},
#                     {id: 98742, tagId: "RobaSimple"},
#                     {id: 98720, tagId: "RobaDoble"},
#                     {id: 98825, tagId: "Floor"},
#                     {id: 98722, tagId: "Intext"}
#                 ],
#                 target: '',
#                 schain: '1.0,1!allinagency.com,396538,1,,'
#             };
#             }
#
#         </script>
# <script>
#             var sasRefreshConf = {
#                 // fill this params
#                 duration: 15,
#                 area: 50,
#                 capping: 5,
#                 // fill this params
#                 // tagId: String('[sas_tagId]'),
#                 // keyword1: Number([refsh_no]),
#                 // keyword2: String('[sas_keywordTargeting]'),
#                 // formatId: Number([sas_formatId])
#             };
#         </script>
# <script src="https://ced-ns.sascdn.com/diff/templates/js/rtb-banner/sas-refresh-1.4.js"></script>
# </meta></meta></meta></head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-M4HNZ3H" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- SEARCH POPUP -->
# <div class="search-popup" style="display:none;">
# <!-- CROSS ICON -->
# <svg class="cross-icon big close-button search-popup-close">
# <use xlink:href="#svg-cross-big"></use>
# </svg>
# <!-- /CROSS ICON -->
# <form action="https://www.rffm.es/noticias" class="search-popup-form" method="GET">
# <input class="input-line" id="search" name="q" placeholder="¿Qué estás buscando?" type="text"/>
# </form>
# <p class="search-popup-text">¡Escribe lo que estás buscando y presiona Enter para comenzar tu búsqueda!</p>
# </div>
# <!-- /SEARCH POPUP -->
# <!-- MOBILE MENU WRAP -->
# <div class="mobile-menu-wrap">
# <!-- LOGO IMG -->
# <a class="logo-menu-responsive" href="#">
# <figure class="logo-img">
# <img alt="Logo" src="/img/brand/logo.png"/>
# </figure>
# </a>
# <!-- /LOGO IMG -->
# <!-- CROSS ICON -->
# <svg class="cross-icon big mobile-menu-close">
# <use xlink:href="#svg-cross-big"></use>
# </svg>
# <!-- /CROSS ICON -->
# <!-- SEARCH POPUP OPEN -->
# <svg class="search-popup-open search-icon">
# <use xlink:href="#svg-search"></use>
# </svg>
# <!-- /SEARCH POPUP OPEN -->
# <!-- MOBILE MENU -->
# <ul class="mobile-menu">
# <!-- MOBILE MENU ITEM -->
# <li class="mobile-menu-item">
# <a class="mobile-menu-item-link" href="https://www.rffm.es/federacion">
#                 Federación
#               </a>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Actualidad</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/federacion">Últimas noticias</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Documentación y circulares</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/federacion/documentacion-circulares/estatutos">Estatutos</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/federacion/documentacion-circulares/normativa-reglamentos">Normativa y reglamentos</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/federacion/documentacion-circulares/bases-competicion">Bases de competición</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/federacion/documentacion-circulares/cuotas">Cuotas</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/federacion/documentacion-circulares/circulares">Circulares</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/federacion/documentacion-circulares/protocolo-covid-rffm">Protocolo COVID-19</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/federacion/documentacion-circulares/documentacion-interes">Documentación de interés</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Estructura organizativa</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/federacion/organigrama">Organigrama</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/federacion/delegaciones-territoriales">Delegaciones Territoriales</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/federacion/ley-de-transparencia">Ley de transparencia</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Proceso electoral</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/federacion/proceso-electoral-2021/proceso-electoral">Proceso electoral</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/federacion/proceso-electoral-2021/resoluciones-proceso-electoral">Resoluciones</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE MENU ITEM -->
# <!-- MOBILE MENU ITEM -->
# <li class="mobile-menu-item">
# <a class="mobile-menu-item-link" href="#">
#                 Competición
#               </a>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Resultados y clasificaciones</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/competiciones/calendario">Calendario</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/competiciones/resultados">Resultados y jornadas</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/competiciones/clasificaciones">Clasificaciones</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/competiciones/goleadores">Goleadores</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Sanciones</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/competiciones/sanciones">Consulta de sanciones</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/comite-de-apelacion">Comité de apelación</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Directorio</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/competiciones/directorio-de-clubs">Consulta clubes y equipos</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/competiciones/campos">Consulta de campos</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Estadísticas</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/competiciones/comparativa-de-equipos">Comparativa de equipos</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE MENU ITEM -->
# <!-- MOBILE MENU ITEM -->
# <li class="mobile-menu-item">
# <a class="mobile-menu-item-link" href="https://www.rffm.es/futbol">
#                 Fútbol
#               </a>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Noticias</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/futbol/futbol-sala">Fútbol Sala</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/futbol/futbol-femenino">Fútbol femenino</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/futbol/futbol-7">Fútbol 7</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/futbol/debutantes">Debutantes</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/futbol/selecciones-autonomicas">Selecciones autonómicas</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/futbol/futbol-base">Fútbol base</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Escuelas Federativas</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/futbol/futbol-base">Actualidad</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/futbol/futbol-base/documentacion">Documentos de interés</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Centro de tecnificación</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/futbol/futbol-base/centro-tecnificacion">Actualidad</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE MENU ITEM -->
# <!-- MOBILE MENU ITEM -->
# <li class="mobile-menu-item">
# <a class="mobile-menu-item-link" href="https://www.rffm.es/entrenadores">
#                 Entrenadores
#               </a>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Escuela de entrenadores</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/entrenadores/escuela-entrenadores">Actualidad</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Cursos</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/entrenadores/escuela-entrenadores/cursos-federativos">Cursos federativos</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/entrenadores/escuela-entrenadores/cursos-academicos">Cursos académicos</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/entrenadores/escuela-entrenadores/masteres-otras-formaciones">Másteres y otras formaciones</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/entrenadores/escuela-entrenadores/inscripcion-cursos">Inscripción a cursos</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Comité de entrenadores</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/entrenadores/comite-entrenadores">Actualidad</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/entrenadores/comite-entrenadores/estructura-organizativa">Estructura organizativa</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/entrenadores/comite-entrenadores/documentacion">Documentos de interés</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE MENU ITEM -->
# <!-- MOBILE MENU ITEM -->
# <li class="mobile-menu-item">
# <a class="mobile-menu-item-link" href="https://www.rffm.es/arbitros">
#                 Arbitraje
#               </a>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Actualidad</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/arbitros">Últimas noticias</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Documentos de interés</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/arbitros/reglas-juego-reglamento">Reglas de juego y reglamento</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/arbitros/circulares">Circulares</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/arbitros/utiles">Útiles</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Estructura organizativa</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/arbitros/estructura-organizativa">Organigrama</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Cursos</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/noticias/cursos-de-arbitros-de-futbol">Cursos de Árbitros de Fútbol</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/noticias/cursos-de-arbitros-de-futbol-sala">Cursos de Árbitros de Fútbol Sala</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE MENU ITEM -->
# <!-- MOBILE MENU ITEM -->
# <li class="mobile-menu-item">
# <a class="mobile-menu-item-link" href="https://www.rffm.es/multimedia">
#                 Multimedia
#               </a>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Boletín Semanal RFFM</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/multimedia/boletin-semanal-rffm/boletin-semanal-rffm">Ver todos las boletines</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Canal TV</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/videos">Ver todos los vídeos</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Revista</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/multimedia/revista">Ver todas las revistas</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Imágenes</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/albumes">Ver fotografías</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE MENU ITEM -->
# <!-- MOBILE MENU ITEM -->
# <li class="mobile-menu-item">
# <a class="mobile-menu-item-link" href="https://www.rffm.es/programas">
#                 Programas
#               </a>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Programas del Área Social</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/programas/tolerancia-cero-2022">Tolerancia Cero</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/proyectos/area-social/futbol-inclusivo">Fútbol Inclusivo</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/programas/area-social/sumate">Súmate</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/programas/area-social/fundacion">Fundación RFFM</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Programas del Área de Salud</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/programas/cardio-futbol">Cardio Fútbol</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/programas/desfibriladores">Desfibriladores</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE MENU ITEM -->
# <!-- MOBILE MENU ITEM -->
# <li class="mobile-menu-item">
# <a class="mobile-menu-item-link" href="https://www.rffm.es/servicios-medicos-rffm">
#                 Servicios médicos
#               </a>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Cartera de servicios</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.mutualidaddefutbolistas.com/madrid/">Cartera de servicios médicos RFFM</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Actualidad</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/servicios-medicos-rffm">Últimas noticias</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <p class="mobile-dropdown-item-link pd-dropdown-handler">Servicios médicos</p>
# <span class="pd-dropdown-handler">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
# </span>
# <!-- MOBILE DROPDOWN -->
# <ul class="mobile-dropdown pd-dropdown">
# <!-- MOBILE DROPDOWN ITEM -->
# <li class="mobile-dropdown-item">
# <a class="mobile-dropdown-item-link" href="https://www.rffm.es/mutualidad">Mutualidad</a>
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE DROPDOWN ITEM -->
# </ul>
# <!-- /MOBILE DROPDOWN -->
# </li>
# <!-- /MOBILE MENU ITEM -->
# <!-- <li><a href="https://intranet.ffmadrid.es/nfg/"><img class="mobile-federado" src="/img/brand/logo-portal-federado.png" alt="portal-federado"></a></li> -->
# <li><a href="/portal-federado"><img alt="portal-federado" class="mobile-federado" src="/img/brand/logo-portal-federado.png"/></a></li>
# </ul>
# <!-- /MOBILE MENU -->
# </div>
# <!-- /MOBILE MENU WRAP -->
# <!-- HEADER WRAP -->
# <div class="header-wrap-logo">
# <!-- HEADER -->
# <div class="header-logo grid-limit">
# <!-- MOBILE MENU PULL -->
# <div class="mobile-menu-pull mobile-menu-open">
# <!-- MENU PULL ICON -->
# <svg class="menu-pull-icon">
# <use xlink:href="#svg-menu-pull"></use>
# </svg>
# <!-- /MENU PULL ICON -->
# </div>
# <!-- /MOBILE MENU PULL -->
# <!-- MOBILE MENU PULL -->
# <div class="scroll-menu-pull">
# <!-- MENU PULL ICON -->
# <svg class="menu-pull-icon">
# <use xlink:href="#svg-menu-pull"></use>
# </svg>
# <!-- /MENU PULL ICON -->
# <div class="menu-desc">Menú</div>
# </div>
# <!-- /MOBILE MENU PULL -->
# <!-- logo-madrid -->
# <div class="logo-madrid">
# <!-- LOGO IMG -->
# <figure class="header-logo-img">
# <img alt="Comunidad de Madrid" src="/img/brand/community-of-madrid.jpg"/>
# </figure>
# <!-- /LOGO IMG -->
# </div>
# <!-- logo-madrid -->
# <!-- LOGO -->
# <div class="logo">
# <a href="/">
# <!-- LOGO IMG -->
# <figure class="header-logo-img">
# <img alt="Logo" src="/img/brand/logo.png"/>
# </figure>
# <!-- /LOGO IMG -->
# </a>
# </div>
# <!-- /LOGO -->
# <!-- Logo Federado-->
# <div class="logo-federado">
# <!-- LOGO IMG -->
# <figure class="header-logo-img">
# <a href="/portal-federado" target="_blank">
# <img alt="Portal del Federado" src="/img/brand/logo-portal-federado-blanco.png" style="max-width:100%;"/>
# </a>
# </figure>
# <!-- /LOGO IMG -->
# <a class="button tiny pf-intranet" href="/portal-federado" target="_blank">
#                 Intranet
#                 <!-- BUTTON ORNAMENT -->
# <div class="button-ornament">
# <!-- ARROW ICON -->
# <svg class="arrow-icon">
# <use xlink:href="#svg-arrow"></use>
# </svg>
# <!-- /ARROW ICON -->
# </div>
# <!-- /BUTTON ORNAMENT -->
# </a>
# </div>
# <!-- /Logo Federado -->
# <div class="logo-federado" style="margin-right:25px">
# <a href="https://player.goandgotv.com/" target="_blank">
# <img src="https://www.rffm.es/img/banners/TV-Online.png"/>
# </a>
# </div>
# </div>
# <!-- /HEADER -->
# </div>
# <!-- /HEADER WRAP -->
# <!-- fixed-top-height -->
# <div class="fixed-top-height"></div>
# <!-- /fixed-top-height -->
# <!-- NAVIGATION WRAP -->
# <nav class="navigation-wrap oculto" id="navigation-wrap">
# <!-- NAVIGATION -->
# <div class="navigation grid-limit">
# <!-- SEARCH BUTTON -->
# <div class="search-button search-popup-open">
# <!-- SEARCH ICON -->
# <svg class="search-icon">
# <use xlink:href="#svg-search"></use>
# </svg>
# <!-- /SEARCH ICON -->
# </div>
# <!-- /SEARCH BUTTON -->
# <!-- MAIN MENU -->
# <ul class="main-menu">
# <li class="main-menu-item">
# <a class="main-menu-item-link" href="https://www.rffm.es/federacion">
#                             Federación
#                                                             <!-- SVG ARROW -->
# <svg class="arrow-icon">
# <use xlink:href="#svg-arrow"></use>
# </svg>
# <!-- /SVG ARROW -->
# </a>
# <ul class="submenu" style="display:none;">
# <li class="submenu-item grid-limit">
# <div class="link-sections-wrap">
# <div class="link-sections">
# <div class="link-section">
# <div class="section-title-wrap red">
# <h2 class="section-title small">Actualidad</h2>
# <div class="section-title-separator"></div>
# </div>
# <ul class="link-list">
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/federacion">Últimas noticias</a>
# </li>
# <!-- /LINK LIST ITEM -->
# </ul>
# </div>
# </div>
# </div>
# <div class="link-sections-wrap">
# <div class="link-sections">
# <div class="link-section">
# <div class="section-title-wrap red">
# <h2 class="section-title small">Documentación y circulares</h2>
# <div class="section-title-separator"></div>
# </div>
# <ul class="link-list">
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/federacion/documentacion-circulares/estatutos">Estatutos</a>
# </li>
# <!-- /LINK LIST ITEM -->
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/federacion/documentacion-circulares/normativa-reglamentos">Normativa y reglamentos</a>
# </li>
# <!-- /LINK LIST ITEM -->
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/federacion/documentacion-circulares/bases-competicion">Bases de competición</a>
# </li>
# <!-- /LINK LIST ITEM -->
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/federacion/documentacion-circulares/cuotas">Cuotas</a>
# </li>
# <!-- /LINK LIST ITEM -->
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/federacion/documentacion-circulares/circulares">Circulares</a>
# </li>
# <!-- /LINK LIST ITEM -->
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/federacion/documentacion-circulares/protocolo-covid-rffm">Protocolo COVID-19</a>
# </li>
# <!-- /LINK LIST ITEM -->
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/federacion/documentacion-circulares/documentacion-interes">Documentación de interés</a>
# </li>
# <!-- /LINK LIST ITEM -->
# </ul>
# </div>
# </div>
# </div>
# <div class="link-sections-wrap">
# <div class="link-sections">
# <div class="link-section">
# <div class="section-title-wrap red">
# <h2 class="section-title small">Estructura organizativa</h2>
# <div class="section-title-separator"></div>
# </div>
# <ul class="link-list">
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/federacion/organigrama">Organigrama</a>
# </li>
# <!-- /LINK LIST ITEM -->
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/federacion/delegaciones-territoriales">Delegaciones Territoriales</a>
# </li>
# <!-- /LINK LIST ITEM -->
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/federacion/ley-de-transparencia">Ley de transparencia</a>
# </li>
# <!-- /LINK LIST ITEM -->
# </ul>
# </div>
# </div>
# </div>
# <div class="link-sections-wrap">
# <div class="link-sections">
# <div class="link-section">
# <div class="section-title-wrap red">
# <h2 class="section-title small">Proceso electoral</h2>
# <div class="section-title-separator"></div>
# </div>
# <ul class="link-list">
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/federacion/proceso-electoral-2021/proceso-electoral">Proceso electoral</a>
# </li>
# <!-- /LINK LIST ITEM -->
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/federacion/proceso-electoral-2021/resoluciones-proceso-electoral">Resoluciones</a>
# </li>
# <!-- /LINK LIST ITEM -->
# </ul>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li class="main-menu-item">
# ...
# </div>
# </li>
# </ul>
# <div class="footer-contact-button">
# <a class="button tiny red" href="/contacto/">
#                         Contacto
#                         <!-- BUTTON ORNAMENT -->
# <div class="button-ornament">
# <!-- ARROW ICON -->
# <svg class="arrow-icon">
# <use xlink:href="#svg-arrow"></use>
# </svg>
# <!-- /ARROW ICON -->
# </div>
# <!-- /BUTTON ORNAMENT -->
# </a>
# </div>
# </div>
# <!-- /CONTACT INFO PREVIEW -->
# </div>
# <!-- FOOTER TOP WIDGET -->
# <!-- FOOTER TOP WIDGET -->
# <div class="footer-top-widget">
# <!-- SECTION TITLE WRAP -->
# <div class="section-title-wrap red negative">
# <h2 class="section-title">Navegación</h2>
# <div class="section-title-separator"></div>
# </div>
# <!-- /SECTION TITLE WRAP -->
# <!-- LINK SECTION -->
# <div class="link-section">
# <!-- LINK LIST -->
# <ul class="link-list small negative">
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
#                                         Home
#                                     </a>
# </li>
# <!-- /LINK LIST ITEM -->
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/federacion">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
#                                         Federación
#                                     </a>
# </li>
# <!-- /LINK LIST ITEM -->
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/competiciones/calendario">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
#                                         Competición
#                                     </a>
# </li>
# <!-- /LINK LIST ITEM -->
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/futbol">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
#                                         Futbol
#                                     </a>
# </li>
# <!-- /LINK LIST ITEM -->
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/futbol/futbol-femenino">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
#                                         Femenino
#                                     </a>
# </li>
# <!-- /LINK LIST ITEM -->
# </ul>
# <!-- /LINK LIST -->
# <!-- LINK LIST -->
# <ul class="link-list small negative">
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/competiciones/resultados">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
#                                         Resultados
#                                     </a>
# </li>
# <!-- /LINK LIST ITEM -->
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/entrenadores/escuela-entrenadores/cursos-federativos">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
#                                         Formación
#                                     </a>
# </li>
# <!-- /LINK LIST ITEM -->
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/multimedia/rffm-tv">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
#                                         Televisión
#                                     </a>
# </li>
# <!-- /LINK LIST ITEM -->
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/competiciones/calendario">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
#                                         Competiciones
#                                     </a>
# </li>
# <!-- /LINK LIST ITEM -->
# </ul>
# <!-- /LINK LIST -->
# <!-- LINK LIST -->
# <ul class="link-list small negative">
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/futbol/selecciones-autonomicas">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
#                                         Selecciones
#                                     </a>
# </li>
# <!-- /LINK LIST ITEM -->
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/entrenadores">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
#                                         Entrenadores
#                                     </a>
# </li>
# <!-- /LINK LIST ITEM -->
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/arbitros">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
#                                         Arbitros
#                                     </a>
# </li>
# <!-- /LINK LIST ITEM -->
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="https://www.rffm.es/multimedia">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
#                                         Multimedia
#                                     </a>
# </li>
# <!-- /LINK LIST ITEM -->
# </ul>
# <!-- /LINK LIST -->
# <!-- LINK LIST -->
# <ul class="link-list small negative">
# <!-- LINK LIST ITEM -->
# <li class="link-list-item">
# <a href="/portal-federado">
# <!-- ARROW ICON -->
# <svg class="arrow-icon medium">
# <use xlink:href="#svg-arrow-medium"></use>
# </svg>
# <!-- /ARROW ICON -->
#                                         Portal federado
#                                     </a>
# </li>
# <!-- /LINK LIST ITEM -->
# </ul>
# <!-- /LINK LIST -->
# </div>
# <!-- /LINK SECTION -->
# </div>
# <!-- FOOTER TOP WIDGET -->
# </div>
# <!-- /FOOTER TOP WIDGETS -->
# </div>
# <!-- /FOOTER TOP -->
# </div>
# <!-- /FOOTER TOP WRAP -->
# <div id="Floor"></div>
# <!-- FOOTER BOTTOM WRAP -->
# <div class="footer-bottom-wrap">
# <!-- FOOTER BOTTOM -->
# <div class="footer-bottom grid-limit">
# <p class="footer-bottom-text"><span class="brand"><span class="highlighted"></span>Real Federación de Fútbol de Madrid</span><span class="separator">|</span>Campos de Fútbol Ernesto Cotorruelo, Via Lusitana, 5 (28025 Madrid).</p>
# <p class="footer-bottom-text">
# <a href="https://www.rffm.es/aviso-legal">Aviso legal</a>
# <span class="separator">|</span>
# <a href="https://www.rffm.es/politica-de-privacidad">Política de privacidad</a>
# </p>
# <!-- <div class="matchapp-logo">
#           <a href="https://matchapp.es" target="_blank"><p class="footer-bottom-text">Powered by </p> <img src="/img/brand/logo_matchapp.png" alt="Matchapp"></a>
#         </div> -->
# </div>
# <!-- /FOOTER BOTTOM -->
# </div>
# <!-- /FOOTER BOTTOM WRAP -->
# <!-- app bundle -->
# <script src="/rffm.main.min.js"></script>
# <script type="application/javascript">
#
#     document.addEventListener("DOMContentLoaded", function (event) {
#         console.log('All assets are loaded')
#     });
#
#     sas.callSmart = () => {
#         console.log('Call to Smart');
#         sas.cmd.push(function () {
#             sas.call('onecall', sas.adCallConfig);
#         });
#
#         const id_ads = ['Billboard','Billboard2','Leaderboard1','Leaderboard2','Leaderboard3','Leaderboard4','RobaSimple','RobaSimple2','RobaDoble','RobaDoble2','Intext','Flotante','Floor'];
#         id_ads.forEach((item, i) => {
#             if (document.getElementById(item) !== null) {
#                 console.log(item);
#                 sas.cmd.push(function () {
#                     sas.render(item);
#                 });
#             }
#         });
#     }
#     document.addEventListener("DOMContentLoaded", function () {
#         window.__tcfapi('addEventListener', 2, function (tcData, listenerSuccess) {
#             if (listenerSuccess) {
#                 // check the eventstatus
#                 if (tcData.eventStatus === 'useractioncomplete' ||
#                     tcData.eventStatus === 'tcloaded') {
#                     console.log('cmp responded:', tcData);
#                     sas.setGdprConsentData(tcData.tcString);
#                     sas.callSmart();
#                 }
#             }
#         });
#     });
# </script>
# <script async="" data-ad-client="ca-pub-3333377928887555" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script type="text/javascript">
#     var isEmpty = function (str) {
#         return (!str || 0 === str.length);
#     }
#     var resultsCombo = function (force)
#     {
#         $("#search_btn_results").prop("disabled", true);
#         $("#search_btn_results").addClass("disabled");
#         var season = $("#season").val();
#         var type = $("#type").val();
#         var competition = $("#competition").val();
#         var group = $("#group").val();
#         var round = $("#round").val();
#         var club = $("#club").val();
#         var team = $("#team").val();
#         var grouping = $("#grouping").val();
#         console.info("Season: "+season);
#         console.info("Type: "+type);
#         console.info("Grouping: "+grouping);
#         console.info("Competition: "+competition);
#         console.info("Group: "+group);
#         console.info("Round: "+round);
#         console.info("club: "+club);
#         console.info("team: "+team);
#         console.info("Force: "+force);
#         if (isEmpty(season) && isEmpty(type) && isEmpty(grouping))
#         {
#             $("#competition").html("");
#             $("#competition").prop("disabled", true);
#         }
#         if (!isEmpty(season) && !isEmpty(type) && !isEmpty(grouping) && force !=="load" && ($("#competition").prop("disabled")==true || force == 'competition'))
#         {
#             //web.api_competitions
#             var jqxhr = $.getJSON( "https://www.rffm.es/api/competition", {
#                 idSeason: season,
#                 idGameType: type,
#                 idGrouping: grouping
#             }, function() {
#
#                 //console.log( "success" );
#
#             }).done(function(data) {
#                 console.log(data);
#                 if (data.err == true)
#                 {
#                     alert(data.messages['message-error'][0]);
#                 }
#                 else
#                 {
#                     $("#competition").html("");
#                     $("#group").html("");
#                     $("#round").html("");
#                     $("#club").html("");
#                     $("#team").html("");
#                     var newoptions = "";
#                     newoptions = newoptions+'<option value="">Seleccione</option>';
#                     $.each( data.extra.data, function( item ) {
#                         newoptions = newoptions+'<optgroup value="'+data.extra.data[item].id+'" label="'+data.extra.data[item].name+'">';
#                         $.each( data.extra.data[item].competitions, function( sitem ) {
#                             newoptions = newoptions+'<option value="'+data.extra.data[item].competitions[sitem].id+'">'+data.extra.data[item].competitions[sitem].name+'</option>';
#                         });
#                         newoptions = newoptions+'</optgroup>';
#                     });
#                     $("#competition").html(newoptions);
#                     $("#competition").prop("disabled", false);
#                 }
#
#             }).fail(function() {
#                 alert("Ha ocurrido un error y no se han cargado correctamente las competiciones");
#             });
#         }
#
#         if (!isEmpty(season) && !isEmpty(type) && !isEmpty(competition) && force !=="load" && ($("#group").prop("disabled")==true || force == 'group'))
#         {
#             //web.api_competitions
#             var jqxhr = $.getJSON( "https://www.rffm.es/api/groups", {
#                 idSeason: season,
#                 idGameType: type,
#                 idCompetition: competition
#             }, function() {
#
#                 //console.log( "success" );
#
#             }).done(function(data) {
#                 console.log(data);
#                 if (data.err == true)
#                 {
#                     alert(data.messages['message-error'][0]);
#                 }
#                 else
#                 {
#                     $("#group").html("");
#                     $("#round").html("");
#                     var newoptions = "";
#                     newoptions = newoptions+'<option value="">Seleccione</option>';
#                     $.each( data.extra.data, function( item ) {
#                         newoptions = newoptions+'<option value="'+data.extra.data[item].id+'">'+data.extra.data[item].name+'</option>';
#                     });
#                     $("#club").html("");
#                     $("#team").html("");
#                     $("#group").html(newoptions);
#                     $("#group").prop("disabled", false);
#                 }
#
#             }).fail(function() {
#                 alert("Ha ocurrido un error y no se han cargado correctamente las competiciones");
#             });
#         }
#         if (!isEmpty(season) && !isEmpty(type) && !isEmpty(competition) && !isEmpty(group) && force !=="load" && ($("#round").prop("disabled")==true || force == 'round'))
#         {
#             //web.api_competitions
#             var jqxhr = $.getJSON( "https://www.rffm.es/api/rounds", {
#                 idGroup: group
#             }, function() {
#
#                 //console.log( "success" );
#
#             }).done(function(data) {
#                 console.log(data);
#                 if (data.err == true)
#                 {
#                     alert(data.messages['message-error'][0]);
#                 }
#                 else
#                 {
#                     $("#round").html("");
#                     var newoptions = "";
#                     newoptions = newoptions+'<option value="">Última jornada</option>';
#                     $.each( data.extra.data, function( item ) {
#                         newoptions = newoptions+'<option value="'+data.extra.data[item].id+'">'+data.extra.data[item].name+' ('+data.extra.data[item].date+')</option>';
#                     });
#                     $("#round").html(newoptions);
#                     $("#round").prop("disabled", false);
#                 }
#
#             }).fail(function() {
#                 alert("Ha ocurrido un error y no se han cargado correctamente las competiciones");
#             });
#         }
#
#         if (force == "load" && isEmpty(season) && isEmpty(type))
#         {
#             $("#season").find('option:eq(1)').prop('selected', true);
#             $("#type").find('option:eq(1)').prop('selected', true);
#             resultsCombo('competition');
#         }
#         else if (force == "load" && isEmpty(type) && !isEmpty(season))
#         {
#             $("#type").find('option:eq(1)').prop('selected', true);
#             resultsCombo('competition');
#         }
#
#         if (!isEmpty(season) && !isEmpty(type) && !isEmpty(competition) && !isEmpty(group))
#         {
#             $("#search_btn_results").prop("disabled", false);
#             $("#search_btn_results").removeClass("disabled");
#         }
#     };
#     $(document).ready(function() {
#         resultsCombo("load");
#         $("#season").change(function() {
#             resultsCombo('competition');
#         });
#         $("#type").change(function() {
#             resultsCombo('competition');
#         });
#         $("#grouping").change(function() {
#             resultsCombo("competition");
#         });
#         $("#competition").change(function() {
#             resultsCombo("group");
#         });
#         $("#group").change(function() {
#             resultsCombo("round");
#         });
#         $("#round").change(function() {
#             resultsCombo("completed");
#         });
#         $("#club").change(function() {
#             resultsCombo("team");
#         });
#         $("#team").change(function() {
#             resultsCombo("completed");
#         });
#     });
# </script>
# </body>
# </html>

# %% [markdown]
# El paso anterior ha analizado el texto y extraído sus componentes. Ahora podemos escribir, por ejemplo:

# %%
print(soup.head.title)
# Out:
# <title>Clasificaciones | Real Federación de Fútbol de Madrid</title>

# %%
print(soup.head.title.text)
# Out:
# Clasificaciones | Real Federación de Fútbol de Madrid

# %% [markdown]
# Esta forma de "navegar" la página de arriba a abajo puede resultar muy tediosa y además solo permite llegar a algunos elementos, es la llamada "dot navegation" que usaremos cuando ya estemos cerca de la información que queremos

# %%
soup.body.div
# Out:
# <div class="search-popup" style="display:none;">
# <!-- CROSS ICON -->
# <svg class="cross-icon big close-button search-popup-close">
# <use xlink:href="#svg-cross-big"></use>
# </svg>
# <!-- /CROSS ICON -->
# <form action="https://www.rffm.es/noticias" class="search-popup-form" method="GET">
# <input class="input-line" id="search" name="q" placeholder="¿Qué estás buscando?" type="text"/>
# </form>
# <p class="search-popup-text">¡Escribe lo que estás buscando y presiona Enter para comenzar tu búsqueda!</p>
# </div>

# %% [markdown]
# Para buscar con más libertad tendremos otras funciones como 'find' y 'find_all' que encuentran, respectivamente, la primera aparición o todas las apariciones de un tag:

# %%
cabecera = soup.find('h1')
cabecera
# Out:
# <h1 class="section-title big">
#                                     TEMPORADA 2022-2023
#                                                     | PREFERENTE PREBENJAMIN
#                                                     | GRUPO 5
#                                                     | JORNADA 11
#                                                     | 10-02-2023
#                             </h1>

# %%
cabeceras = soup.find_all('h2')
len(cabeceras)
# Out:
# 34

# %%
cabeceras[2]
# Out:
# <h2 class="section-title small">Estructura organizativa</h2>

# %% [markdown]
# Ahora vamos a buscar la información que nos interesa. Tras inspeccionar la página en google Chrome (por ejemplo), vemos que parece que cada fila viene en un elemento de tipo `div` con atributo  class="table-row". La función `select`devuelve todos los elementos que cumplen esto (nótese el . antes del nombre)

# %%
row = soup.select('.table-row')
len(row)
# Out:
# 24

# %%
for i in range(len(row)):
    print(i,row[i].text.strip().replace("\n", ""))
# Out:
# 0 1                                                                                                                            C.D. ESTUDIANTES LAS TABLAS 'A'                                                                                                                                28                                                                                                                                                11                                                                                                                                                9                                                                                                                                                1                                                                                                                                                1                                                                                                                                                58                                                                                                                                                17                                                                                                                                                0
# 1 2                                                                                                                            UNION ZONA NORTE 'B'                                                                                                                                25                                                                                                                                                11                                                                                                                                                8                                                                                                                                                1                                                                                                                                                2                                                                                                                                                49                                                                                                                                                17                                                                                                                                                0
# 2 3                                                                                                                            A.D. ESPERANZA 'A'                                                                                                                                25                                                                                                                                                11                                                                                                                                                8                                                                                                                                                1                                                                                                                                                2                                                                                                                                                40                                                                                                                                                17                                                                                                                                                0
# 3 4                                                                                                                            REAL MADRID C.F. 'B'                                                                                                                                24                                                                                                                                                11                                                                                                                                                7                                                                                                                                                3                                                                                                                                                1                                                                                                                                                66                                                                                                                                                15                                                                                                                                                0
# 4 5                                                                                                                            GREDOS SAN DIEGO-MORATALAZ 'A'                                                                                                                                20                                                                                                                                                11                                                                                                                                                6                                                                                                                                                2                                                                                                                                                3                                                                                                                                                35                                                                                                                                                27                                                                                                                                                0
# 5 6                                                                                                                            C.D. CANILLAS 'B'                                                                                                                                19                                                                                                                                                11                                                                                                                                                6                                                                                                                                                1                                                                                                                                                4                                                                                                                                                52                                                                                                                                                39                                                                                                                                                0
# 6 7                                                                                                                            A.D. OÑA SANCHINARRO 'A'                                                                                                                                18                                                                                                                                                11                                                                                                                                                6                                                                                                                                                0                                                                                                                                                5                                                                                                                                                30                                                                                                                                                33                                                                                                                                                0
# 7 8                                                                                                                            CLUB SAN AGUSTIN 'A'                                                                                                                                10                                                                                                                                                11                                                                                                                                                3                                                                                                                                                1                                                                                                                                                7                                                                                                                                                38                                                                                                                                                44                                                                                                                                                0
# 8 9                                                                                                                            A.D.A.E. SIMANCAS                                                                                                                                9                                                                                                                                                11                                                                                                                                                3                                                                                                                                                0                                                                                                                                                8                                                                                                                                                22                                                                                                                                                43                                                                                                                                                0
# 9 9                                                                                                                            ALAMEDA DE OSUNA ESCUELAS DE F 'A'                                                                                                                                9                                                                                                                                                11                                                                                                                                                3                                                                                                                                                0                                                                                                                                                8                                                                                                                                                22                                                                                                                                                43                                                                                                                                                0
# 10 11                                                                                                                            C.D. OLIMPICO DE HORTALEZA 'A'                                                                                                                                3                                                                                                                                                11                                                                                                                                                0                                                                                                                                                3                                                                                                                                                8                                                                                                                                                15                                                                                                                                                52                                                                                                                                                0
# 11 12                                                                                                                            A.D. UNION ADARVE 'B'                                                                                                                                1                                                                                                                                                11                                                                                                                                                0                                                                                                                                                1                                                                                                                                                10                                                                                                                                                4                                                                                                                                                84                                                                                                                                                0
# 12 1                                                                                                                        C.D. ESTUDIANTES LAS TABLAS 'A'                                                                                                                            28                                                                                                                                                11                                                                        /                                                                            9                                                                        /                                                                            1                                                                        /                                                                            1                                                                                                                                                58                                                                        /                                                                            17                                                                                                                                                0
# 13 2                                                                                                                        UNION ZONA NORTE 'B'                                                                                                                            25                                                                                                                                                11                                                                        /                                                                            8                                                                        /                                                                            1                                                                        /                                                                            2                                                                                                                                                49                                                                        /                                                                            17                                                                                                                                                0
# 14 3                                                                                                                        A.D. ESPERANZA 'A'                                                                                                                            25                                                                                                                                                11                                                                        /                                                                            8                                                                        /                                                                            1                                                                        /                                                                            2                                                                                                                                                40                                                                        /                                                                            17                                                                                                                                                0
# 15 4                                                                                                                        REAL MADRID C.F. 'B'                                                                                                                            24                                                                                                                                                11                                                                        /                                                                            7                                                                        /                                                                            3                                                                        /                                                                            1                                                                                                                                                66                                                                        /                                                                            15                                                                                                                                                0
# 16 5                                                                                                                        GREDOS SAN DIEGO-MORATALAZ 'A'                                                                                                                            20                                                                                                                                                11                                                                        /                                                                            6                                                                        /                                                                            2                                                                        /                                                                            3                                                                                                                                                35                                                                        /                                                                            27                                                                                                                                                0
# 17 6                                                                                                                        C.D. CANILLAS 'B'                                                                                                                            19                                                                                                                                                11                                                                        /                                                                            6                                                                        /                                                                            1                                                                        /                                                                            4                                                                                                                                                52                                                                        /                                                                            39                                                                                                                                                0
# 18 7                                                                                                                        A.D. OÑA SANCHINARRO 'A'                                                                                                                            18                                                                                                                                                11                                                                        /                                                                            6                                                                        /                                                                            0                                                                        /                                                                            5                                                                                                                                                30                                                                        /                                                                            33                                                                                                                                                0
# 19 8                                                                                                                        CLUB SAN AGUSTIN 'A'                                                                                                                            10                                                                                                                                                11                                                                        /                                                                            3                                                                        /                                                                            1                                                                        /                                                                            7                                                                                                                                                38                                                                        /                                                                            44                                                                                                                                                0
# 20 9                                                                                                                        A.D.A.E. SIMANCAS                                                                                                                            9                                                                                                                                                11                                                                        /                                                                            3                                                                        /                                                                            0                                                                        /                                                                            8                                                                                                                                                22                                                                        /                                                                            43                                                                                                                                                0
# 21 9                                                                                                                        ALAMEDA DE OSUNA ESCUELAS DE F 'A'                                                                                                                            9                                                                                                                                                11                                                                        /                                                                            3                                                                        /                                                                            0                                                                        /                                                                            8                                                                                                                                                22                                                                        /                                                                            43                                                                                                                                                0
# 22 11                                                                                                                        C.D. OLIMPICO DE HORTALEZA 'A'                                                                                                                            3                                                                                                                                                11                                                                        /                                                                            0                                                                        /                                                                            3                                                                        /                                                                            8                                                                                                                                                15                                                                        /                                                                            52                                                                                                                                                0
# 23 12                                                                                                                        A.D. UNION ADARVE 'B'                                                                                                                            1                                                                                                                                                11                                                                        /                                                                            0                                                                        /                                                                            1                                                                        /                                                                            10                                                                                                                                                4                                                                        /                                                                            84                                                                                                                                                0

# %% [markdown]
# Dentro de cada fila obtendremos los datos uno a uno. El nombre del equipo está en un elemento team-name, como solo hay uno usamos `select_one`

# %%
team_name = row[0].select_one('.team-name')
team_name
# Out:
# <p class="team-name">
# <a href="https://www.rffm.es/competiciones/equipos?team=3909479&amp;season=18&amp;type=2&amp;grouping=1&amp;competition=15293079&amp;group=16544990&amp;round=&amp;club=">
#                                                         C.D. ESTUDIANTES LAS TABLAS 'A'
#                                                     </a>
# </p>

# %%
a = team_name.find("a")
a
# Out:
# <a href="https://www.rffm.es/competiciones/equipos?team=3909479&amp;season=18&amp;type=2&amp;grouping=1&amp;competition=15293079&amp;group=16544990&amp;round=&amp;club=">
#                                                         C.D. ESTUDIANTES LAS TABLAS 'A'
#                                                     </a>

# %%
a.text
# Out:
# "\n                                                        C.D. ESTUDIANTES LAS TABLAS 'A'\n                                                    "

# %%
a.text.strip()
# Out:
# "C.D. ESTUDIANTES LAS TABLAS 'A'"

# %%
team_name.a.text.strip()
# Out:
# "C.D. ESTUDIANTES LAS TABLAS 'A'"

# %% [markdown]
# Los elementos de cada fila:

# %%
datos = row[0].select('.table-row-item')
print(len(datos))
# Out:
# 9

# %%
datos[0].text.strip()
# Out:
# "1\n                                                                    \n\n\n\n\n\n\n\n\n\n\n                                                        C.D. ESTUDIANTES LAS TABLAS 'A'"

# %%
datos[1].text.strip()
# Out:
# '28'

# %% [markdown]
# Ya podemos trabajar

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

url = "https://www.rffm.es/competiciones/clasificaciones?season=18&type=2&grouping=1&competition=15293079&group=16544990&round="


page = requests.get(url)
soup = BeautifulSoup(page.text, 'html.parser')  # le pasamos el texto en HTML para que lo analice
rows =  soup.select('.table-row') # las filas



cols = {"Equipos":[],"Puntos":[],"Jugados":[],"Ganados":[],"Empates":[],"Perdidos":[], "GF":[],"GC":[],"PuntosSancion":[]}
keys = list(cols.keys())

for f in range(len(rows)//2): # lo de /2 es porque parece que se repiten
    row = rows[f]
    team_name = row.select_one('.team-name')
    cols["Equipos"].append(team_name.a.text.strip())
    datos = row.select('.table-row-item') # datos de la fila
    
    # completamos columna a columna
    for c in range(1,len(datos)):
        nombre = keys[c] # la clave (Puntos, etc)
        valor = int(datos[c].text.strip())
        cols[nombre].append(valor)

# %%
import pandas as pd
df = pd.DataFrame(cols)
df
# Out:
#                                Equipos  Puntos  Jugados  Ganados  Empates  \
# 0      C.D. ESTUDIANTES LAS TABLAS 'A'      28       11        9        1
# 1                 UNION ZONA NORTE 'B'      25       11        8        1
# 2                   A.D. ESPERANZA 'A'      25       11        8        1
# 3                 REAL MADRID C.F. 'B'      24       11        7        3
# 4       GREDOS SAN DIEGO-MORATALAZ 'A'      20       11        6        2
# 5                    C.D. CANILLAS 'B'      19       11        6        1
# 6             A.D. OÑA SANCHINARRO 'A'      18       11        6        0
# 7                 CLUB SAN AGUSTIN 'A'      10       11        3        1
# 8                    A.D.A.E. SIMANCAS       9       11        3        0
# 9   ALAMEDA DE OSUNA ESCUELAS DE F 'A'       9       11        3        0
# 10      C.D. OLIMPICO DE HORTALEZA 'A'       3       11        0        3
# 11               A.D. UNION ADARVE 'B'       1       11        0        1
#
#     Perdidos  GF  GC  PuntosSancion
# 0          1  58  17              0
# 1          2  49  17              0
# 2          2  40  17              0
# 3          1  66  15              0
# 4          3  35  27              0
# 5          4  52  39              0
# 6          5  30  33              0
# 7          7  38  44              0
# 8          8  22  43              0
# 9          8  22  43              0
# 10         8  15  52              0
# 11        10   4  84              0
