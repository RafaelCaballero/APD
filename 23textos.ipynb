# %% [markdown]
# ## Adquisición y preprocesamiento de la información - RafaC
#
# <table>
#     <tr>
#       <td>Grado en Ingeniería de Datos e Inteligencia Artificial - Facultad de Informática - UCM
#       </td>
#       <td>
#       <img src="https://biblioteca.ucm.es/data/cont/media/www/pag-88746//escudo.jpg"  width=50/>
#       </td>
#      </tr>
# </table>
#
#
#
#
# ### Análisis de textos
#
# El mundo del análisis de textos es totalmente diferente a lo visto hasta ahora, con sus propios problemas y bibliotecas especializadas. Vamos a ver solo algunas de sus características.
#
# Empecemos asegurándonos de que las bibliotecas necesarias están instaladas

# %%
modules = ["wikipedia==1.4.0",  "bs4", "spacy==3.4.1", "nltk"]


import sys
import os.path
from subprocess import check_call
import importlib
import os

def instala(modules):
  print("Instalando módulos")
  for m in modules:
      # para el import quitamos [...] y ==...
      p = m.find("[")
      mi = m if p==-1 else m[:p]
      p = mi.find("==")
      mi = mi if p==-1 else mi[:p]

      torch_loader = importlib.util.find_spec(mi)
      if torch_loader is not None:
          print(m," encontrado")
      else:
          print(m," No encontrado, instalando...",end="")  
          try:        
            r = check_call([sys.executable, "-m", "pip", "install", "--user", m])
            print("¡hecho!")
          except:
            print("¡Problema al instalar ",m,"! ¿seguro que el módulo existe?",sep="")
              
  print("¡Terminado!")

instala(modules)
# Out:
# Instalando módulos
# wikipedia==1.4.0  encontrado
# bs4  encontrado
# spacy==3.4.1  encontrado
# nltk  encontrado
# ¡Terminado!

# %% [markdown]
# ## Tokens
#
# La primera idea es obtener las piezas sintácticas básicas, palabras, símbolos de puntuación, etc., pero esto no es tan trivial como parece. Empezamos usando la función estándar `split`

# %%
s = "Desde lo alto se divisa la ciudad y toda la campiña"
l = s.split(" ")
l
# Out:
# ['Desde',
#  'lo',
#  'alto',
#  'se',
#  'divisa',
#  'la',
#  'ciudad',
#  'y',
#  'toda',
#  'la',
#  'campiña']

# %%
s = "Se remueve, levanta una tenue polvareda, avanza."
l = s.split(" ")
l
# Out:
# ['Se', 'remueve,', 'levanta', 'una', 'tenue', 'polvareda,', 'avanza.']

# %% [markdown]
# Bibliotecas como spaCy permiten obtener mejor los tokens

# %%
import spacy
nlp = spacy.blank('es') # modelo
s = "Se remueve, levanta una tenue polvareda, avanza."
doc =  nlp(s)
l = [token.text for token in doc]
l
# Out:
# ['Se',
#  'remueve',
#  ',',
#  'levanta',
#  'una',
#  'tenue',
#  'polvareda',
#  ',',
#  'avanza',
#  '.']

# %% [markdown]
# Podemos "limpiar" el texto quedando solo con un tipo de palabras

# %%
l =  [token.text for token in doc if  token.is_alpha] 
l
# Out:
# ['Se', 'remueve', 'levanta', 'una', 'tenue', 'polvareda', 'avanza']

# %% [markdown]
# Un caso particular de *token* son las stop words, palabras sin semántica que pueden desvirtuar nuestros análisis

# %%
l =  [token.text for token in doc if  token.is_alpha and not token.is_stop] 
l
# Out:
# ['remueve', 'levanta', 'tenue', 'polvareda', 'avanza']

# %% [markdown]
# ### Contando oraciones y palabras
#
# Igual que con las palabras podemos intentarlo desde Python estándar:

# %%
s = "he comprado patatas, naranjas, manzanas..."
punto = s.find(".") # posición del primer punto
if punto!=-1: # -1 si no hay puntos
  print("La primera oración: ", s[:punto])
  print("El resto del texto: ", s[punto+1:])
# Out:
# La primera oración:  he comprado patatas, naranjas, manzanas
# El resto del texto:  ..

# %%
# !python -m spacy download es_core_news_sm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting es-core-news-sm==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.4.0/es_core_news_sm-3.4.0-py3-none-any.whl (12.9 MB)
#      --------------------------------------- 12.9/12.9 MB 15.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from es-core-news-sm==3.4.0) (3.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.0.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.4.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.0.10)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.4.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.10.1)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.6.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in e:\instalados\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.28.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.0.6)
# Requirement already satisfied: jinja2 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.1.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (8.1.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.9.2)
# Requirement already satisfied: setuptools in e:\instalados\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (65.5.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in e:\instalados\anaconda\lib\site-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (4.64.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.0.3)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in e:\instalados\anaconda\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\instalados\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in e:\instalados\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in e:\instalados\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in e:\instalados\anaconda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.26.12)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.7.8)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.0.3)
# Requirement already satisfied: colorama in e:\instalados\anaconda\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in e:\instalados\anaconda\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rafa\appdata\roaming\python\python39\site-packages (from jinja2->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.1.2)
# [+] Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# DEPRECATION: https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.4.0/es_core_news_sm-3.4.0-py3-none-any.whl#egg=es_core_news_sm==3.4.0 contains an egg fragment with a non-PEP 508 name pip 25.0 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/11617
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import es_core_news_sm
nlp = es_core_news_sm.load()
s = "he comprado patatas, naranjas, manzanas... todo en \
     http://verdurasfrescas.com. ¡Y ha llegado muy rápido!"
doc = nlp(s)
for i,o in enumerate(doc.sents):
    print(i+1,o)
# Out:
# 1 he comprado patatas, naranjas, manzanas... todo en      http://verdurasfrescas.com.
# 2 ¡Y ha llegado muy rápido!

# %%
from bs4 import BeautifulSoup
import requests
pagina = "https://www.gutenberg.org/cache/epub/8870/pg8870.html"
page = requests.get(pagina)
soup = BeautifulSoup(page.text, 'html.parser')  # le pasamos el texto en HTML para que lo analice
soup.text
# Out:
# '\nThe Project Gutenberg eBook of La Mejor Cocinera, Recetas de Cocina, by Calleja\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nThe Project Gutenberg eBook of La Mejor Cocinera, Recetas de Cocina\n\r\nThis ebook is for the use of anyone anywhere in the United States and most other parts of the world at no cost and with almost no restrictions whatsoever. You may copy it, give it away or re-use it under the terms of the Project Gutenberg License included with this ebook or online at www.gutenberg.org. If you are not located in the United States, you’ll have to check the laws of the country where you are located before using this eBook.\n\nTitle: La Mejor Cocinera, Recetas de Cocina\n\nAuthor: Calleja\n\nRelease date: September 1, 2005 [eBook #8870]Most recently updated: September 13, 2014\nLanguage: Spanish\n\n\n*** START OF THE PROJECT GUTENBERG EBOOK LA MEJOR COCINERA, RECETAS DE COCINA ***\n\nProduced by Distributed Proofreaders\nLA MEJOR COCINERA pará CALLEJA\n RECETAS DE COCINA\nÍNDICE\nA LAS SEÑORAS\nCALDOS\nCaldo sencillo\r\n —   español\r\n —   de ave\r\n —   improvisado\r\n —   de legumbres y verduras\r\n —   de cereales\nSOPAS\nSopa de yemas\r\n\r\n\xa0—  de obispo\r\n\r\n\xa0—  Juliana\r\n\r\n\xa0—  de huevo\r\n\r\n\xa0—  fina\r\n\r\n\xa0—  de croqueta\r\n\r\n\xa0—  de ajo\r\n\r\n\xa0—  de pasta\r\n\r\n\xa0—  de macarrones\r\n\r\n\xa0—  de almejas\r\n\r\n\xa0—  de pescado\r\n\r\n\xa0—  más fina\r\n\r\n\xa0—  de queso\r\n\r\n\xa0—  de mariscos\r\n\r\n\xa0—  real\r\n\r\n\xa0—  de almendra\r\n\r\n\xa0—  de arroz\r\n\r\n\xa0—  Lionesa\r\n\r\n\xa0—  de pescado\r\n\r\n\xa0—  de vigilia\r\n\r\n\xa0—  Juliana para vigilia\r\n\r\n\xa0—  Juliana\r\n\r\nConsomé de almejas\r\n\r\n\xa0\xa0—    de carnes\r\n\r\n\xa0\xa0—    de ave\r\n\r\n\xa0\xa0—    Juvenal\r\n\r\n\xa0\xa0—    a la Montmart\r\n\r\n\xa0\xa0—    Mesalina\r\n\r\n\xa0\xa0—    Martinière\r\n\r\nSopa a la Purísima\r\n\r\n\xa0\xa0—  de ostras\r\n\r\n\xa0\xa0—  de puré de judías encarnadas\r\n\r\n\xa0\xa0—  de acederas y huevos\r\n\r\n\xa0\xa0—  a la aragonesa\n\nPURÉS\nPuré de garbanzos\r\n —  de guisantes frescos\r\n —  de lentejas\r\n —  de judías secas\r\n —  de patatas\r\n —  de espinacas\r\n —  de habas\r\n —  de patatas al gratín\nPOTAJES\nPotaje Carmelita\r\n\r\n\xa0\xa0—   de judías estofadas\r\n\r\n\xa0\xa0—   con chorizo\r\n\r\n\xa0\xa0—   de garbanzos\r\n\r\n\xa0\xa0—   de    —  con espinacas\r\n\r\nOtro potaje de garbanzos\r\n\r\nPotaje de lentejas a la española\r\n\r\nPotaje de lentejas a la francesa\r\n\r\n\xa0\xa0—   de habas secas\r\n\r\n\xa0\xa0—   de guisantes\r\n\r\n\xa0\xa0—   de cocido\r\n\r\n\xa0\xa0—   de alubias encarnadas\r\n\r\n\xa0\xa0—   velouté\r\n\r\n\xa0\xa0—   de judías encarnadas estofadas\n\nVERDURAS\nTallos de alcachofas\r\n\r\nAchicorias\r\n\r\nJudías verdes\r\n\r\nEspinacas\r\n\r\nHabas verdes\r\n\r\nColiflor\r\n\r\nPisto\r\n\r\nZanahorias\r\n\r\nPastel de coliflor\r\n\r\nColiflor en salsa blanca\r\n\r\nColiflor frita\r\n\r\nCardos a la española\r\n\r\nHabas a la casera\r\n\r\nHabas a la maître d\'Hotel\r\n\r\nGuisantes a la inglesa\r\n\r\n\xa0\xa0\xa0—     a la bilbaína\r\n\r\n\xa0\xa0\xa0—     a la parisién\r\n\r\nMenestra de guisantes\r\n\r\nAchicorias a la crema\r\n\r\nAlcachofas fritas\r\n\r\nAcederas con huevos duros\r\n\r\nEspárragos al natural\r\n\r\nCardo al natural\r\n\r\nMezcla de verduras\r\n\r\nSetas\n\nMENESTRA\nPlato de espinaca\r\nPatatas cocidas\r\n  —    en salsa\r\n  —    en puré\r\n  —    al gratín\r\nPastel para mezclar con carne o salchichas\r\nPatatas a la maître d\'Hotel\r\nTimbal de patata\r\nPatatas a la vinagreta\r\n  —    a la soufflés\r\nAcelgas en paquetitos\r\nPatatas fritas\r\n  —    Georgette\r\n  —    a la Dietrich\r\nEspárragos a la andaluza\nENSALADAS\nEnsalada de lechuga\r\n\r\n\xa0\xa0\xa0—    de escarola\r\n\r\n\xa0\xa0\xa0—    de pepino\r\n\r\n\xa0\xa0\xa0—    de remolacha\r\n\r\n\xa0\xa0\xa0—    de apio\r\n\r\n\xa0\xa0\xa0—    mezclada\r\n\r\nEnsalada de puntas de espárragos\r\n\r\nEnsalada de alcachofas\r ...

# %%
doc =  nlp(soup.text)
print("El libro incluye ", len(list(doc.sents)), "oraciones")
# Out:
# El libro incluye  1826 oraciones

# %% [markdown]
# Si lo que queremos es contar palabras podemos utilizar `Counter` que incluye un diccionario con cada letra de la palabra y su frecuencia.

# %%
from collections import Counter
palabras =  [token.text for token in doc if  token.is_alpha and not token.is_stop] 
c = Counter(palabras)

# %%
c
# Out:
# Counter({'Project': 85,
#          'Gutenberg': 85,
#          'eBook': 10,
#          'of': 112,
#          'Cocinera': 3,
#          'Recetas': 3,
#          'Cocina': 3,
#          'by': 26,
#          'Calleja': 2,
#          'This': 3,
#          'ebook': 2,
#          'is': 22,
#          'for': 22,
#          'use': 9,
#          'anyone': 5,
#          'anywhere': 2,
#          'in': 58,
#          'United': 15,
#          'States': 15,
#          'and': 65,
#          'most': 4,
#          'other': 16,
#          'parts': 2,
#          'world': 2,
#          'at': 13,
#          'cost': 3,
#          'with': 46,
#          'almost': 2,
#          'restrictions': 2,
#          'whatsoever': 2,
#          'You': 12,
#          'may': 15,
#          'copy': 12,
#          'it': 13,
#          'give': 3,
#          'away': 2,
#          'or': 71,
#          'under': 5,
#          'terms': 20,
#          'License': 10,
#          'included': 3,
#          'this': 39,
#          'online': 4,
#          'If': 16,
#          'you': 55,
#          'are': 23,
#          'not': 26,
#          'located': 7,
#          'have': 6,
#          'to': 76,
#          'check': 4,
#          'laws': 10,
#          'country': 4,
#          'where': 5,
#          'before': 3,
#          'using': 6,
#          'Title': 1,
#          'Author': 1,
#          'Release': 1,
#          'date': 3,
#          'September': 2,
#          'recently': 1,
#          'updated': 1,
#          'Language': 1,
#          'Spanish': 1,
#          'START': 2,
#          'OF': 10,
#          'PROJECT': 4,
#          'GUTENBERG': 4,
#          'EBOOK': 2,
#          'COCINERA': 3,
#          'RECETAS': 7,
#          'COCINA': 3,
#          'Produced': 1,
#          'Distributed': 1,
#          'Proofreaders': 1,
#          'pará': 1,
#          'CALLEJA': 1,
#          'ÍNDICE': 1,
#          'SEÑORAS': 2,
#          'CALDOS': 2,
#          'Caldo': 1,
#          'sencillo': 2,
#          'español': 2,
#          'ave': 22,
#          'improvisado': 2,
#          'legumbres': 8,
#          'verduras': 13,
#          'cereales': 1,
#          'SOPAS': 2,
#          'Sopa': 3,
#          'yemas': 120,
#          'obispo': 1,
#          'Juliana': 3,
#          'huevo': 171,
#          'fina': 49,
#          'croqueta': 8,
#          'ajo': 94,
#          'pasta': 119,
#          'macarrones': 10,
#          'almejas': 19,
#          'pescado': 24,
#          'queso': 37,
#          'mariscos': 3,
#          'real': 3,
#          'almendra': 21,
#          'arroz': 43,
#          'Lionesa': 1,
#          'vigilia': 6,
#          'Consomé': 1,
#          'carnes': 10,
#          'Juvenal': 1,
#          'Montmart': 1,
#          'Mesalina': 1,
#          'Martinière': 1,
#          'Purísima': 1,
#          'ostras': 10,
#          'puré': 16,
#          'judías': 11,
#          'encarnadas': 5,
#          'acederas': 4,
#          'huevos': 152,
#          'aragonesa': 1,
#          'PURÉS': 2,
#          'Puré': 1,
#          'garbanzos': 17,
#          'guisantes': 31,
#          'frescos': 5,
#          'lentejas': 7,
#          'secas': 6,
#          'patatas': 51,
#          'espinacas': 14,
#          'habas': 3,
#          'gratín': 7,
#          'POTAJES': 2,
#          'Potaje': 3,
#          'Carmelita': 1,
#          'estofadas': 4,
#          'chorizo': 17,
#          'potaje': 1,
#          'española': 11,
#          'francesa': 5,
#          'cocido': 69,
#          'alubias': 5,
#          'velouté': 1,
#          'VERDURAS': 2,
#          'Tallos': 1,
#          'alcachofas': 23,
#          'Achicorias': 2,
#          'Judías': 1,
#          'verdes': 6,
#          'Espinacas': 1,
#          'Habas': 4,
#          'Coliflor': 3,
#          'Pisto': 1,
#          'Zanahorias': 1,
#          'Pastel': 11,
#          'coliflor': 7,
#          'salsa': 181,
#          'blanca': 32,
#          'frita': 11,
#          'Cardos': 1,
#          'casera': 5,
#          'maître': 3,
#          'Guisantes': 2,
#          'inglesa': 13,
#          'bilbaína': 1,
#          'parisién': 1,
#          'Menestra': 1,
#          'crema': 21,
#          'Alcachofas': 2,
#          'fritas': 25,
#          'Acederas': 1,
#          'duros': 25,
#          'Espárragos': 3,
#          'natural': 7,
#          'Cardo': 1,
#          'Mezcla': 1,
#          'Setas': 1,
#          'MENESTRA': 3,
#          'Plato': 1,
#          'espinaca': 1,
#          'Patatas': 5,
#          'cocidas': 42,
#          'mezclar': 2,
#          'carne': 63,
#          'salchichas': 8,
#          'Timbal': 2,
#          'patata': 16,
#          'vinagreta': 10,
#          'soufflés': 2,
#          'Acelgas': 1,
#          'paquetitos': 2,
#          'Georgette': 1,
#          'Dietrich': 1,
#          'andaluza': 2,
#          'ENSALADAS': 2,
#          'Ensalada': 3,
#          'lechuga': 6,
#          'escarola': 3,
#          'pepino': 2,
#          'remolacha': 1,
#          'apio': 4,
#          'mezclada': 3,
#          'puntas': 9,
#          'espárragos': 16,
#          'anchoas': 7,
#          'cardo': 3,
#          'SALSAS': 2,
#          'Salsa': 4,
#          'mayonesa': 24,
#          'almendras': 31,
#          'rubia': 1,
#          'verde': 9,
#          'amarilla': 5,
#          'tártara': 2,
#          'tomates': 17,
#          'Robert': 1,
#          'trufas': 25,
#          'champiñons': 14,
#          'perigord': 1,
#          'alioli': 1,
#          'aves': 15,
#          'nuez': 27,
#          'cerdo': 66,
#          'roubire': 1,
#          'langostinos': 13,
#          'cangrejos': 9,
#          'aspic': 3,
#          'remolada': 1,
#          'chaufroix': 5,
#          'oscuro': 2,
#          'blanco': 98,
#          'amarillo': 4,
#          'hierbas': 27,
#          'HUEVOS': 32,
#          'Huevos': 7,
#          'pasados': 4,
#          'agua': 325,
#          'fritos': 22,
#          'estrellados': 3,
#          'camisa': 1,
#          'escalfados': 2,
#          'cristal': 6,
#          'palacio': 1,
#          'capricho': 1,
#          'Sor': 1,
#          'Simena': 1,
#          'Tórtola': 1,
#          'Valencia': 1,
#          'turca': 1,
#          'polinac': 1,
#          'primavera': 4,
#          'rellenos': 12,
#          'fórmula': 40,
#          'tomate': 93,
#          'mantequilla': 83,
#          'jamón': 108,
#          'cubilete': 1,
#          'plato': 46,
#          'americana': 5,
#          'marinera': 6,
#          'entremés': 1,
#          'monstruo': 1,
#          'TORTILLAS': 3,
#          'Tortilla': 3,
#          'leche': 105,
#          'bacalao': 13,
#          'picadillo': 64,
#          'sesos': 10,
#          'merluza': 21,
#          'bechamelle': 25,
#          'ron': 11,
#          'finas': 27,
#          'PESCADOS': 2,
#          'Besugo': 3,
#          'asado': 21,
#          'frito': 48,
#          'minuto': 2,
#          'dorado': 11,
#          'Merluza': 1,
#          'cocida': 25,
#          'rebozada': 2,
#          'asada': 12,
#          'Cola': 2,
#          'Tarta': 3,
#          'florentina': 1,
#          'Bacalao': 1,
#          'horno': 189,
#          'vizcaína': 1,
#          'arriero': 1,
#          'croquetas': 8,
#          'disfrazado': 1,
#          'rebozado': 2,
#          'Salmón': 1,
#          'aceitunas': 28,
#          'chambord': 2,
#          'genovesa': 1,
#          'alcaparras': 7,
#          'Salmonetes': 1,
#          'Langostinos': 1,
#          'Langosta': 1,
#          'Almejas': 1,
#          'sencillas': 3,
#          'Escabeche': 1,
#          'Lamprea': 1,
#          'Truchas': 2,
#          'Calamares': 1,
#          'chipirones': 1,
#          'tinta': 8,
#          'Lubina': 1,
#          'Rodaballo': 1,
#          'caldo': 139,
#          'corto': 1,
#          'rodaballo': 2,
#          'Lenguados': 1,
#          'Marguery': 1,
#          'rusa': 2,
#          'Sardinas': 1,
#          'rebozadas': 7,
#          'rellenas': 11,
#          'asadas': 11,
#          'Pescadillas': 1,
#          'parrilla': 25,
#          'limón': 106,
#          'Carpa': 1,
#          'alemana': 3,
#          'Raya': 1,
#          'Ranas': 1,
#          'Frito': 1,
#          'ranas': 2,
#          'Anguila': 1,
#          'Anguilas': 2,
#          'guisadas': 3,
#          'Atún': 1,
#          'guisado': 3,
#          'Bonito': 1,
#          'RELLENOS': 4,
#          'Conchas': 1,
#          'Pimientos': 3,
#          'Calabacines': 1,
#          'Lomo': 6,
#          'relleno': 15,
#          'Solomillo': 2,
#          'Morcilla': 2,
#          'navarra': 1,
#          'CONSERVAS': 2,
#          'Tomate': 2,
#          'Receta': 1,
#          'práctica': 2,
#          'salmuera': 4,
#          'encarnados': 2,
#          'vaina': 1,
#          'Fritada': 1,
#          'Melocotones': 1,
#          'Guinda': 1,
#          'aguardiente': 11,
#          'Aceitunas': 1,
#          'vinagre': 52,
#          'CARNES': 5,
#          'Carne': 3,
#          'rellena': 34,
#          'Cordero': 1,
#          'Ternera': 9,
#          'adobado': 4,
#          'Bola': 1,
#          'Estofado': 1,
#          'Mechado': 1,
#          'Fiambre': 1,
#          'Cabeza': 2,
#          'Bifteck': 1,
#          'Chuletas': 7,
#          'Gorrinito': 1,
#          'rajas': 18,
#          'fiambre': 1,
#          'salteada': 1,
#          'jardinera': 3,
#          'Pudding': 3,
#          'Fricandeau': 1,
#          'Cucuruchos': 1,
#          'zanahorias': 27,
#          'trufada': 3,
#          'toro': 2,
#          'Cadera': 1,
#          'moldeadas': 4,
#          'catalana': 3,
#          'italiana': 2,
#          'filetes': 17,
#          'carnero': 25,
#          'Batallón': 1,
#          'Salmigondis': 1,
#          'Ropa': 2,
#          'vieja': 2,
#          'Marengot': 2,
#          'Chuleta': 1,
#          'ternera': 72,
#          'Granadinas': 1,
#          'glaseadas': 1,
#          'vaca': 74,
#          'asador': 5,
#          'Guisado': 1,
#          'Pecho': 2,
#          'Solomillos': 1,
#          'verdura': 4,
#          'picatostes': 10,
#          'setas': 16,
#          'papillot': 1,
#          'Lengua': 4,
#          'escarlata': 5,
#          'Vaca': 1,
#          'estofada': 1,
#          'Manos': 3,
#          'jugo': 45,
#          'Pierna': 1,
#          'campesina': 1,
#          'cordero': 8,
#          'papillote': 1,
#          'empanadas': 5,
#          'Costilla': 1,
#          'Empanadas': 3,
#          'clase': 14,
#          'CERDO': 14,
#          'GUISADAS': 2,
#          'EMBUTIDOS': 2,
#          'Tocino': 1,
#          'magro': 2,
#          'pimiento': 16,
#          'juncadella': 1,
#          'Lonjas': 1,
#          'cebollas': 25,
#          'Orejas': 1,
#          'trufadas': 1,
#          'hígado': 17,
#          'Foiegras': 1,
#          'Jamón': 4,
#          'Jamoncillo': 1,
#          'trufado': 3,
#          'dulce': 10,
#          'momento': 17,
#          'hilados': 2,
#          'Queso': 2,
#          'cabeza': 25,
#          'jabalí': 1,
#          'Chorizo': 1,
#          'crudo': 13,
#          'Salchichón': 1,
#          'Salchichas': 1,
#          'Longanizas': 1,
#          'Butifarra': 1,
#          'Mortadela': 1,
#          'Morcillas': 1,
#          'asturianas': 1,
#          'conservar': 4,
#          'embutido': 5,
#          'FRITOS': 2,
#          'Sesos': 1,
#          'huecos': 3,
#          'rebozados': 1,
#          'Boladillos': 1,
#          'Bolos': 1,
#          'Buñuelos': 3,
#          'viento': 1,
#          'Torrijas': 1,
#          'Chandrios': 1,
#          'Envueltas': 1,
#          'pechuga': 15,
#          'Manzanas': 1,
#          'AVES': 2,
#          'CAZA': 2,
#          'Pollo': 1,
#          'salteados': 3,
#          'Mascota': 1,
#          'manchega': 1,
#          'tiernos': 4,
#          'Pechugas': 2,
#          'pollo': 14,
#          'Gallina': 4,
#          'guisada': 2,
#          'pepitoria': 4,
#          'Capón': 2,
#          'Pato': 1,
#          'gallina': 25,
#          'capón': 6,
#          'mechado': 1,
#          'dorada': 14,
#          'pebre': 1,
#          'Ganso': 1,
#          'Pavo': 1,
#          'Pavos': 1,
#          'asados': 13,
#          'Pichones': 4,
#          'Menudillos': 1,
#          'pavo': 10,
#          'paisana': 1,
#          'estofados': 1,
#          'Carolina': 1,
#          'champiñones': 1,
#          'jerez': 26,
#          'Faisán': 1,
#          'Codornices': 2,
#          'hoja': 12,
#          'parra': 3,
#          'Perdices': 2,
#          'escabechadas': 1,
#          'Malvices': 1,
#          'Chochas': 1,
#          'Becacina': 1,
#          'Gazapos': 1,
#          'papillotes': 2,
#          'Conejo': 3,
#          'casero': 3,
#          'liebre': 7,
#          'Liebre': 2,
#          'Corzo': 1,
#          'pierna': 7,
#          'Cabrito': 1,
#          'Becadas': 2,
#          'monte': 1,
#          'pastel': 5,
#          'Bocadillos': 2,
#          'ARROZ': 15,
#          'Arroz': 4,
#          'menudillos': 12,
#          'riojana': 1,
#          'langosta': 9,
#          'Paella': 1,
#          'riñones': 4,
#          'PLATOS': 2,
#          'VARIADOS': 2,
#          'Macarrones': 2,
#          'Canalones': 1,
#          'Migas': 1,
#          'Carlos': 2,
#          'IV': 2,
#          'Criadillas': 1,
#          'Fiambres': 1,
#          'Sandwich': 1,
#          'hojaldre': 15,
#          'Empanadillas': 3,
#          'pan': 122,
#          'Pasteles': 2,
#          'Hígado': 1,
#          'Callos': 1,
#          'Flan': 5,
#          'Mollejas': 1,
#          'Riñones': 3,
#          'Albóndigas': 1,
#          'Croquetas': 2,
#          'PASTELERÍA': 2,
#          'REPOSTERÍA': 2,
#          'Bizcochos': 3,
#          'brazo': 4,
#          'gitano': 4,
#          'Bizcocho': 5,
#          'almíbar': 76,
#          'manteca': 274,
#          'canela': 67,
#          'ángel': 2,
#          'Brazo': 1,
#          'borracho': 1,
#          'Cajas': 1,
#          'bizcocho': 25,
#          'banquete': 2,
#          'Bizcochón': 1,
#          'chocolate': 17,
#          'espuma': 6,
#          'frutas': 29,
#          'Moka': 1,
#          'manzanas': 20,
#          'castañas': 7,
#          'té': 8,
#          'tomar': 8,
#          'capuchinas': 2,
#          'Rosquillas': 1,
#          'Almagro': 1,
#          'consejo': 1,
#          'Isidro': 1,
#          'yema': 31,
#          'económicas': 2,
#          'Magdalenas': 2,
#          'Polvorones': 1,
#          'Mantecados': 2,
#          'franceses': 1,
#          'América': 1,
#          'Viena': 4,
#          'Astorga': 1,
#          'Torta': 1,
#          'merengue': 12,
#          'Roscas': 1,
#          'Tortas': 1,
#          'chatchigorris': 2,
#          'Punta': 1,
#          'Llasante': 1,
#          'Budín': 1,
#          'baño': 44,
#          'maría': 37,
#          'fuego': 178,
#          'plátanos': 2,
#          'Leche': 1,
#          'Cuajada': 1,
#          'Requesón': 1,
#          'postre': 3,
#          'caña': 1,
#          'Postre': 2,
#          'Suspiros': 1,
#          'Cafareles': 1,
#          'Petits': 1,
#          'Choux': 1,
#          'Saint': 1,
#          'Honoré': 1,
#          'Soplillo': 1,
#          'Pastelillos': 1,
#          'POSTRE': 2,
#          'soufflé': 1,
#          'manzana': 12,
#          'Merengues': 2,
#          'Chantilly': 7,
#          'Crema': 4,
#          'naranja': 20,
#          'Gelatina': 4,
#          'Pan': 1,
#          'Sequillos': 1,
#          'Tocinillo': 1,
#          'cielo': 1,
#          'avellana': 5,
#          'Natillas': 1,
#          'acarameladas': 2,
#          'bizcochos': 15,
#          'café': 37,
#          'Galletas': 1,
#          'Bollos': 1,
#          'Medias': 2,
#          'lunas': 3,
#          'Monerías': 1,
#          'Mil': 1,
#          'hojas': 13,
#          'Píos': 1,
#          'nonos': 1,
#          'Calineta': 1,
#          'moles': 4,
#          'Ensaimadas': 1,
#          'Roscón': 1,
#          'Guirlache': 1,
#          'Turrón': 2,
#          'Bollitos': 1,
#          'Papelitos': 1,
#          'Patata': 1,
#          'pastelillos': 3,
#          'Patelillos': 1,
#          'Marrón': 1,
#          'glacé': 1,
#          'capuchina': 1,
#          'Azúcar': 2,
#          'clarificada': 1,
#          'confitar': 2,
#          'Baño': 1,
#          'Yemas': 1,
#          'coco': 13,
#          'Piñones': 1,
#          'bañados': 1,
#          'Pastillas': 1,
#          'Azucarillos': 1,
#          'Almendras': 2,
#          'garapiñadas': 1,
#          'Churros': 1,
#          'Dulce': 11,
#          'DULCE': 17,
#          'FRUTAS': 2,
#          'membrillo': 5,
#          'Jalea': 4,
#          'Mermelada': 4,
#          'Manzana': 1,
#          'moldeada': 3,
#          'Pasta': 6,
#          'Naranjas': 1,
#          'confitadas': 10,
#          'cereza': 2,
#          'guinda': 3,
#          'Cabello': 1,
#          'ciruela': 7,
#          'claudia': 1,
#          'higo': 1,
#          'higos': 4,
#          'melocotón': 5,
#          'albaricoque': 5,
#          'Albaricoque': 1,
#          'moldeado': 1,
#          'pera': 4,
#          'Compota': 1,
#          'Compotas': 1,
#          'sandía': 3,
#          'Sandía': 1,
#          'confitada': 2,
#          'fresa': 12,
#          'grosella': 7,
#          'batatas': 2,
#          'Batatas': 1,
#          'uva': 2,
#          'Uvas': 1,
#          'Ciruelas': 1,
#          'confitados': 1,
#          'uvas': 7,
#          'HELADOS': 2,
#          'hacerlos': 2,
#          'helado': 16,
#          'Mantecado': 3,
#          'Helado': 4,
#          'arlequín': 1,
#          'vainilla': 14,
#          'Biscuit': 1,
#          'Sorbete': 1,
#          'JARABES': 2,
#          'PONCHES': 2,
#          'Jarabe': 1,
#          'malvavisco': 2,
#          'Ponche': 1,
#          'LICORES': 2,
#          'Licor': 2,
#          'menta': 7,
#          'Curaçao': 1,
#          'Chartreuse': 1,
#          'Anisete': 1,
#          'Anisado': 1,
#          'SERVIR': 2,
#          'COMIDA': 2,
#          'menús': 3,
#          'almuerzos': 1,
#          'comidas': 3,
#          'banquetes': 1,
#          'ÚTILES': 2,
#          'tocador': 3,
#          'Jabón': 2,
#          'afeitarse': 1,
#          'Agua': 9,
#          'perfumada': 2,
#          'Dentífrico': 1,
#          'colonia': 1,
#          'lavar': 1,
#          'Desinfección': 1,
#          'objetos': 4,
#          'dientes': 10,
#          'Polvos': 1,
#          'dentífricos': 1,
#          'ojos': 2,
#          'deshinchar': 2,
#          'párpados': 4,
#          'manos': 12,
#          'arrugas': 1,
#          'color': 32,
#          'cara': 4,
#          'rostros': 1,
#          'pálidos': 1,
#          'uñas': 3,
#          'LIMPIEZA': 3,
#          'Lejía': 1,
#          'sebo': 3,
#          'aceite': 202,
#          'frío': 19,
#          'brillo': 5,
#          'suelos': 1,
#          'calzado': 2,
#          'negro': 4,
#          'limpiar': 3,
#          'plata': 6,
#          'bronces': 1,
#          'mármol': 13,
#          'manchas': 5,
#          'cuero': 2,
#          'hierro': 4,
#          'muebles': 1,
#          'franelas': 2,
#          'aceros': 1,
#          'cera': 5,
#          'esperma': 2,
#          'camas': 2,
#          'dueña': 2,
#          'hogar': 1,
#          'dedica': 1,
#          'libro': 6,
#          'cocina': 4,
#          'cocinera': 2,
#          'casa': 5,
#          'señora': 2,
#          'cualquiera': 6,
#          'posición': 1,
#          'social': 1,
#          'orden': 2,
#          'economía': 1,
#          'completo': 3,
#          'faltar': 1,
#          'poblaciones': 1,
#          'pequeñas': 10,
#          'comercios': 1,
#          'surtidos': 1,
#          'indispensable': 2,
#          'amas': 1,
#          'preparen': 1,
#          'tiempo': 25,
#          'conservas': 1,
#          'pescados': 8,
#          'Aprendiendo': 1,
#          'enseña': 1,
#          'forma': 46,
#          'sencilla': 1,
#          'despensa': 1,
#          'provista': 1,
#          'facilitando': 1,
#          'preparación': 4,
#          'comida': 9,
#          'improvisada': 1,
#          'sabrá': 1,
#          'elegir': 1,
#          'menú': 2,
#          'servirse': 21,
#          'ofrece': 1,
#          'recetas': 2,
#          'preparar': 1,
#          'presente': 2,
#          'invitados': 3,
#          'familiares': 2,
#          'entremeses': 1,
#          'licores': 22,
#          'recomendable': 1,
#          'premio': 2,
#          'colegios': 2,
#          'escuelas': 2,
#          'niñas': 2,
#          'seguridad': 1,
#          'regalo': 1,
#          'ofrecérseles': 1,
#          'Contiene': 1,
#          'regiones': 1,
#          'postres': 13,
#          'repostería': 1,
#          'pastelería': 1,
#          'helados': 4,
#          'resultado': 2,
#          'práctico': 2,
#          'señoras': 3,
#          'encontrarán': 1,
#          'fórmulas': 6,
#          'limpieza': 1,
#          'lejías': 1,
#          'jabones': 2,
#          'insistimos': 1,
#          'recomendar': 1,
#          'señorita': 1,
#          'sale': 3,
#          'escuela': 1,
#          'colegio': 1,
#          'ejemplares': 1,
#          'aficiona': 1,
#          'leerlo': 1,
#          'practicarlo': 1,
#          'vías': 1,
#          'útil': 1,
#          'familia': 2,
#          'proporcionándole': 1,
#          'dispendios': 1,
#          'sabrosa': 1,
#          'nutritiva': 1,
#          'agrado': 1,
#          'madres': 1,
#          'públicas': 1,
#          'dedicase': 1,
#          'semana': 2,
#          'particulares': 1,
#          'necesario': 18,
#          'incluirse': 1,
#          'gastos': 1,
#          'material': 1,
#          'haga': 4,
#          'niña': 1,
#          'mujer': 1,
#          'educada': 1,
#          'instruida': 1,
#          'solidez': 1,
#          'requiere': 1,
#          'base': 1,
#          'edificio': 1,
#          'sociedad': 1,
#          'compara': 1,
#          'transcendencia': 1,
#          'vida': 1,
#          'futura': 1,
#          'CALDO': 8,
#          'kilo': 98,
#          'buey': 1,
#          'póngase': 23,
#          'litro': 56,
#          'sal': 331,
#          'zanahoria': 13,
#          'puerro': 9,
#          'cuézase': 6,
#          'hora': 42,
#          'servirlo': 20,
#          'agregando': 24,
#          'trozo': 37,
#          'jícaras': 8,
#          'previamente': 7,
#          'remojados': 4,
#          'Téngase': 1,
#          'media': 52,
#          'cociendo': 18,
#          'lento': 62,
#          'trozos': 43,
#          'cocer': 119,
#          'litros': 18,
#          'cebolleta': 2,
#          'ramita': 3,
#          'perejil': 144,
#          'hervir': 108,
#          'sirve': 115,
#          'cien': 48,
#          'gramos': 140,
#          'extracto': 1,
#          'gelatinas': 1,
#          'hirviendo': 57,
#          'disuelve': 7,
#          'LEGUMBRES': 1,
#          'jícara': 27,
#          'habichuelas': 1,
#          'puerros': 5,
#          'cebolletas': 3,
#          'sazona': 49,
#          'compone': 4,
#          'tamiz': 20,
#          'niños': 1,
#          'convalecientes': 1,
#          'échese': 8,
#          'cebada': 1,
#          'trigo': 2,
#          'avena': 1,
#          'maíz': 1,
#          'centeno': 1,
#          'sazónese': 6,
#          'hierva': 5,
#          'reducirse': 4,
#          'pásenlo': 1,
#          'colador': 20,
#          'SOPA': 28,
#          'batidas': 31,
#          'meten': 36,
#          'estén': 30,
#          'duras': 5,
#          'sacan': 42,
#          'cortan': 58,
#          'trocitos': 28,
#          'cuadraditos': 15,
#          'echan': 47,
#          'poniendo': 41,
#          'deshace': 9,
#          'cacerola': 103,
#          'echa': 193,
#          'harina': 167,
#          'moviendo': 16,
#          'cesar': 34,
#          'echando': 24,
#          'baten': 71,
#          'mezclando': 15,
#          'mezclado': 23,
#          'agrega': 64,
#          'hervido': 6,
#          'ratito': 7,
#          'poquitos': 1,
#          'claras': 55,
#          'habrán': 9,
#          'batido': 51,
#          'punto': 121,
#          'nieve': 28,
#          'porciones': 6,
#          'fríen': 75,
#          'cebolla': 154,
#          'picada': 24,
#          'nabos': 7,
#          'cortadas': 15,
#          'tiritas': 10,
#          'hojita': 1,
#          'hierbabuena': 5,
#          'picado': 40,
#          'rehogado': 4,
#          'pone': 321,
#          'repollo': 2,
#          'regulares': 6,
#          'rehoga': 19,
#          'deja': 112,
#          'horas': 81,
#          'sopa': 27,
#          'cortada': 8,
#          'rehogar': 8,
#          'sazonado': 16,
#          'avellanas': 8,
#          'tostadas': 15,
#          'molidas': 9,
#          'persona': 5,
#          'finos': 3,
#          'mezclándolos': 1,
#          'servirla': 15,
#          'taza': 18,
#          'masa': 43,
#          ...})

# %%
c.most_common(20)
# Out:
# [('sal', 331),
#  ('agua', 325),
#  ('pone', 321),
#  ('manteca', 274),
#  ('azúcar', 225),
#  ('aceite', 202),
#  ('echa', 193),
#  ('horno', 189),
#  ('salsa', 181),
#  ('fuego', 178),
#  ('huevo', 171),
#  ('harina', 167),
#  ('cebolla', 154),
#  ('huevos', 152),
#  ('perejil', 144),
#  ('ponen', 144),
#  ('gramos', 140),
#  ('caldo', 139),
#  ('pan', 122),
#  ('punto', 121)]

# %% [markdown]
# Podemos añadir "the" como stopword

# %%
nlp = spacy.blank("es")
nlp.Defaults.stop_words.add("the")
doc =  nlp(soup.text)
palabras =  [token.text for token in doc if  token.is_alpha and not token.is_stop] 
c = Counter(palabras)
c.most_common(20)
# Out:
# [('sal', 331),
#  ('agua', 325),
#  ('pone', 321),
#  ('manteca', 274),
#  ('azúcar', 225),
#  ('aceite', 202),
#  ('echa', 193),
#  ('horno', 189),
#  ('salsa', 181),
#  ('fuego', 178),
#  ('huevo', 171),
#  ('harina', 167),
#  ('cebolla', 154),
#  ('huevos', 152),
#  ('perejil', 144),
#  ('ponen', 144),
#  ('gramos', 140),
#  ('caldo', 139),
#  ('pan', 122),
#  ('punto', 121)]

# %% [markdown]
# ### Lemas y raíces
#
# El resultado anterior se ve afectado por el hecho de que la misma palabra puede aparecer en singular, plural, verbos conjugados de distinta forma, etc.

# %%
import es_core_news_sm
nlp = es_core_news_sm.load()
doc =  nlp(soup.text)
palabras = [p.lemma_.upper() for p in doc
            if p.is_alpha and not p.is_stop]
c = Counter(palabras)
c.most_common(20)
# Out:
# [('PONER', 517),
#  ('AGUA', 342),
#  ('SAL', 334),
#  ('HUEVO', 325),
#  ('COCER', 310),
#  ('MANTECA', 266),
#  ('ECHAR', 265),
#  ('AZÚCAR', 228),
#  ('SERVIR', 210),
#  ('ACEITE', 210),
#  ('SALSA', 198),
#  ('HORNO', 189),
#  ('FUEGO', 181),
#  ('DEJAR', 176),
#  ('HARINA', 158),
#  ('CEBOLLA', 155),
#  ('YEMA', 151),
#  ('CALDO', 149),
#  ('PEREJIL', 144),
#  ('GRAMO', 143)]

# %% [markdown]
# La **extracción de raíces**, conocida en la literatura en inglés como *stemming*, que convierte palabras a su raíz eliminando sufijos de persona, género, etc. Es una alternativa a la lematización que ha sido tradicionalmente utilizada en aplicaciones de inteligencia artificial, por ejemplo en *aprendizaje automático*, pero que no es tan útil para nuestros propósitos al no obtenerse palabras completas como resultados

# %%
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer('spanish')
palabras = [stemmer.stem(p.text).upper() for p in doc
              if p.is_alpha and not p.is_stop]
frecuencia = Counter(palabras)
palabras_comunes = frecuencia.most_common(5)

palabras_comunes
# Out:
# [('PON', 556), ('HUEV', 364), ('AGU', 343), ('SAL', 341), ('COC', 328)]

# %%
from nltk.stem import SnowballStemmer
import es_core_news_sm
nlp = es_core_news_sm.load()  
doc = nlp(soup.text) 

stemmer = SnowballStemmer('spanish')

palabras = [p.text.upper() for p in doc        
             if p.is_alpha and not p.is_stop]  
print("Palabras no vacías en el texto ", len(set(palabras)))   

palabras = [p.lemma_.upper() for p in doc
            if p.is_alpha and not p.is_stop]
print("Con lemas ", len(set(palabras)))   
palabras = [stemmer.stem(p.text).upper() for p in doc
              if p.is_alpha and not p.is_stop]
print("Con raíces ", len(set(palabras)))
# Out:
# Palabras no vacías en el texto  3889
# Con lemas  3428
# Con raíces  2485
