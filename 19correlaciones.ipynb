# %% [markdown]
# ## Adquisición y preprocesamiento de la información
#
# <table>
#     <tr>
#       <td>Grado en Ingeniería de Datos e Inteligencia Artificial - Facultad de Informática - UCM
#       </td>
#       <td>
#       <img src="https://biblioteca.ucm.es/data/cont/media/www/pag-88746//escudo.jpg"  width=50/>
#       </td>
#      </tr>
# </table>
#
#
#
#
# # Correlaciones
#
#
#
# ### Índice
# [Introducción](#Introducción)<br>
# [Definición](#Definición)<br>
# [Ejemplo](#Ejemplo)<br>
# [A tener en cuenta](#Dibujar)<br>
# [Representación gráfica](#Representación)<br>
# [Variables nominales](#Nominales)<br>
# [Bibliografía](#Bibliografía)<br>
#
#
# <a name="Intro"></a>
# ## Introducción
# Hasta ahora hemos considerado cada columna (cada variable) de forma independiente, viendo histogramas, outliers, etc. de forma individual. Solo hemos comparado columnas por ejemplo al hablar de los tests que nos permiten ver si tienen la misma media o si son muestras de la misma variable.
#
# Ahora vamos a estudiar la *correlación* entre las columnas por pares. La idea es ver si dos variables tienen *relación lineal*: si cuando una crece la otra en general también (correlación positiva) o si cuando una crece la otra decrece (correlación negativa).
#
# Una correlación alta indica que las variables están muy relacionadas (contienen información muy similar). Esto implica:
#
# - Si una de las variables es una variable a predecir se podrá hacer muy bien a partir de la otra (por ejemplo con regresión lineal)
#
# - Si las dos variables son características de un objeto puede que nos interese quitar una porque estamos "reforzando" o "duplicando" la misma información y eso puede tener influencia negativa en algunos métodos de aprendizaje automático.
#
# Para más detalles ver la [bibliografía](#Bibliografía)
#
# <a name="Definición"></a>
# ## Definición
#
# Para estudiar la correlación entre dos variables se suele utilizar el *coeficiente de correlación de Pearson*
#
# $$
# r = \frac{\sum(x_i - \overline{x})(y_i - \overline{y})}{\sum(x_i - \overline{x})^2(y_i - \overline{y})^2}
# $$
#
# Es un valor que está entre -1 y +1. Algunos ejemplos:
#
#
# <img src="https://www.statlect.com/images/linear-correlation-coefficient.png" />
#
# <a name="Ejemplo"></a>
# ## Ejemplo
# Por fortuna no tenemos que calcular las correlaciones; Pandas ya incluye un método [df.corr](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html)
#
# Supongamos que queremos saber qué dos comunidades tienen mayor correlación en sus datos de paro

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/parocomunidades.csv"


df = pd.read_csv(url, encoding="latin1")
df
# Out:
#      Comunidad  Periodo  Total
# 0    Andalucía     2019  20.80
# 1    Andalucía     2018  21.26
# 2    Andalucía     2017  24.43
# 3    Andalucía     2016  28.25
# 4    Andalucía     2015  29.83
# ..         ...      ...    ...
# 337    Melilla     2006   9.86
# 338    Melilla     2005  12.33
# 339    Melilla     2004  12.49
# 340    Melilla     2003  19.88
# 341    Melilla     2002   3.57
#
# [342 rows x 3 columns]

# %% [markdown]
# Vaya...las comunidades deberían ser columnas, qué hacer?

# %%
df_ancho = df.pivot(index='Periodo', columns='Comunidad', values='Total')
df_ancho
# Out:
# Comunidad  Andalucía  Aragón  Asturias  Balears. Illes  Canarias  Cantabria  \
# Periodo
# 2002           20.15    6.54     10.12            8.69     11.32      10.58
# 2003           18.35    6.53     10.14           10.01     12.04      10.42
# 2004           15.99    5.56     10.24            8.09     10.75      11.10
# 2005           13.80    5.76      9.30            7.50     10.88       8.01
# 2006           12.22    4.99      9.09            6.34     11.37       5.87
# 2007           13.96    5.12      8.00            9.35     10.89       4.72
# 2008           21.66    9.71     10.00           12.05     20.99       8.81
# 2009           26.27   13.57     14.13           19.45     26.77      12.70
# 2010           28.04   16.29     16.61           21.78     28.78      14.67
# 2011           31.01   16.80     18.84           25.49     30.33      15.92
# 2012           35.71   18.72     23.82           24.30     32.60      19.19
# 2013           36.26   20.59     22.29           22.72     33.09      19.81
# 2014           34.23   18.65     20.78           18.88     31.08      18.42
# 2015           29.83   14.60     20.33           17.02     26.75      17.71
# 2016           28.25   13.53     14.59           13.80     24.90      12.89
# 2017           24.43   11.37     14.64           12.61     22.04      13.49
# 2018           21.26   11.11     12.86           10.91     19.99       9.68
# 2019           20.80    9.93     13.14            9.91     18.78      11.18
#
# Comunidad  Castilla - La Mancha  Castilla y León  Cataluña  Ceuta  \
# Periodo
# 2002                       9.85            10.15     10.61   5.70
# 2003                       9.80            11.02      9.72   9.65
# 2004                      10.20            10.48      9.32   6.59
# 2005                       9.42             8.53      6.63  17.14
# 2006                       8.05             7.58      6.56  14.44
# 2007                       8.10             6.94      6.50  20.18
# 2008                      15.04            11.40     11.75  15.66
# 2009                      19.29            14.21     16.90  24.01
# 2010                      21.72            15.78     17.86  24.83
# 2011                      24.53            17.21     20.40  27.19
# 2012                      30.07            20.74     23.81  37.17
# 2013                      28.99            22.02     21.87  36.78
# 2014                      28.50            20.28     19.88  32.46
# 2015                      24.97            17.58     17.73  23.25
# 2016                      22.14            14.81     14.85  22.39
# 2017                      19.74            13.71     12.63  26.03
# 2018                      16.16            11.21     11.75  24.02
# 2019                      16.56            11.20     10.45  27.58
#
# Comunidad  Comunitat Valenciana  Extremadura  Galicia  La Rioja  Madrid  \
# Periodo
# 2002                      10.71        18.91    11.89      5.65    6.99
# 2003                      10.68        17.14    13.46      6.75    7.16
# 2004                      10.11        17.65    12.47      4.68    6.95
# 2005                       8.13        15.16     9.14      6.69    5.90
# 2006                       8.48        12.94     7.88      6.88    6.46
# 2007                       8.94        14.79     7.46      5.88    6.40
# 2008                      14.58        18.11     9.64      9.80   10.02
# 2009                      22.09        21.21    12.80     13.76   14.48
# 2010                      22.57        23.95    15.62     15.58   15.54
# 2011                      24.83        28.33    18.17     18.61   17.96
# 2012                      27.62        33.97    21.13     18.82   19.32
# 2013                      27.15        32.40    21.88     20.24   20.45
# 2014                      23.48        29.96    20.87     17.17   18.00
# 2015                      21.45        28.07    17.74     13.97   16.51
# 2016                      19.15        28.31    16.29     10.90   14.60
# 2017                      16.76        25.12    14.71     11.51   13.75
# 2018                      14.30        23.10    12.04     10.30   11.54
# 2019                      14.13        23.48    11.74      9.89    9.99
#
# Comunidad  Melilla  Murcia  Navarra  País Vasco
# Periodo
# 2002          3.57   11.45     5.58        9.64
# 2003         19.88   10.76     6.16        9.93
# 2004         12.49    9.96     5.14        9.26
# 2005         12.33    7.43     5.92        6.45
# 2006          9.86    7.85     4.59        6.92
# 2007         17.43    8.25     4.28        5.90
# 2008         16.17   15.29     8.13        8.48
# 2009         19.87   21.84    10.51       12.13
# 2010         24.46   24.45    11.77       10.98
# 2011         24.84   26.31    13.80       13.16
# 2012         26.41   29.37    17.17       16.60
# 2013         33.79   28.50    16.44       16.58
# 2014         29.52   27.26    14.92       16.60
# 2015         32.64   23.51    13.53       12.89
# 2016         27.38   18.58    10.01       12.27
# 2017         24.62   17.21     9.63       10.57
# 2018         23.85   15.83     9.99        9.58
# 2019         26.81   16.08     9.01        9.09

# %%
correlaciones = df_ancho.corr()
correlaciones
# Out:
# Comunidad             Andalucía    Aragón  Asturias  Balears. Illes  Canarias  \
# Comunidad
# Andalucía              1.000000  0.977459  0.953459        0.905497  0.960734
# Aragón                 0.977459  1.000000  0.949875        0.928527  0.986693
# Asturias               0.953459  0.949875  1.000000        0.878793  0.921376
# Balears. Illes         0.905497  0.928527  0.878793        1.000000  0.932623
# Canarias               0.960734  0.986693  0.921376        0.932623  1.000000
# Cantabria              0.947519  0.913081  0.961087        0.838444  0.874083
# Castilla - La Mancha   0.979060  0.980527  0.970881        0.885875  0.973624
# Castilla y León        0.981304  0.965258  0.973286        0.888571  0.934923
# Cataluña               0.979066  0.969260  0.954366        0.956256  0.958420
# Ceuta                  0.783265  0.852749  0.827492        0.752239  0.847961
# Comunitat Valenciana   0.973228  0.982463  0.942779        0.963217  0.985358
# Extremadura            0.957001  0.930858  0.950776        0.814481  0.903911
# Galicia                0.945031  0.907547  0.949470        0.825752  0.854918
# La Rioja               0.937522  0.977660  0.936812        0.953169  0.972845
# Madrid                 0.975621  0.987575  0.958349        0.926478  0.985108
# Melilla                0.776738  0.808207  0.797641        0.668523  0.802989
# Murcia                 0.978164  0.987775  0.955940        0.948640  0.984022
# Navarra                0.966533  0.978610  0.979924        0.903984  0.962621
# País Vasco             0.957361  0.917932  0.938522        0.833694  0.878033
#
# Comunidad             Cantabria  Castilla - La Mancha  Castilla y León  \
# Comunidad
# Andalucía              0.947519              0.979060         0.981304
# Aragón                 0.913081              0.980527         0.965258
# Asturias               0.961087              0.970881         0.973286
# Balears. Illes         0.838444              0.885875         0.888571
# Canarias               0.874083              0.973624         0.934923
# Cantabria              1.000000              0.934094         0.976691
# Castilla - La Mancha   0.934094              1.000000         0.970521
# Castilla y León        0.976691              0.970521         1.000000
# Cataluña               0.937449              0.957444         0.970011
# Ceuta                  0.694599              0.856901         0.772598
# Comunitat Valenciana   0.910388              0.967978         0.955529
# Extremadura            0.928329              0.966359         0.940433
# Galicia                0.976181              0.924255         0.973063
# La Rioja               0.874063              0.949840         0.933914
# Madrid                 0.917857              0.986499         0.963116
# Melilla                0.741418              0.838195         0.778747
# Murcia                 0.925189              0.975417         0.962545
# Navarra                0.930578              0.982684         0.967550
# País Vasco             0.955500              0.927718         0.973828
#
# Comunidad             Cataluña     Ceuta  Comunitat Valenciana  Extremadura  \
# Comunidad
# Andalucía             0.979066  0.783265              0.973228     0.957001
# Aragón                0.969260  0.852749              0.982463     0.930858
# Asturias              0.954366  0.827492              0.942779     0.950776
# Balears. Illes        0.956256  0.752239              0.963217     0.814481
# Canarias              0.958420  0.847961              0.985358     0.903911
# Cantabria             0.937449  0.694599              0.910388     0.928329
# Castilla - La Mancha  0.957444  0.856901              0.967978     0.966359
# Castilla y León       0.970011  0.772598              0.955529     0.940433
# Cataluña              1.000000  0.760646              0.987131     0.917137
# Ceuta                 0.760646  1.000000              0.816202     0.816473
# Comunitat Valenciana  0.987131  0.816202              1.000000     0.913181
# Extremadura           0.917137  0.816473              0.913181     1.000000
# Galicia               0.925310  0.697810              0.892151     0.939653
# La Rioja              0.953881  0.873138              0.972397     0.880141
# Madrid                0.968434  0.846829              0.985907     0.942233
# Melilla               0.713820  0.824894              0.766932     0.824797
# Murcia                0.985814  0.821092              0.991608     0.923606
# Navarra               0.964614  0.866128              0.964389     0.947922
# País Vasco            0.945149  0.711364              0.913549     0.921614
#
# Comunidad              Galicia  La Rioja    Madrid   Melilla    Murcia  \
# Comunidad
# Andalucía             0.945031  0.937522  0.975621  0.776738  0.978164
# Aragón                0.907547  0.977660  0.987575  0.808207  0.987775
# Asturias              0.949470  0.936812  0.958349  0.797641  0.955940
# Balears. Illes        0.825752  0.953169  0.926478  0.668523  0.948640
# Canarias              0.854918  0.972845  0.985108  0.802989  0.984022
# Cantabria             0.976181  0.874063  0.917857  0.741418  0.925189
# Castilla - La Mancha  0.924255  0.949840  0.986499  0.838195  0.975417
# Castilla y León       0.973063  0.933914  0.963116  0.778747  0.962545
# Cataluña              0.925310  0.953881  0.968434  0.713820  0.985814
# Ceuta                 0.697810  0.873138  0.846829  0.824894  0.821092
# Comunitat Valenciana  0.892151  0.972397  0.985907  0.766932  0.991608
# Extremadura           0.939653  0.880141  0.942233  0.824797  0.923606
# Galicia               1.000000  0.862507  0.910411  0.751917  0.903330
# La Rioja              0.862507  1.000000  0.971284  0.772258  0.973005
# Madrid                0.910411  0.971284  1.000000  0.822407  0.982737
# Melilla               0.751917  0.772258  0.822407  1.000000  0.780685
# Murcia                0.903330  0.973005  0.982737  0.780685  1.000000
# Navarra               0.917341  0.968343  0.974842  0.816566  0.976773
# País Vasco            0.971119  0.873704  0.916321  0.707003  0.920879
#
# Comunidad              Navarra  País Vasco
# Comunidad
# Andalucía             0.966533    0.957361
# Aragón                0.978610    0.917932
# Asturias              0.979924    0.938522
# Balears. Illes        0.903984    0.833694
# Canarias              0.962621    0.878033
# Cantabria             0.930578    0.955500
# Castilla - La Mancha  0.982684    0.927718
# Castilla y León       0.967550    0.973828
# Cataluña              0.964614    0.945149
# Ceuta                 0.866128    0.711364
# Comunitat Valenciana  0.964389    0.913549
# Extremadura           0.947922    0.921614
# Galicia               0.917341    0.971119
# La Rioja              0.968343    0.873704
# Madrid                0.974842    0.916321
# Melilla               0.816566    0.707003
# Murcia                0.976773    0.920879
# Navarra               1.000000    0.923749
# País Vasco            0.923749    1.000000

# %% [markdown]
# ¿Entre qué dos comunidades diferentes hay mayor correlación? ¿y menos?

# %%
# Out:
# Comunidad             Comunitat Valenciana    Murcia
# Comunidad
# Comunitat Valenciana                   NaN  0.991608
# Murcia                            0.991608       NaN

# %% [markdown]
# <a name="Dibujar"></a>
# ## A tener en cuenta
#
# En el caso de las correlaciones (como en todos) no hay que precipitarse en sacar conclusiones. En particular:
#
# - Que haya correlación no significa que los valores sean "parecidos" sino que se mueven a la vez (en la misma dirección o contraria)
#
# - Correlación no implica causalidad, en ocasiones puede haber otra variable que esté "moviendo" las dos variables correlaciones
#
# - Ya hemos visto que puede haber correlación de otros tipos que no está detectada por nuestro método (la correlación de Pearson); pero es que también sucede al revés, podemos encontrar correlación y que no signifique lo que creemos:
#
# <img src="https://github.com/RafaelCaballero/tdm/raw/master/images/Situations-in-which-linear-correlation-should-not-be-used-a-two-variables-have-a.png" />

# %% [markdown]
# Vamos a mostrar los datos de las dos comunidades más correlacionadas a ver si es uno de estos casos:

# %%
from matplotlib import pyplot as plt
fig, ax = plt.subplots(figsize=(10, 6))

ax.scatter(df_ancho["Comunitat Valenciana"],df_ancho["Murcia"])
ax.plot([0,30],[0,30],color="red")
plt.show()

# %%
# otra forma 
fig, ax = plt.subplots(figsize=(10, 6))
cs = ["Comunitat Valenciana","Murcia"]
for c in cs:
    df_ancho[c].plot(ax=ax,label=c)
ax.legend()    
plt.show()

# %% [markdown]
# <a name="Representación"></a>
# ## Representación
#
# La tabla de correlaciones se puede mostrar de forma más informativa, veamos cómo:

# %%
correlaciones.style.background_gradient()
# Out:
# <style type="text/css">
# #T_24e17_row0_col0, #T_24e17_row1_col1, #T_24e17_row2_col2, #T_24e17_row3_col3, #T_24e17_row4_col4, #T_24e17_row5_col5, #T_24e17_row6_col6, #T_24e17_row7_col7, #T_24e17_row8_col8, #T_24e17_row9_col9, #T_24e17_row10_col10, #T_24e17_row11_col11, #T_24e17_row12_col12, #T_24e17_row13_col13, #T_24e17_row14_col14, #T_24e17_row15_col15, #T_24e17_row16_col16, #T_24e17_row17_col17, #T_24e17_row18_col18 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_24e17_row0_col1, #T_24e17_row1_col6, #T_24e17_row2_col7, #T_24e17_row4_col13, #T_24e17_row10_col0, #T_24e17_row12_col7, #T_24e17_row13_col10, #T_24e17_row16_col13 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_24e17_row0_col2, #T_24e17_row17_col5 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_24e17_row0_col3, #T_24e17_row1_col5, #T_24e17_row10_col2, #T_24e17_row11_col17 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_24e17_row0_col4, #T_24e17_row2_col16, #T_24e17_row8_col13, #T_24e17_row11_col12 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_24e17_row0_col5, #T_24e17_row7_col16 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_24e17_row0_col6, #T_24e17_row6_col7, #T_24e17_row7_col2, #T_24e17_row8_col3, #T_24e17_row8_col7 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_24e17_row0_col7, #T_24e17_row4_col14, #T_24e17_row7_col0, #T_24e17_row14_col6 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_24e17_row0_col8, #T_24e17_row4_col16 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_24e17_row0_col9 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_24e17_row0_col10, #T_24e17_row1_col17, #T_24e17_row13_col1, #T_24e17_row18_col7 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_24e17_row0_col11, #T_24e17_row3_col16 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_24e17_row0_col12, #T_24e17_row0_col17, #T_24e17_row2_col6, #T_24e17_row6_col11, #T_24e17_row7_col1, #T_24e17_row7_col6 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_24e17_row0_col13, #T_24e17_row17_col12 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_24e17_row0_col14, #T_24e17_row6_col10, #T_24e17_row13_col4, #T_24e17_row14_col17, #T_24e17_row17_col13 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_24e17_row0_col15 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_24e17_row0_col16, #T_24e17_row1_col0, #T_24e17_row1_col13, #T_24e17_row6_col1, #T_24e17_row12_col18, #T_24e17_row16_col0, #T_24e17_row17_col2 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_24e17_row0_col18, #T_24e17_row4_col8, #T_24e17_row18_col5 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_24e17_row1_col2, #T_24e17_row6_col18, #T_24e17_row8_col12, #T_24e17_row12_col0, #T_24e17_row12_col2 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_24e17_row1_col3, #T_24e17_row5_col8, #T_24e17_row6_col5, #T_24e17_row16_col2 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_24e17_row1_col4, #T_24e17_row1_col14, #T_24e17_row4_col1 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_24e17_row1_col7, #T_24e17_row3_col8, #T_24e17_row16_col3, #T_24e17_row17_col10 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_24e17_row1_col8, #T_24e17_row14_col0, #T_24e17_row17_col6, #T_24e17_row17_col16 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_24e17_row1_col9, #T_24e17_row12_col1 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_24e17_row1_col10, #T_24e17_row6_col14, #T_24e17_row7_col5, #T_24e17_row10_col4, #T_24e17_row12_col5, #T_24e17_row14_col4 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_24e17_row1_col11, #T_24e17_row3_col1, #T_24e17_row11_col10 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_24e17_row1_col12 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_24e17_row1_col15 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_24e17_row1_col16, #T_24e17_row8_col10 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_24e17_row1_col18, #T_24e17_row2_col13, #T_24e17_row13_col0, #T_24e17_row17_col11 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_24e17_row2_col0, #T_24e17_row2_col18, #T_24e17_row7_col14, #T_24e17_row11_col6 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_24e17_row2_col1, #T_24e17_row12_col8, #T_24e17_row17_col18 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_24e17_row2_col3 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_24e17_row2_col4 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_24e17_row2_col5, #T_24e17_row14_col13, #T_24e17_row16_col17 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_24e17_row2_col8, #T_24e17_row3_col10 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_24e17_row2_col9 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_24e17_row2_col10, #T_24e17_row11_col2, #T_24e17_row16_col5 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_24e17_row2_col11, #T_24e17_row8_col6, #T_24e17_row11_col7 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_24e17_row2_col12, #T_24e17_row16_col7 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_24e17_row2_col14, #T_24e17_row5_col0, #T_24e17_row11_col5 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_24e17_row2_col15 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_24e17_row2_col17, #T_24e17_row6_col16, #T_24e17_row10_col3, #T_24e17_row14_col8, #T_24e17_row17_col1 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_24e17_row3_col0, #T_24e17_row18_col11 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_24e17_row3_col2, #T_24e17_row11_col9 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_24e17_row3_col4, #T_24e17_row5_col16 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_24e17_row3_col5, #T_24e17_row9_col15, #T_24e17_row11_col15 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_24e17_row3_col6 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_24e17_row3_col7 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_24e17_row3_col9 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_24e17_row3_col11, #T_24e17_row3_col15, #T_24e17_row5_col9, #T_24e17_row9_col5, #T_24e17_row9_col7, #T_24e17_row9_col12, #T_24e17_row15_col0, #T_24e17_row15_col1, #T_24e17_row15_col2, #T_24e17_row15_col3, #T_24e17_row15_col4, #T_24e17_row15_col6, #T_24e17_row15_col8, #T_24e17_row15_col10, #T_24e17_row15_col13, #T_24e17_row15_col14, #T_24e17_row15_col16, #T_24e17_row15_col17, #T_24e17_row15_col18 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_24e17_row3_col12 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_24e17_row3_col13, #T_24e17_row4_col3, #T_24e17_row4_col17, #T_24e17_row8_col5, #T_24e17_row14_col2 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_24e17_row3_col14, #T_24e17_row4_col5, #T_24e17_row13_col5, #T_24e17_row16_col11 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_24e17_row3_col17, #T_24e17_row11_col13, #T_24e17_row12_col3 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_24e17_row3_col18 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_24e17_row4_col0, #T_24e17_row7_col17, #T_24e17_row8_col14 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_24e17_row4_col2 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_24e17_row4_col6, #T_24e17_row8_col1, #T_24e17_row13_col8, #T_24e17_row13_col14, #T_24e17_row14_col7 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_24e17_row4_col7, #T_24e17_row14_col18 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_24e17_row4_col9 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_24e17_row4_col10, #T_24e17_row8_col16, #T_24e17_row14_col1, #T_24e17_row16_col1 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_24e17_row4_col11 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_24e17_row4_col12 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_24e17_row4_col15 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_24e17_row4_col18, #T_24e17_row13_col9, #T_24e17_row18_col17 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_24e17_row5_col1, #T_24e17_row13_col12 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_24e17_row5_col2, #

# %% [markdown]
# Con seaborn

# %%
import seaborn as sns
plt.figure(figsize=(11,8))
sns.heatmap(correlaciones, cmap="Greens",annot=True)
plt.show()

# %% [markdown]
# Hay otras posibilidades más complejas que por ejemplo crean grupos (clústers) de atributos correlacionados

# %%
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.clustermap(df_ancho.corr(), 
                   method = 'complete', 
                   cmap   = 'RdBu', 
                   annot  = True, 
                   annot_kws = {'size': 8})

# %% [markdown]
# Si se quieren ver las gráficas una a una:

# %%
sns.pairplot(df_ancho.corr())

# %% [markdown]
# <a name="Nominales"></a>
# ## Variables nominales
#
# Si una variable es nominal/ordinal y la otra intervalo/ratio lo que se haría es convertir la variable nominal a números (ya veremos como) y usar correlación normal.
#
# En el caso de dos variables "categóricas" (nominales u ordinales) podemos utilizar el test de la  $\mathcal{X}^2$ (chi-squared en inglés). Al ser un test solo dice si hay correlación o no, no cuánta (aunque se puede mirar el estadístico). Por eso es mejor hablar de *asociación* dejando el término *correlación* para variables tipo ratio.
#
# En este test $H_0$ = No hay correlación entre las variables.
#
# Por tantp, si $p<0.05$ rechazaremos $H_0$ y diremos que sí hay correlación entre las variables, en otro caso no podemos asegurar que no haya correlación.
#
# Ejemplo:

# %%
url = "https://github.com/RafaelCaballero/tdm/raw/master/datos/Ventas%20Videojuegos.xlsx"
df = pd.read_excel(url)
df
# Out:
#                                                   Nombre Plataforma   Año  \
# 0                                             Wii Sports        Wii  2006
# 1                                      Super Mario Bros.        NES  1985
# 2                                         Mario Kart Wii        Wii  2008
# 3                                      Wii Sports Resort        Wii  2009
# 4                               Pokemon Red/Pokemon Blue         GB  1996
# ...                                                  ...        ...   ...
# 16321                      Farming 2017 - The Simulation        PS4  2016
# 16322                                  Rugby Challenge 3       XOne  2016
# 16323  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...        PSV  2016
# 16324   Phantasy Star Online 2 Episode 4: Deluxe Package        PSV  2017
# 16325                   Brothers Conflict: Precious Baby        PSV  2017
#
#              Genero             Editorial  Ventas NA  Ventas EU  Ventas JP  \
# 0            Sports              Nintendo      41.50      29.02       3.77
# 1          Platform              Nintendo      29.08       3.58       6.81
# 2            Racing              Nintendo      15.85      12.88       3.79
# 3            Sports              Nintendo      15.75      11.01       3.28
# 4      Role-Playing              Nintendo      11.27       8.89      10.22
# ...             ...                   ...        ...        ...        ...
# 16321    Simulation     UIG Entertainment       0.00       0.01       0.00
# 16322        Sports  Alternative Software       0.00       0.01       0.00
# 16323        Action       dramatic create       0.00       0.00       0.01
# 16324  Role-Playing                  Sega       0.00       0.00       0.01
# 16325        Action          Idea Factory       0.00       0.00       0.01
#
#        Ventas Otros  Ventas Global
# 0              8.46          82.74
# 1              0.77          40.24
# 2              3.31          35.82
# 3              2.96          33.00
# 4              1.00          31.37
# ...             ...            ...
# 16321          0.00           0.01
# 16322          0.00           0.01
# 16323          0.00           0.01
# 16324          0.00           0.01
# 16325          0.00           0.01
#
# [16326 rows x 10 columns]

# %%
df2 = df[df.Plataforma.isin(df.Plataforma.value_counts()[0:5].index)]

# %% [markdown]
# ¿Están relacionados el género y la plataforma?
#
# El primer paso es obtener la *tabla de contingencias* de las dos variables

# %%
contingencias=pd.crosstab(index=df2.Plataforma,columns=df2.Genero)
contingencias
# Out:
# Genero      Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Plataforma
# DS             336        238        36   389        90     236      66
# PS2            345        196       146   218       101      18     212
# PS3            373         72        76   121        36       2      90
# Wii            230         83        41   272        57      54      92
# X360           318         47        65   122        24       6     102
#
# Genero      Role-Playing  Shooter  Simulation  Sports  Strategy
# Plataforma
# DS                   196       42         279     146        78
# PS2                  183      158          89     391        70
# PS3                  117      155          30     210        22
# Wii                   35       61          84     256        25
# X360                  76      197          36     215        27

# %% [markdown]
# Es sobre esta tabla sobre la que hacemos el test:

# %%
from scipy.stats import chi2_contingency
 
# este es el test
ChiSqResult = chi2_contingency(contingencias)
ChiSqResult
# Out:
# Chi2ContingencyResult(statistic=1584.9838847918977, pvalue=1.0169947057435031e-303, dof=44, expected_freq=array([[422.28783383, 167.64985163,  95.95054402, 295.75964392,
#          81.18892186,  83.29772502, 148.14342235, 160.00544016,
#         161.58704253, 136.54500495, 321.0652819 ,  58.51928783],
#        [421.29747774, 167.25667656,  95.72551929, 295.06602374,
#          80.99851632,  83.10237389, 147.79599407, 159.63019288,
#         161.20808605, 136.22477745, 320.31231454,  58.38204748],
#        [258.28486647, 102.54005935,  58.68644906, 180.89614243,
#          49.65776459,  50.94757666,  90.60929773,  97.8644906 ,
#          98.83184965,  83.51533136, 196.37388724,  35.79228487],
#        [255.51186944, 101.43916914,  58.05637982, 178.95400593,
#          49.12462908,  50.40059347,  89.63649852,  96.81379822,
#          97.77077151,  82.61869436, 194.26557864,  35.40801187],
#        [244.61795252,  97.11424332,  55.58110781, 171.32418398,
#          47.03016815,  48.25173096,  85.81478734,  92.68607814,
#          93.60225025,  79.09619189, 185.98293769,  33.89836795]]))

# %%
p = ChiSqResult[1]
p
# Out:
# 1.0169947057435031e-303

# %% [markdown]
# Por tanto rechazamos la hipótesis nula; sí hay correlación entre las variables.
#
# Otro ejemplo tomado de [aquí](https://thinkingneuron.com/how-to-measure-the-correlation-between-two-categorical-variables-in-python/)

# %%
import pandas as pd
ColumnNames=['AGE','GENDER' ,'SALARY', 'APPROVE_LOAN']
DataValues=[ [28, 'M', 610000, 'Yes'],
             [42, 'M',140000, 'No'],
             [29, 'F',420000, 'No'],
             [30, 'M',420000, 'No'],
             [27, 'M',420000, 'No'],
             [34, 'F',190000, 'No'],
             [24, 'M',330000, 'Yes'],
             [34, 'M',160000, 'Yes'],
             [25, 'F',300000, 'Yes'],
             [34, 'M',450000, 'Yes'],
             [30, 'F',140000, 'Yes'],
             [33, 'M',600000, 'Yes'],
             [22, 'M',400000, 'Yes'],
             [25, 'F',490000, 'Yes'],
             [32, 'M',120000, 'Yes'],
             [29, 'F',360000, 'Yes'],
             [30, 'M',480000, 'Yes'],
             [29, 'F',460000, 'Yes'],
             [32, 'M',470000, 'Yes'],
             [28, 'M',400000, 'Yes']]
LoanData=pd.DataFrame(data=DataValues,columns=ColumnNames)
LoanData
# Out:
#     AGE GENDER  SALARY APPROVE_LOAN
# 0    28      M  610000          Yes
# 1    42      M  140000           No
# 2    29      F  420000           No
# 3    30      M  420000           No
# 4    27      M  420000           No
# 5    34      F  190000           No
# 6    24      M  330000          Yes
# 7    34      M  160000          Yes
# 8    25      F  300000          Yes
# 9    34      M  450000          Yes
# 10   30      F  140000          Yes
# 11   33      M  600000          Yes
# 12   22      M  400000          Yes
# 13   25      F  490000          Yes
# 14   32      M  120000          Yes
# 15   29      F  360000          Yes
# 16   30      M  480000          Yes
# 17   29      F  460000          Yes
# 18   32      M  470000          Yes
# 19   28      M  400000          Yes

# %% [markdown]
# ¿Hay relación entre el sexo y que concedan el préstamo?

# %%
contingencias=pd.crosstab(index=LoanData.GENDER,columns=LoanData.APPROVE_LOAN)
ChiSqResult = chi2_contingency(contingencias)
ChiSqResult
# Out:
# Chi2ContingencyResult(statistic=0.0, pvalue=1.0, dof=1, expected_freq=array([[1.75, 5.25],
#        [3.25, 9.75]]))

# %% [markdown]
# Por tanto no podemos descartar que no haya correlación. Veamos un último caso:

# %%
df2 = LoanData.copy()
df2["GENDER"] = LoanData.apply(lambda x: "M" if x["APPROVE_LOAN"]=="Yes" else "F",axis=1)
contingencias=pd.crosstab(index=df2.GENDER,columns=df2.APPROVE_LOAN)
ChiSqResult = chi2_contingency(contingencias)
ChiSqResult
# Out:
# Chi2ContingencyResult(statistic=15.02222222222222, pvalue=0.00010625262134433874, dof=1, expected_freq=array([[ 1.25,  3.75],
#        [ 3.75, 11.25]]))

# %% [markdown]
#  LA desventaja es que no vemos entre qué valores es la asociación, solo que existe.

# %% [markdown]
# <a name="Bibliografía"></a>
# ## Bibliografía
#
#
# Una explicación matemática sencilla de donde he tomado alguna imagen:
# *Taboga, Marco (2021). "Linear correlation", Lectures on probability theory and mathematical statistics. Kindle Direct Publishing. Online appendix.* https://www.statlect.com/fundamentals-of-probability/linear-correlation.
#
#
#
# Sobre correlación y causalidad:
#  [Why correlation does not imply causation?](https://medium.com/@seema.singh/why-correlation-does-not-imply-causation-5b99790df07e)
#
#
#
# Descripción de los distintos tipos de tests para variables categóricas y numéricas:
# *Data Preprocessing in Data Mining*. Intelligent Systems Reference Library №72. Salvador García, Julián Luengo, Francisco Herrera. Spring, 2015.  Ver en particular: *3.2.1 Finding Redundant Attributes*
