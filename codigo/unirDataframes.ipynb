# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelCaballero/APD/blob/main/codigo/unirDataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table>
# <tr>
# <td><img src="https://raw.githubusercontent.com/RafaelCaballero/APD/refs/heads/main/img/logoAPD.png" width="150"></td>
# <td><table><tr><td><h1>Pandas - Unir Dataframes</h1></td></tr>
#            <tr><td><h3>Rafael Caballero Roldán</h3></td></tr></table></td>
# <td><img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTsPjCdm67xYS9AM7-dXQ46O23vaexAhnVJaQ&s" width="105"></td>
# </tr>
# </table>
#
# ### Combinando dataframes
# Veamos en este Notebook cómo se combinan y agregan dataframes en uno solo
#
# ### Índice
# [Concatenar](#Concatenar)<br>
# [Merge](#Merge)<br>

# %% [markdown]
# El siguiente código es para mostrar una dataframe al lado de otro, ejecutarlo pero no hace falta entenderlo

# %%
from IPython.display import display, HTML
from IPython.display import display_html
from IPython.display import Markdown

def display_side_by_side(*args,title=""):
    print(title)
    html_str = ''
    for df in args:
        html_str += '&nbsp;&nbsp;&nbsp;'+df.to_html()
    display_html(
        html_str.replace('table','table style="display:inline"'),
        raw=True)

# %% [markdown]
# <a name="Concatenar"></a>
# ### Concatenar
#
# La forma más fácil, y a veces la más rápida y útil, de combinar dataframes, ya sea "pegándolo" debajo o al lado con `pd.concat`
#
# <img src = "https://miro.medium.com/max/1050/1*0wu6DunCzPC4o9FIyRTW4w.png">

# %%
import IPython.display as display
import pandas as pd
from pandas import DataFrame
from random import sample


df1 = DataFrame({'clave': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],
                 'data': range(7),
                 'otro': sample(range(10, 30), 7)})

df2 = DataFrame({'clave': ['e', 'e', 'e', 'e'],
                 'data': range(4),
                 'otro': sample(range(10, 30), 4)})

display_side_by_side(df1,df2)
# Out:
# &nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data</th>
#       <th>otro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>b</td>
#       <td>0</td>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>1</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>a</td>
#       <td>2</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>c</td>
#       <td>3</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>a</td>
#       <td>4</td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>a</td>
#       <td>5</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>b</td>
#       <td>6</td>
#       <td>28</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data</th>
#       <th>otro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>e</td>
#       <td>0</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>e</td>
#       <td>1</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>e</td>
#       <td>2</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>e</td>
#       <td>3</td>
#       <td>14</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
df3 = pd.concat([df1,df2])
df3
# Out:
#   clave  data  otro
# 0     b     0    27
# 1     b     1    11
# 2     a     2    14
# 3     c     3    13
# 4     a     4    29
# 5     a     5    16
# 6     b     6    28
# 0     e     0    11
# 1     e     1    28
# 2     e     2    19
# 3     e     3    14

# %% [markdown]
# Si nos incomoda que el índice no sea consecutivo:

# %%
df3 = df3.reset_index(drop=True)
df3
# Out:
#    clave  data  otro
# 0      b     0    27
# 1      b     1    11
# 2      a     2    14
# 3      c     3    13
# 4      a     4    29
# 5      a     5    16
# 6      b     6    28
# 7      e     0    11
# 8      e     1    28
# 9      e     2    19
# 10     e     3    14

# %% [markdown]
# Sin embargo, hay veces que es útil usar el índice (si no tiene ya otro cometido) para "apuntar" el origen de cada fila

# %%
import IPython.display as display
import pandas as pd

df1 = DataFrame({'clave': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],
                 'data': range(7),
                 'otro': sample(range(10, 30), 7)})

df2 = DataFrame({'clave': ['e', 'e', 'e', 'e'],
                 'data': range(4),
                 'otro': sample(range(10, 30), 4)})

df1.index = ["A"]*len(df1)
df2.index = ["B"]*len(df2)
display_side_by_side(df1,df2,pd.concat([df1,df2]),title="pd.concat([df1,df2])")
# Out:
# pd.concat([df1,df2])
# &nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data</th>
#       <th>otro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>0</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>1</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>2</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>c</td>
#       <td>3</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>4</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>5</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>6</td>
#       <td>22</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data</th>
#       <th>otro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>0</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>1</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>2</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>3</td>
#       <td>23</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data</th>
#       <th>otro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>0</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>1</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>2</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>c</td>
#       <td>3</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>4</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>5</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>6</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>0</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>1</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>2</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>3</td>
#       <td>23</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# **Ojo** porque `concat` no es tan *tonto* como parece; no se limita a pegar debajo sino que alinea por nombres de columna

# %%
import IPython.display as display
import pandas as pd

df1 = DataFrame({'clave': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],
                 'data': range(7),
                 'otro': sample(range(10, 30), 7)})

df2 = DataFrame({'clave': ['e', 'e', 'e', 'e'],
                 'otro': sample(range(10, 30), 4),
                 'data': range(4) } )

df1.index = ["A"]*len(df1)
df2.index = ["B"]*len(df2)
display_side_by_side(df1,df2,pd.concat([df1,df2]), title="pd.concat([df1,df2])")
# Out:
# pd.concat([df1,df2])
# &nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data</th>
#       <th>otro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>0</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>1</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>2</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>c</td>
#       <td>3</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>4</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>5</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>6</td>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>otro</th>
#       <th>data</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>22</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>14</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>11</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>10</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data</th>
#       <th>otro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>0</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>1</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>2</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>c</td>
#       <td>3</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>4</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>5</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>6</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>0</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>1</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>2</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>3</td>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# Con el parámetro axis (que por defecto vale 0) podemos hacer que en lugar de por filas concatene por columnas. En este caso lo lógico es que ambos dataframes tengan el mismo número de filas

# %%
import numpy as np
filas = 5
df1 = DataFrame({'A': np.random.randint(1,10,filas) ,
                 'B': np.random.randint(1,10,filas),
                 'C': np.random.randint(1,10,filas)})

df2 = DataFrame({'D': np.random.randint(2000,3000,filas),
                 'E': np.random.randint(2000,3000,filas)})
display_side_by_side(df1,df2, pd.concat([df1,df2],axis=1),
                     title="pd.concat([df1,df2],axis=1)")
# Out:
# pd.concat([df1,df2],axis=1)
# &nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>7</td>
#       <td>6</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>9</td>
#       <td>6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4</td>
#       <td>8</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>6</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>6</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2329</td>
#       <td>2971</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2841</td>
#       <td>2885</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2578</td>
#       <td>2286</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2233</td>
#       <td>2404</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2684</td>
#       <td>2208</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>7</td>
#       <td>6</td>
#       <td>5</td>
#       <td>2329</td>
#       <td>2971</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>9</td>
#       <td>6</td>
#       <td>1</td>
#       <td>2841</td>
#       <td>2885</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4</td>
#       <td>8</td>
#       <td>1</td>
#       <td>2578</td>
#       <td>2286</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>6</td>
#       <td>8</td>
#       <td>2233</td>
#       <td>2404</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>6</td>
#       <td>4</td>
#       <td>2684</td>
#       <td>2208</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# Un aspecto muy importante: igual que al concatenar utiliza los nombres de columna aquí va a usar los números de fila

# %%
df2.index=[0,1,2,4,7]
display_side_by_side(df1,df2, pd.concat([df1,df2],axis=1),
                     title="pd.concat([df1,df2],axis=1)")
# Out:
# pd.concat([df1,df2],axis=1)
# &nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>7</td>
#       <td>6</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>9</td>
#       <td>6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4</td>
#       <td>8</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>6</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>6</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2329</td>
#       <td>2971</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2841</td>
#       <td>2885</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2578</td>
#       <td>2286</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2233</td>
#       <td>2404</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2684</td>
#       <td>2208</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>7.0</td>
#       <td>6.0</td>
#       <td>5.0</td>
#       <td>2329.0</td>
#       <td>2971.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>9.0</td>
#       <td>6.0</td>
#       <td>1.0</td>
#       <td>2841.0</td>
#       <td>2885.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.0</td>
#       <td>8.0</td>
#       <td>1.0</td>
#       <td>2578.0</td>
#       <td>2286.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.0</td>
#       <td>6.0</td>
#       <td>8.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.0</td>
#       <td>6.0</td>
#       <td>4.0</td>
#       <td>2233.0</td>
#       <td>2404.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2684.0</td>
#       <td>2208.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# Si el número de filas o columnas no encaja, `concat` añadirá valores vacío para completar

# %%
import numpy as np
filas = 5
df1 = DataFrame({'A': np.random.randint(1,10,filas) ,
                 'B': np.random.randint(1,10,filas),
                 'C': np.random.randint(1,10,filas)})

df2 = DataFrame({'D': np.random.randint(2000,3000,filas-1),
                 'E': np.random.randint(2000,3000,filas-1)})
display_side_by_side(df1,df2, pd.concat([df1,df2],axis=1),title="pd.concat([df1,df2],axis=1)")

display_side_by_side(df1,df2, pd.concat([df1,df2],axis=0),title="pd.concat([df1,df2],axis=0)")
# Out:
# pd.concat([df1,df2],axis=1)
# &nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>9</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>5</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>9</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>5</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2622</td>
#       <td>2617</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2938</td>
#       <td>2271</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2310</td>
#       <td>2331</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2609</td>
#       <td>2054</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>9</td>
#       <td>2</td>
#       <td>3</td>
#       <td>2622.0</td>
#       <td>2617.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>5</td>
#       <td>1</td>
#       <td>2938.0</td>
#       <td>2271.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>9</td>
#       <td>9</td>
#       <td>2310.0</td>
#       <td>2331.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>5</td>
#       <td>6</td>
#       <td>2609.0</td>
#       <td>2054.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>7</td>
#       <td>8</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table style="display:inline">
# pd.concat([df1,df2],axis=0)
# &nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>9</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>5</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>9</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>5</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2622</td>
#       <td>2617</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2938</td>
#       <td>2271</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2310</td>
#       <td>2331</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2609</td>
#       <td>2054</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>9.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3.0</td>
#       <td>5.0</td>
#       <td>1.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3.0</td>
#       <td>9.0</td>
#       <td>9.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.0</td>
#       <td>5.0</td>
#       <td>6.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2.0</td>
#       <td>7.0</td>
#       <td>8.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2622.0</td>
#       <td>2617.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2938.0</td>
#       <td>2271.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2310.0</td>
#       <td>2331.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2609.0</td>
#       <td>2054.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# **Ejercicio**  El siguiente código descarga tres ficheros con datos diarios de metereología en Madrid y sus metadatos a una carpeta ./raw

# %%
import requests
from pathlib import Path
path = Path.cwd()
pathraw = Path(path,"raw")

pathraw.mkdir(exist_ok=True)

datos = [
         "https://datos.madrid.es/egob/catalogo/300351-0-meteorologicos-diarios.csv",
         "https://datos.madrid.es/egob/catalogo/300351-3-meteorologicos-diarios.csv",
          "https://datos.madrid.es/egob/catalogo/300351-9-meteorologicos-diarios.csv"
          ]
locales = []
for url in datos:
    nombre = Path(url).name
    camino = Path(pathraw,nombre)
    r = requests.get(url, allow_redirects=True) # el fichero queda en la variable r
    if r.status_code==200:
        with open(camino, 'wb') as f:
            f.write(r.content) # ahora lo grabamos localmente
        print("Grabado,",camino)
        locales.append(camino)
    else:
        print("Error descargando ",url,r.status_code)
# Out:
# Grabado, d:\docencia\2526\apd\codigo\raw\300351-0-meteorologicos-diarios.csv
# Grabado, d:\docencia\2526\apd\codigo\raw\300351-3-meteorologicos-diarios.csv
# Grabado, d:\docencia\2526\apd\codigo\raw\300351-9-meteorologicos-diarios.csv

# %%
locales
# Out:
# [WindowsPath('d:/docencia/2526/apd/codigo/raw/300351-0-meteorologicos-diarios.csv'),
#  WindowsPath('d:/docencia/2526/apd/codigo/raw/300351-3-meteorologicos-diarios.csv'),
#  WindowsPath('d:/docencia/2526/apd/codigo/raw/300351-9-meteorologicos-diarios.csv')]

# %% [markdown]
# Añadir código para combinar los ficheros que empiezan por nombre 300351 y tienen como extensión csv de la carpeta raw en uno solo sabiendo que tienen las mismas columnas

# %% [markdown]
# 1.- Obtenemos los paths a estos ficheros (realmente  ya lo tenemos en la vairable `locales`)

# %%
csvs = list(pathraw.glob("300351*.csv"))
csvs
# Out:
# [WindowsPath('d:/docencia/2526/apd/codigo/raw/300351-0-meteorologicos-diarios.csv'),
#  WindowsPath('d:/docencia/2526/apd/codigo/raw/300351-3-meteorologicos-diarios.csv'),
#  WindowsPath('d:/docencia/2526/apd/codigo/raw/300351-9-meteorologicos-diarios.csv')]

# %% [markdown]
# 2.- Los leemos todos, generando una lita de dataframes

# %%
dfs = [pd.read_csv(nombre,sep=";")  for nombre in csvs]

# %% [markdown]
# 3.- Los juntamos uno debajo de otro

# %%
df = pd.concat(dfs)
df
# Out:
#      PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  PUNTO_MUESTREO   ANO  MES  \
# 0           28         79       102        81  28079102_81_98  2019    1
# 1           28         79       102        81  28079102_81_98  2019    2
# 2           28         79       102        81  28079102_81_98  2019    3
# 3           28         79       102        81  28079102_81_98  2019    4
# 4           28         79       102        81  28079102_81_98  2019    5
# ..         ...        ...       ...       ...             ...   ...  ...
# 928         28         79        59        89  28079059_89_98  2022    8
# 929         28         79        59        89  28079059_89_98  2022    9
# 930         28         79        59        89  28079059_89_98  2022   10
# 931         28         79        59        89  28079059_89_98  2022   11
# 932         28         79        59        89  28079059_89_98  2022   12
#
#       D01 V01   D02  ...   D27  V27   D28  V28   D29  V29   D30  V30   D31  \
# 0    0.66   V  1.16  ...  2.57    V  2.93    V  3.23    V  3.18    V  4.72
# 1    4.32   V  2.98  ...  1.36    V  0.97    V  0.00    N  0.00    N  0.00
# 2    1.57   V  1.13  ...  1.48    V  1.69    V  2.89    V  1.99    V  1.72
# 3    1.32   V  1.21  ...  1.00    V  1.82    V  1.97    V  1.84    V  0.00
# 4    2.06   V  2.21  ...  1.77    V  3.32    V  3.76    V  3.04    V  1.89
# ..    ...  ..   ...  ...   ...  ...   ...  ...   ...  ...   ...  ...   ...
# 928  0.00   V  0.00  ...  0.00    V  0.00    V  0.00    V  0.00    V  0.00
# 929  0.00   V  0.00  ...  0.00    V  0.00    V  0.30    V  0.00    V  0.00
# 930  0.00   V  0.00  ...  0.00    V  0.00    V  0.00    V  0.00    V  1.90
# 931  0.00   V  0.00  ...  0.00    V  3.40    V  0.00    V  0.00    V  0.00
# 932  0.00   V  0.00  ...  0.00    V  0.00    V  0.00    V  0.00    V  0.00
#
#      V31
# 0      V
# 1      N
# 2      V
# 3      N
# 4      V
# ..   ...
# 928    V
# 929    N
# 930    V
# 931    N
# 932    V
#
# [3155 rows x 69 columns]

# %%
df.MAGNITUD.unique()
# Out:
# array([81, 82, 83, 86, 87, 88, 89, 80])

# %% [markdown]
# <a name="Merge"></a>
# ### Merge
#
# En este caso se busca unir dos dataframes fijándonos en las coincidencias entre valores de dos columnas

# %%
from pandas import DataFrame
from pandas import Series
import pandas as pd
from random import sample
df1 = DataFrame({'clave': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],
                 'data1': range(7),
                 'otro': sample(range(10, 30), 7)})

df2 = DataFrame({'clave': ['a', 'b', 'b', 'd'],
                 'data2': range(4)})
display_side_by_side(df1,df2)
# Out:
# &nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data1</th>
#       <th>otro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>b</td>
#       <td>0</td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>1</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>a</td>
#       <td>2</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>c</td>
#       <td>3</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>a</td>
#       <td>4</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>a</td>
#       <td>5</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>b</td>
#       <td>6</td>
#       <td>18</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>a</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>b</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>d</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# Por defecto la mezcla es por la columna que se llama igual

# %%
display_side_by_side(df1,df2, pd.merge(df1,df2),title="pd.merge(df1,df2)")
# Out:
# pd.merge(df1,df2)
# &nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data1</th>
#       <th>otro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>b</td>
#       <td>0</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>1</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>a</td>
#       <td>2</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>c</td>
#       <td>3</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>a</td>
#       <td>4</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>a</td>
#       <td>5</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>b</td>
#       <td>6</td>
#       <td>27</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>a</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>b</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>d</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data1</th>
#       <th>otro</th>
#       <th>data2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>b</td>
#       <td>0</td>
#       <td>23</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>0</td>
#       <td>23</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>b</td>
#       <td>1</td>
#       <td>13</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>b</td>
#       <td>1</td>
#       <td>13</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>a</td>
#       <td>2</td>
#       <td>22</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>a</td>
#       <td>4</td>
#       <td>25</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>a</td>
#       <td>5</td>
#       <td>21</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>b</td>
#       <td>6</td>
#       <td>27</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>b</td>
#       <td>6</td>
#       <td>27</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# Si no se indica lo contrario, `merge` busca columnas comunes y hace un (inner) 'join'. Nótese que en este caso no se tienen en cuenta los índices
# <br><br>
#
# El método merge se puede llamar también dentro de un dataframe (es equivalente)

# %%
df1.merge(df2)
# Out:
#   clave  data1  otro  data2
# 0     b      0    23      1
# 1     b      0    23      2
# 2     b      1    13      1
# 3     b      1    13      2
# 4     a      2    22      0
# 5     a      4    25      0
# 6     a      5    21      0
# 7     b      6    27      1
# 8     b      6    27      2

# %% [markdown]
# También se pueden unir por varias columnas, que podemos especificar directamente con los parámetros `left_on`y `right_on`

# %%
df3 = df1.merge(df2, left_on=['clave','data1'], right_on = ['clave','data2'])

display_side_by_side(df1,df2, df3)
# Out:
# &nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data1</th>
#       <th>otro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>b</td>
#       <td>0</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>1</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>a</td>
#       <td>2</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>c</td>
#       <td>3</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>a</td>
#       <td>4</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>a</td>
#       <td>5</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>b</td>
#       <td>6</td>
#       <td>27</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>a</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>b</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>d</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data1</th>
#       <th>otro</th>
#       <th>data2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>b</td>
#       <td>1</td>
#       <td>13</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# Si la clave o claves por las que querenos unir se llaman ambas igual podemos usar simplemente `on`

# %%
df3 = pd.merge(df1,df2,on='clave')
display_side_by_side(df1,df2, df3)
# Out:
# &nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data1</th>
#       <th>otro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>b</td>
#       <td>0</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>1</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>a</td>
#       <td>2</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>c</td>
#       <td>3</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>a</td>
#       <td>4</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>a</td>
#       <td>5</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>b</td>
#       <td>6</td>
#       <td>27</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>a</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>b</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>d</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data1</th>
#       <th>otro</th>
#       <th>data2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>b</td>
#       <td>0</td>
#       <td>23</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>0</td>
#       <td>23</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>b</td>
#       <td>1</td>
#       <td>13</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>b</td>
#       <td>1</td>
#       <td>13</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>a</td>
#       <td>2</td>
#       <td>22</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>a</td>
#       <td>4</td>
#       <td>25</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>a</td>
#       <td>5</td>
#       <td>21</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>b</td>
#       <td>6</td>
#       <td>27</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>b</td>
#       <td>6</td>
#       <td>27</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# Además de *inner* join, se pueden hacer con el parámetro `how` tomando valores *left*, *right*, *outer*, *inner*
#
# <img src="https://www.golinuxcloud.com/wp-content/uploads/types_joins-1320x961.png">

# %% [markdown]
# En el caso de left, right y full/outer si la columna no encaja se rellenan con valores NaN

# %%
df3 = df1.merge( df2, on='clave', how='left')
display_side_by_side(df1,df2, df3)
# Out:
# &nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data1</th>
#       <th>otro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>b</td>
#       <td>0</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>1</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>a</td>
#       <td>2</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>c</td>
#       <td>3</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>a</td>
#       <td>4</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>a</td>
#       <td>5</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>b</td>
#       <td>6</td>
#       <td>27</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>a</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>b</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>d</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data1</th>
#       <th>otro</th>
#       <th>data2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>b</td>
#       <td>0</td>
#       <td>23</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>0</td>
#       <td>23</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>b</td>
#       <td>1</td>
#       <td>13</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>b</td>
#       <td>1</td>
#       <td>13</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>a</td>
#       <td>2</td>
#       <td>22</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>c</td>
#       <td>3</td>
#       <td>14</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>a</td>
#       <td>4</td>
#       <td>25</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>a</td>
#       <td>5</td>
#       <td>21</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>b</td>
#       <td>6</td>
#       <td>27</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>b</td>
#       <td>6</td>
#       <td>27</td>
#       <td>2.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# **Ejercicio** En
#
# https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/tweetsCompletadoOrdenRename.csv
#
# Tenemos datos de tweets, incluyendo el identificador del usuario que que ha emitidos cada tweet,  `userid`.
#
# En
#
# https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/usersrentaf.csv
#
# tenemos datos de usuarios: sú número de seguidores, la renta de la zona donde viven, etc. En este caso el identificador se llama simplemente `id`.
#
# Queremos unir ambos ficheros, de forma que a cada tweet se le añadan los datos de su usuario. Si un tweet no tiene su usario en el segundo conjunto de datos debemos borrarlo. Igualmente si un usuario no tiene ningún tweet no se incluirá.

# %%
import pandas as pd
url_tweets = "https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/tweetsCompletadoOrdenRename.csv"
url_users = "https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/usersrentaf.csv"
df_tweets = pd.read_csv(url_tweets)
df_users = pd.read_csv(url_users)

# %%
df_tweets.columns
# Out:
# Index(['userid', '_id', 'screen_name', 'text', 'hora', 'foto/vídeo', 'foto',
#        'video', ''¡'', ''!'', ''¿'', ''?'', 'menciones', 'hashtags', 'URLs',
#        'emojis', 'sentimiento medio emojis', 'palabras',
#        'proporción palabras correctas', 'longitud media palabras',
#        'mayúsculas', 'números', 'palabras vacías', 'adjetivos', 'sustantivos',
#        'verbos', 'tiempo pasado', 'tiempo presente', 'tiempo futuro',
#        'tiempo imperfecto', 'tiempo condicional', 'modo imperativo',
#        'modo indicativo', 'modo subjuntivo', 'primera persona',
#        'segunda persona', 'tercera persona', 'singular', 'plural',
#        'infinitivo', 'gerundio', 'participio', 'estoy en'],
#       dtype='object')

# %%
df_users.columns
# Out:
# Index(['id', 'screen_name', 'name', 'followers', 'created_at', 'friends_count',
#        'location', 'ntweets', 'verified', 'nTotal', 'tweets', 'localidad',
#        'provincia', 'distrito', 'seccion', 'cambio1518', 'mediana',
#        'rentapaismin', 'rentapaismax', 'rentacommin', 'rentacommax'],
#       dtype='object')
