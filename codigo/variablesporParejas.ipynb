# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelCaballero/APD/blob/main/codigo/variablesporParejas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table>
# <tr>
# <td><img src="https://raw.githubusercontent.com/RafaelCaballero/APD/refs/heads/main/img/logoAPD.png" width="150"></td>
# <td><table><tr><td><h1>Variables por parejas</h1></td></tr>
#            <tr><td><h3>Rafael Caballero Roldán</h3></td></tr></table></td>
# <td><img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTsPjCdm67xYS9AM7-dXQ46O23vaexAhnVJaQ&s" width="105"></td>
# </tr>
# </table>

# %% [markdown]
# # Tabla de Contenidos
# 1. [Gráficas con dos variables continuas](#1.-Gráficas-con-dos-variables-continuas)<br>
#    1.1 [Diagrama de dispersión](#1.1-Diagrama-de-dispersión)<br>
#    1.2 [Diagrama de líneas](#1.2-Diagrama-de-líneas)<br>
#    1.3 [Diagrama de densidad](#1.3-Diagrama-de-densidad)<br>
# 2. [Gráficas con dos variables discretas](#2.-Gráficas-con-dos-variables-discretas)<br>
#    2.1 [Diagrama de barras](#2.1-Diagrama-de-barras)<br>
#    2.2 [Mapas de calor](#2.2-Mapas-de-calor)<br>
#
# 3. [Gráficas con una variable discreta y otra continua](#3.-Gráficas-con-una-variable-discreta-y-otra-continua)<br>
#    3.1 [Gráficos de enjambre](#3.1-Gráficos-de-enjambre)<br>
#    3.2 [Gráficos de violín](#3.2-Gráficos-de-violín)<br>
#    3.3 [Diagramas de barras con IC](#3.3-Diagramas-de-barras-con-IC)<br>
#
# 4. [Correlaciones](#4.-Correlaciones)<br>
#     4.1 [Introducción](#4.1-Introducción)<br>
#     4.2 [Definición](#4.2-Definición)<br>
#     4.3 [Ejemplo](#4.3-Ejemplo)<br>
#     4.4 [A tener en cuenta](#4.4-A-tener-en-cuenta)<br>
#     4.5 [Representación gráfica](#4.5-Representación-gráfica)<br>
#     4.6 [Variables nominales](#4.6-Variables-nominales)<br>
#     4.7 [Pearson y Spearman](#4.7-Pearson-y-Spearman)<br>
# 5. [Referencias](#5.-Referencias)<br>

# %%
modules = ["scipy","tqdm","yfinance"]

import sys
import os.path
from subprocess import check_call
import importlib
import os

def instala(modules):
    print("Instalando módulos")
    for m in modules:
        # para el import quitamos [...] y ==...
        p = m.find("[")
        mi = m if p==-1 else m[:p]
        p = mi.find("==")
        mi = mi if p==-1 else mi[:p]
        torch_loader = importlib.util.find_spec(mi)
        if torch_loader is not None:
            print(m," encontrado")
        else:
            print(m," No encontrado, instalando...",end="")
            try:
                r = check_call([sys.executable, "-m", "pip", "install", "--user", m])
                print("¡hecho!")
            except:
                print("¡Problema al instalar ",m,"! ¿seguro que el módulo existe?",sep="")

    print("¡Terminado!")

instala(modules)
# Out:
# Instalando módulos
# scipy  encontrado
# tqdm  encontrado
# yfinance  encontrado
# ¡Terminado!

# %% [markdown]
# ## 1. Gráficas con dos variables continuas
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
import pandas as pd

import yfinance as yf
import pandas as pd

# Definir los símbolos de Yahoo Finance, incluyendo General Electric y Visa
symbols = {
    'USD/JPY': 'JPY=X',
    'EUR/USD': 'EURUSD=X',
    'Amazon': 'AMZN',
    'Alphabet': 'GOOGL',
    'Pfizer': 'PFE',
    'Nvidia': 'NVDA',
    'Tesla': 'TSLA',
    'General Electric': 'GE',
    'Visa': 'V'
}

# Descargar los datos de todos los símbolos
data = yf.download(list(symbols.values()), period="max")

# Filtrar para quedarnos solo con la columna 'Adj Close'
df = data['Close'].dropna()

# Nombres inteligibles
symbol_renames = {v: k for k, v in symbols.items()} # diccionario inverso
df = df.rename(columns=symbol_renames)
# Añadir una columna con el día de la semana
df["Date"] = df.index
filtro_fecha = df.Date.dt.year >= 2015
df = df[filtro_fecha]
df["Year"] = df.Date.dt.year
df['Day_of_Week'] = df['Date'].dt.day_name()


# Guardar los datos en un archivo CSV si es necesario
#df.to_csv('close_varios.csv', index=False)
df_bolsa = df.copy()
df
# Out:
# /tmp/ipykernel_2831/2060980361.py:23: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  9 of 9 completed
# Ticker          Amazon   EUR/USD  General Electric    Alphabet     USD/JPY  \
# Date
# 2015-01-02   15.426000  1.208941        102.430702   26.260460  119.870003
# 2015-01-05   15.109500  1.194643        100.550491   25.760094  120.433998
# 2015-01-06   14.764500  1.193902         98.384132   25.124350  119.425003
# 2015-01-07   14.921000  1.187536         98.425034   25.050459  118.672997
# 2015-01-08   15.023000  1.183600         99.610382   25.137739  119.289001
# ...                ...       ...               ...         ...         ...
# 2026-04-14  249.020004  1.176886        318.000000  332.910004  159.214005
# 2026-04-15  248.500000  1.179941        313.929993  337.119995  158.792007
# 2026-04-16  249.699997  1.180916        298.290009  336.019989  158.809006
# 2026-04-17  250.559998  1.178273        304.130005  341.679993  159.195007
# 2026-04-20  248.279999  1.174122        303.600006  337.420013  159.160995
#
# Ticker          Nvidia     Pfizer       Tesla        Visa       Date  Year  \
# Date
# 2015-01-02    0.482985  18.381010   14.620667   61.214733 2015-01-02  2015
# 2015-01-05    0.474828  18.281277   14.006000   59.863499 2015-01-05  2015
# 2015-01-06    0.460432  18.433815   14.085333   59.477764 2015-01-06  2015
# 2015-01-07    0.459232  18.686096   14.063333   60.274654 2015-01-07  2015
# 2015-01-08    0.476507  19.067444   14.041333   61.083092 2015-01-08  2015
# ...                ...        ...         ...         ...        ...   ...
# 2026-04-14  196.509995  27.110001  364.200012  311.369995 2026-04-14  2026
# 2026-04-15  198.869995  27.190001  391.950012  315.910004 2026-04-15  2026
# 2026-04-16  198.350006  27.219999  388.899994  315.100006 2026-04-16  2026
# 2026-04-17  201.679993  27.559999  400.619995  317.019989 2026-04-17  2026
# 2026-04-20  202.059998  27.520000  392.500000  313.940002 2026-04-20  2026
#
# Ticker     Day_of_Week
# Date
# 2015-01-02      Friday
# 2015-01-05      Monday
# 2015-01-06     Tuesday
# 2015-01-07   Wednesday
# 2015-01-08    Thursday
# ...                ...
# 2026-04-14     Tuesday
# 2026-04-15   Wednesday
# 2026-04-16    Thursday
# 2026-04-17      Friday
# 2026-04-20      Monday
#
# [2836 rows x 12 columns]

# %% [markdown]
# ### 1.1 Diagrama de dispersión
#
# Son los típicos gráficos de puntos
#
# **matplotlib**

# %%
import matplotlib.pyplot as plt

# puntos        X                     Y
plt.scatter(df['Nvidia'], df['Alphabet'])
plt.xlabel('Nvidia')  # esto son decoraciones, no es imprescindible
plt.ylabel('Alphabet')
plt.title('Gráfico de puntos')
plt.show() # aquí termina el gráfico

# %% [markdown]
# Tamaño de punto, parámetro `s`

# %%
import matplotlib.pyplot as plt

# puntos        X                     Y
plt.scatter(df['Nvidia'], df['Alphabet'],s=4)  # tamaño del punto
plt.xlabel('Nvidia')  # esto son decoraciones, no es imprescindible
plt.ylabel('Alphabet')
plt.title('Gráfico de puntos')
plt.show()

# %% [markdown]
# Si queremos alterar aspecto podemos darle un tamaño determinado

# %%
fig = plt.figure(figsize=(14,6))
plt.scatter(df['Nvidia'], df['Alphabet'],s=4)  # tamaño del punto
plt.xlabel('Nvidia')  # esto son decoraciones, no es imprescindible
plt.ylabel('Alphabet')
plt.title('Gráfico de puntos')
plt.show()

# %% [markdown]
# Fig tiene la ventaja de que nos permite por ejemplo grabar el gráfico

# %%
fig = plt.figure(figsize=(14,6))
plt.scatter(df['Nvidia'], df['Alphabet'],s=4)  # tamaño del punto
plt.xlabel('Nvidia')  # esto son decoraciones, no es imprescindible
plt.ylabel('Alphabet')
plt.title('Gráfico de puntos')
fig.savefig("Nvidia_Alphabet.png")
plt.show()

# %% [markdown]
# Para hacer dos gráficos en matplotlib, podemos usar `subplots'

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20,5*2)) # 2 filas, una columna, ax1 es el primero, ax2 el segundo
ax1.scatter(df['Nvidia'], df['Alphabet'],s=2,color="red")
ax1.set_title('Gráfico 1: Nvidia vs Alphabet')
ax1.set_ylim(0, 200)

ax2.scatter(df['Nvidia'], df['Amazon'],s=2)
ax2.set_title('Gráfico 2: Nvidia vs Amazon')
ax2.set_ylim(0, 200)
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(14,6))
plt.scatter(df['Nvidia'], df['Alphabet'],s=1,alpha=0.4,color="red", label="Alphabet")
plt.scatter(df['Nvidia'], df['Amazon'],s=1,alpha=0.4, label="Amazon" )
plt.xlabel("Nvidia") # la X es la misma en los dos casos
plt.legend()
plt.show()

# %% [markdown]
# **Pandas**

# %%
df.plot(kind="scatter", x="Alphabet", y="Amazon", figsize=(20,5))
# Out:
# <Axes: xlabel='Alphabet', ylabel='Amazon'>

# %% [markdown]
# **seaborn**

# %%
import seaborn as sns
sns.scatterplot(x='Nvidia', y='Alphabet', data=df,  s=50)

# Añadir título y mostrar el gráfico
plt.title('Scatter Plot con Seaborn: Nvidia vs Alphabet')
plt.show()

# %%
import seaborn as sns
fig, eje = plt.subplots(figsize=(8, 8))
sns.scatterplot(x='Nvidia', y='Alphabet', data=df,  hue="Year", palette="bright", s=50,ax=eje)

# Añadir título y mostrar el gráfico
plt.title('Scatter Plot con Seaborn: Nvidia vs Alphabet')
plt.show()

# %% [markdown]
# **plotly**

# %%
import plotly.express as px
fig = px.scatter(df, x='Nvidia', y='Alphabet', title="Scatter Plot con Plotly")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="52511330-f03f-4abe-ba57-9c3fd408db82" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52511330-f03f-4abe-ba57-9c3fd408db82")) {                    Plotly.newPlot(                        "52511330-f03f-4abe-ba57-9c3fd408db82",                        [{"hovertemplate":"Nvidia=%{x}\u003cbr\u003eAlphabet=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[0.4829852283000946,0.47482749819755554,0.46043163537979126,0.45923200249671936,0.4765070676803589,0.4784265160560608,0.47242823243141174,0.47170835733413696,0.47362783551216125,0.47026872634887695,0.4789064824581146,0.4803459346294403,0.4870642125606537,0.49546194076538086,0.49690139293670654,0.49474212527275085,0.4709886908531189,0.4633108079433441,0.4745875895023346,0.4606715142726898,0.470748633146286,0.4825054109096527,0.4837051331996918,0.4916228950023651,0.4894634485244751,0.4889834225177765,0.5026600360870361,0.49930083751678467,0.5350507497787476,0.535290539264679,0.5369700789451599,0.5307318568229675,0.5321713089942932,0.5360105037689209,0.5316916704177856,0.5373518466949463,0.533257246017456,0.5347023606300354,0.531330406665802,0.5443364977836609,0.5342206954956055,0.5402421355247498,0.5505989789962769,0.5431326031684875,0.5445775985717773,0.5539708733558655,0.5510808229446411,0.5460226535797119,0.5467453002929688,0.5532482266426086,0.5599925518035889,0.5508397817611694,0.559269905090332,0.5652911067008972,0.5469859838485718,0.5395194292068481,0.5067631006240845,0.5050769448280334,0.5149521827697754,0.5171200633049011,0.5041136741638184,0.5060405731201172,0.5072445273399353,0.52193683385849,0.5265134572982788,0.5303668975830078,0.5426506996154785,0.5481904149055481,0.5431326031684875,0.538555920124054,0.545059323310852,0.5416874289512634,0.5347023606300354,0.532052755355835,0.531330406665802,0.5373518466949463,0.5351839661598206,0.5306079387664795,0.5347023606300354,0.5373518466949463,0.533257246017456,0.5347023606300354,0.547949492931366,0.5445775985717773,0.5306079387664795,0.532293975353241,0.5416874289512634,0.5017050504684448,0.49688780307769775,0.5017050504684448,0.5045952796936035,0.5127842426300049,0.5130254030227661,0.512302577495575,0.5091087222099304,0.5091087222099304,0.5054792761802673,0.5047532916069031,0.5016075372695923,0.5284665822982788,0.5357254147529602,0.5354834198951721,0.5415327548980713,0.530886173248291,0.5250788331031799,0.5345156788825989,0.538629412651062,0.526288628578186,0.528950572013855,0.5195136070251465,0.5250788331031799,0.5108023881912231,0.5098344683647156,0.5161257982254028,0.522175133228302,0.530886173248291,0.5291925072669983,0.5270146727561951,0.5134642720222473,0.5083827376365662,0.5122544169425964,0.5018495321273804,0.48684731125831604,0.4866052567958832,0.49362266063690186,0.4941064417362213,0.4880571663379669,0.4788621962070465,0.47547459602355957,0.46966734528541565,0.4778943955898285,0.4810398519039154,0.48128190636634827,0.4778943955898285,0.4885411262512207,0.48563745617866516,0.47668445110321045,0.4788621962070465,0.46966734528541565,0.47547459602355957,0.4699092507362366,0.46724745631217957,0.4774104058742523,0.48321765661239624,0.48442763090133667,0.4827337861061096,0.49096065759658813,0.49289658665657043,0.4979780912399292,0.49483221769332886,0.5560513734817505,0.5754088759422302,0.5725052952766418,0.5739570260047913,0.569117546081543,0.5696015954017639,0.5659719705581665,0.5608205795288086,0.5586338043212891,0.538465678691864,0.5216994881629944,0.5032322406768799,0.49278348684310913,0.5299607515335083,0.5498860478401184,0.5523159503936768,0.5462413430213928,0.5238860249519348,0.5396804213523865,0.54113 ...

# %% [markdown]
# Podemos añadir más infromación con `hover_data`

# %%
import plotly.express as px
fig = px.scatter(df,x='Nvidia', y='Alphabet', title="Scatter Plot con Plotly", hover_data=['Date'])
# Personalizar el tamaño y color
fig.update_traces(marker=dict(size=4, color='red'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="18923896-2ccd-441c-a9e7-5cb5d184afcd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18923896-2ccd-441c-a9e7-5cb5d184afcd")) {                    Plotly.newPlot(                        "18923896-2ccd-441c-a9e7-5cb5d184afcd",                        [{"customdata":[["2015-01-02T00:00:00"],["2015-01-05T00:00:00"],["2015-01-06T00:00:00"],["2015-01-07T00:00:00"],["2015-01-08T00:00:00"],["2015-01-09T00:00:00"],["2015-01-12T00:00:00"],["2015-01-13T00:00:00"],["2015-01-14T00:00:00"],["2015-01-15T00:00:00"],["2015-01-16T00:00:00"],["2015-01-20T00:00:00"],["2015-01-21T00:00:00"],["2015-01-22T00:00:00"],["2015-01-23T00:00:00"],["2015-01-26T00:00:00"],["2015-01-27T00:00:00"],["2015-01-28T00:00:00"],["2015-01-29T00:00:00"],["2015-01-30T00:00:00"],["2015-02-02T00:00:00"],["2015-02-03T00:00:00"],["2015-02-04T00:00:00"],["2015-02-05T00:00:00"],["2015-02-06T00:00:00"],["2015-02-09T00:00:00"],["2015-02-10T00:00:00"],["2015-02-11T00:00:00"],["2015-02-12T00:00:00"],["2015-02-13T00:00:00"],["2015-02-17T00:00:00"],["2015-02-18T00:00:00"],["2015-02-19T00:00:00"],["2015-02-20T00:00:00"],["2015-02-23T00:00:00"],["2015-02-24T00:00:00"],["2015-02-25T00:00:00"],["2015-02-26T00:00:00"],["2015-02-27T00:00:00"],["2015-03-02T00:00:00"],["2015-03-03T00:00:00"],["2015-03-04T00:00:00"],["2015-03-05T00:00:00"],["2015-03-06T00:00:00"],["2015-03-09T00:00:00"],["2015-03-10T00:00:00"],["2015-03-11T00:00:00"],["2015-03-12T00:00:00"],["2015-03-13T00:00:00"],["2015-03-16T00:00:00"],["2015-03-17T00:00:00"],["2015-03-18T00:00:00"],["2015-03-19T00:00:00"],["2015-03-20T00:00:00"],["2015-03-23T00:00:00"],["2015-03-24T00:00:00"],["2015-03-25T00:00:00"],["2015-03-26T00:00:00"],["2015-03-27T00:00:00"],["2015-03-30T00:00:00"],["2015-03-31T00:00:00"],["2015-04-01T00:00:00"],["2015-04-02T00:00:00"],["2015-04-06T00:00:00"],["2015-04-07T00:00:00"],["2015-04-08T00:00:00"],["2015-04-09T00:00:00"],["2015-04-10T00:00:00"],["2015-04-13T00:00:00"],["2015-04-14T00:00:00"],["2015-04-15T00:00:00"],["2015-04-16T00:00:00"],["2015-04-17T00:00:00"],["2015-04-20T00:00:00"],["2015-04-21T00:00:00"],["2015-04-22T00:00:00"],["2015-04-23T00:00:00"],["2015-04-24T00:00:00"],["2015-04-27T00:00:00"],["2015-04-28T00:00:00"],["2015-04-29T00:00:00"],["2015-04-30T00:00:00"],["2015-05-01T00:00:00"],["2015-05-04T00:00:00"],["2015-05-05T00:00:00"],["2015-05-06T00:00:00"],["2015-05-07T00:00:00"],["2015-05-08T00:00:00"],["2015-05-11T00:00:00"],["2015-05-12T00:00:00"],["2015-05-13T00:00:00"],["2015-05-14T00:00:00"],["2015-05-15T00:00:00"],["2015-05-18T00:00:00"],["2015-05-19T00:00:00"],["2015-05-20T00:00:00"],["2015-05-21T00:00:00"],["2015-05-22T00:00:00"],["2015-05-26T00:00:00"],["2015-05-27T00:00:00"],["2015-05-28T00:00:00"],["2015-05-29T00:00:00"],["2015-06-01T00:00:00"],["2015-06-02T00:00:00"],["2015-06-03T00:00:00"],["2015-06-04T00:00:00"],["2015-06-05T00:00:00"],["2015-06-08T00:00:00"],["2015-06-09T00:00:00"],["2015-06-10T00:00:00"],["2015-06-11T00:00:00"],["2015-06-12T00:00:00"],["2015-06-15T00:00:00"],["2015-06-16T00:00:00"],["2015-06-17T00:00:00"],["2015-06-18T00:00:00"],["2015-06-19T00:00:00"],["2015-06-22T00:00:00"],["2015-06-23T00:00:00"],["2015-06-24T00:00:00"],["2015-06-25T00:00:00"],["2015-06-26T00:00:00"],["2015-06-29T00:00:00"],["2015-06-30T00:00:00"],["2015-07-01T00:00:00"],["2015-07-02T00:00:00"],["2015-07-06T00:00:00"],["2015-07-07T00:00:00"],["2015-07-08T00:00:00"],["2015-07-09T00:00:00"],["2015-07-10T00:00:00"],["2015-07-13T00:00:00"],["2015-07-14T00:00:00"],["2015-07-15T00:00:00"],["2015-07-16T00:00:00"],["2015-07-17T00:00:00"],["2015-07-20T00:00:00"],["2015-07-21T00:00:00"],["2015-07-22T00:00:00"],["2015-07-23T00:00:00"],["2015-07-24T00:00:00"],["2015-07-27T00:00:00"],["2015-07-28T ...

# %% [markdown]
# ### 1.2 Diagrama de líneas
#
# El más común, pero en el caso de dos variables exige que una de ellas esté ordenada y que no tenga repeticiones sino queremos obtener un caos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/RafaelCaballero/tdm/refs/heads/master/datos/f1-Singapur24.csv"
f1 = pd.read_csv(url)
f1
# Out:
#     Driver  LapTime  LapNumber PitInTime  Sector1Time  Sector2Time  \
# 0      NOR  100.424        1.0         0          NaN       41.379
# 1      NOR   98.480        2.0         0       29.268       41.412
# 2      NOR   98.406        3.0         0       29.354       41.262
# 3      NOR   98.446        4.0         0       29.399       41.305
# 4      NOR   97.938        5.0         0       29.034       41.159
# ..     ...      ...        ...       ...          ...          ...
# 242    RUS   97.796       58.0         0       28.659       41.835
# 243    RUS   98.326       59.0         0       28.785       42.103
# 244    RUS   97.872       60.0         0       28.765       41.920
# 245    RUS   98.282       61.0         0       29.034       41.976
# 246    RUS   98.155       62.0         0       28.740       41.954
#
#      Sector3Time  SpeedST Compound  TyreLife      Team  Position  Deleted  \
# 0         27.852    186.0   MEDIUM       1.0   McLaren       1.0    False
# 1         27.800    276.0   MEDIUM       2.0   McLaren       1.0    False
# 2         27.790    270.0   MEDIUM       3.0   McLaren       1.0    False
# 3         27.742    272.0   MEDIUM       4.0   McLaren       1.0    False
# 4         27.745    278.0   MEDIUM       5.0   McLaren       1.0    False
# ..           ...      ...      ...       ...       ...       ...      ...
# 242       27.302    290.0     HARD      31.0  Mercedes       4.0    False
# 243       27.438    289.0     HARD      32.0  Mercedes       4.0    False
# 244       27.187      NaN     HARD      33.0  Mercedes       4.0     True
# 245       27.272    287.0     HARD      34.0  Mercedes       4.0    False
# 246       27.461    290.0     HARD      35.0  Mercedes       4.0    False
#
#                        DeletedReason  FastF1Generated
# 0                                NaN            False
# 1                                NaN            False
# 2                                NaN            False
# 3                                NaN            False
# 4                                NaN            False
# ..                               ...              ...
# 242                              NaN            False
# 243                              NaN            False
# 244  TRACK LIMITS AT TURN 19 LAP 60             False
# 245                              NaN            False
# 246                              NaN            False
#
# [247 rows x 15 columns]

# %%
# aquí es donde nos aseguramos de que cada vuelta sale solo una vez
mean_lap_time = f1.groupby('LapNumber')['LapTime'].mean()

# Gráfico
plt.figure(figsize=(10, 6))
sns.lineplot(x=mean_lap_time.index, y=mean_lap_time)
plt.title('Tiempo Medio por Vuelta en Singapur 24')
plt.xlabel('Número de Vuelta')
plt.ylabel('Tiempo Medio (segundos)')
plt.grid(True)
plt.show()

# %% [markdown]
# Aprovechando el parámetro `hue`

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=f1, x="LapNumber", y="LapTime",hue="Driver")
plt.title('Tiempo Medio por Vuelta en Singapur 24')
plt.xlabel('Número de Vuelta')
plt.ylabel('Tiempo Medio (segundos)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 1.3 Diagrama de densidad
#
# Muy útiles porque  a veces los puntos se tapan unos a otros, nos permiten ver dónde hay más puntos acumulados.
#
# **matplotlib**

# %%
plt.figure(figsize=(8, 6))
plt.hexbin(df['Nvidia'], df['Alphabet'], gridsize=40, cmap='Blues')
plt.colorbar(label='Densidad')
plt.title('Hexbin de Nvidia y Alphabet')
plt.xlabel('Nvidia')
plt.ylabel('Alphabet')
plt.show()

# %% [markdown]
# **seaborn**

# %%
import seaborn as sns

# Gráfico de densidad para ver la relación entre BBVA y Santander
plt.figure(figsize=(8, 6))
sns.kdeplot(x='Nvidia', y='Alphabet', data=df[df.Year<2020], fill=True, cmap="Blues")
plt.title('Gráfico de Densidad entre Nvidia y Alphabet')
plt.xlabel('Nvidia')
plt.ylabel('Alphabet')
plt.show()

# %% [markdown]
# ## 2. Gráficas con dos variables discretas
# ---
#
# Cuando hay dos variables discretas solemos representar frecuencias. Esto implica a menudo una preparación de datos haciendo agrupaciones

# %% [markdown]
# ### 2.1 Diagrama de barras
#
# Hay versiones para combinar dos variables discretas, ya sea apilando o poniendo al lado

# %%
import pandas as pd
import seaborn as sns
url = "https://raw.githubusercontent.com/RafaelCaballero/tdm/refs/heads/master/datos/pokemon.csv"
df_pokemon = pd.read_csv(url)
df_pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 12 columns]

# %%
counts = df_pokemon.groupby(['Type 1', 'Legendary']).size().reset_index(name='Proporción')

# Crear la gráfica de barras apiladas con proporciones
fig = px.bar(counts, x='Type 1', y='Proporción', color='Legendary', barmode='relative',
              title='Proporción de Pokémon Legendarios por Tipo')

# Mostrar la gráfica
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9523281e-7db1-44b8-8b6b-cbd44bd7d405" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9523281e-7db1-44b8-8b6b-cbd44bd7d405")) {                    Plotly.newPlot(                        "9523281e-7db1-44b8-8b6b-cbd44bd7d405",                        [{"alignmentgroup":"True","hovertemplate":"Legendary=False\u003cbr\u003eType 1=%{x}\u003cbr\u003eProporción=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"False","offsetgroup":"False","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dark","Dragon","Electric","Fairy","Fighting","Fire","Flying","Ghost","Grass","Ground","Ice","Normal","Poison","Psychic","Rock","Steel","Water"],"xaxis":"x","y":[69,29,20,40,16,27,47,2,30,67,28,22,96,28,43,40,23,108],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Legendary=True\u003cbr\u003eType 1=%{x}\u003cbr\u003eProporción=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"True","offsetgroup":"True","orientation":"v","showlegend":true,"textposition":"auto","x":["Dark","Dragon","Electric","Fairy","Fire","Flying","Ghost","Grass","Ground","Ice","Normal","Psychic","Rock","Steel","Water"],"xaxis":"x","y":[2,12,4,1,5,2,2,3,4,2,2,14,4,4,4],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6 ...

# %%
counts
# Out:
#       Type 1  Legendary  Proporción
# 0        Bug      False          69
# 1       Dark      False          29
# 2       Dark       True           2
# 3     Dragon      False          20
# 4     Dragon       True          12
# 5   Electric      False          40
# 6   Electric       True           4
# 7      Fairy      False          16
# 8      Fairy       True           1
# 9   Fighting      False          27
# 10      Fire      False          47
# 11      Fire       True           5
# 12    Flying      False           2
# 13    Flying       True           2
# 14     Ghost      False          30
# 15     Ghost       True           2
# 16     Grass      False          67
# 17     Grass       True           3
# 18    Ground      False          28
# 19    Ground       True           4
# 20       Ice      False          22
# 21       Ice       True           2
# 22    Normal      False          96
# 23    Normal       True           2
# 24    Poison      False          28
# 25   Psychic      False          43
# 26   Psychic       True          14
# 27      Rock      False          40
# 28      Rock       True           4
# 29     Steel      False          23
# 30     Steel       True           4
# 31     Water      False         108
# 32     Water       True           4

# %% [markdown]
# ### 2.2 Mapas de calor
#
# Muy útiles para comparar las frecuencias de dos variables discretas

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd



url = "https://ucmdrive.ucm.es/s/d2zjioya7aHrZ7q/download/ventas.zip"
df_ventas = pd.read_csv(url)
#df_ventas.columns

# %%
df_ventas.columns
# Out:
# Index(['N.Mes', 'MES', 'CENTRO', 'COD.AREA', 'AREA', 'COD.SEC', 'SECCION',
#        'COD.CAT', 'CATEGORIA', 'COD.SUBCAT', 'SUBCATEGORIA', 'COD.SEG',
#        'SEGMENTO', 'REF.CENTRAL', 'REF.CENTER', 'DESCRIPCION', 'VTA.OFERTA',
#        'VTA.OFERTA.AA', 'VENTAS', 'VENTAS.AA', 'PESO.OFERTA.AA', 'UDS',
#        'UDS.AA', 'AVERIADO', 'AVERIADO.AA', 'UDS.AVERIADO', 'UDS.AVERIADO.AA',
#        'STOCK', 'STOCK.AA', 'UDS.STOCK', 'UDS.STOCK.AA'],
#       dtype='object')

# %%
filtro = df_ventas.SECCION == "BEBIDAS"
df_bebidas = df_ventas[filtro]
df_bebidas
# Out:
#         N.Mes  MES  CENTRO  COD.AREA          AREA  COD.SEC  SECCION  COD.CAT  \
# 9091        2  feb    1000         2  ALIMENTACION       11  BEBIDAS        4
# 9092        2  feb    1000         2  ALIMENTACION       11  BEBIDAS        4
# 9093        2  feb    1000         2  ALIMENTACION       11  BEBIDAS        4
# 9094        2  feb    1000         2  ALIMENTACION       11  BEBIDAS        4
# 9095        2  feb    1000         2  ALIMENTACION       11  BEBIDAS        4
# ...       ...  ...     ...       ...           ...      ...      ...      ...
# 288347     10  oct    2000         2  ALIMENTACION       11  BEBIDAS       18
# 288348     10  oct    2000         2  ALIMENTACION       11  BEBIDAS       18
# 288349     10  oct    2000         2  ALIMENTACION       11  BEBIDAS       18
# 288350     10  oct    2000         2  ALIMENTACION       11  BEBIDAS       18
# 288351     10  oct    2000         2  ALIMENTACION       11  BEBIDAS       18
#
#                          CATEGORIA  COD.SUBCAT  ... UDS  UDS.AA AVERIADO  \
# 9091                         AGUAS           1  ...   0       8        0
# 9092                         AGUAS           1  ...  43      18        0
# 9093                         AGUAS           1  ...  32       0        0
# 9094                         AGUAS           1  ...   5      12        0
# 9095                         AGUAS           1  ...   0      45        0
# ...                            ...         ...  ...  ..     ...      ...
# 288347  BEBIDAS DE ALTA GRADUACION          28  ...   0       3        0
# 288348  BEBIDAS DE ALTA GRADUACION          28  ...   1       0        0
# 288349  BEBIDAS DE ALTA GRADUACION          28  ...   7       2        0
# 288350  BEBIDAS DE ALTA GRADUACION          28  ...   2       0       -8
# 288351  BEBIDAS DE ALTA GRADUACION          28  ...   0       0        0
#
#         AVERIADO.AA  UDS.AVERIADO UDS.AVERIADO.AA  STOCK  STOCK.AA  UDS.STOCK  \
# 9091              0             0               0      5        -6         10
# 9092              0             0               0     20        21         39
# 9093              0             0               0      8        12         16
# 9094              0             0               0      9        15         19
# 9095              0             0               0      0         2          0
# ...             ...           ...             ...    ...       ...        ...
# 288347            0             0               0     95        46          8
# 288348            0             0               0      0        68          0
# 288349            0             0               0     22        33          2
# 288350            0            -1               0      0        72          0
# 288351            0             0               0      0        16          0
#
#         UDS.STOCK.AA
# 9091             -14
# 9092              57
# 9093              24
# 9094              33
# 9095               4
# ...              ...
# 288347             4
# 288348             4
# 288349             3
# 288350             9
# 288351             2
#
# [25371 rows x 31 columns]

# %%
ventas_por_categoria_mes = df_bebidas.groupby(['CATEGORIA', 'MES','N.Mes'])['VENTAS'].sum().reset_index()
ventas_por_categoria_mes = ventas_por_categoria_mes.sort_values('N.Mes')
ventas_por_categoria_mes
# Out:
#                      CATEGORIA  MES  N.Mes  VENTAS
# 2                        AGUAS  feb      2   17456
# 11  BEBIDAS DE ALTA GRADUACION  feb      2    8466
# 29                    CERVEZAS  feb      2   20422
# 20        BEBIDAS REFRESCANTES  feb      2   27634
# 47                   VINO D.O.  feb      2   17297
# ..                         ...  ...    ...     ...
# 43                   ESPUMOSOS  oct     10    1539
# 16  BEBIDAS DE ALTA GRADUACION  oct     10   11967
# 7                        AGUAS  oct     10   18743
# 25        BEBIDAS REFRESCANTES  oct     10   30154
# 70            ZUMOS Y NECTARES  oct     10    5229
#
# [72 rows x 4 columns]

# %%
# Formato ancho
ventas_pivot = ventas_por_categoria_mes.pivot(index='CATEGORIA', columns='N.Mes', values='VENTAS')
ventas_pivot.columns = ventas_por_categoria_mes.drop_duplicates(subset=['N.Mes'])['MES']

# Crear el heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(ventas_pivot, annot=True, fmt=".0f", cmap="YlGnBu")

# Añadir título y etiquetas
plt.title('Total de Ventas por Categoría y Mes en la Sección BEBIDAS')
plt.xlabel('Mes')
plt.ylabel('Categoría')
plt.show()

# %%
ventas_por_categoria_mes
# Out:
#                      CATEGORIA  MES  N.Mes  VENTAS
# 2                        AGUAS  feb      2   17456
# 11  BEBIDAS DE ALTA GRADUACION  feb      2    8466
# 29                    CERVEZAS  feb      2   20422
# 20        BEBIDAS REFRESCANTES  feb      2   27634
# 47                   VINO D.O.  feb      2   17297
# ..                         ...  ...    ...     ...
# 43                   ESPUMOSOS  oct     10    1539
# 16  BEBIDAS DE ALTA GRADUACION  oct     10   11967
# 7                        AGUAS  oct     10   18743
# 25        BEBIDAS REFRESCANTES  oct     10   30154
# 70            ZUMOS Y NECTARES  oct     10    5229
#
# [72 rows x 4 columns]

# %%
ventas_pivot
# Out:
# MES                           feb    mar    abr    may    jun    jul    ago  \
# CATEGORIA
# AGUAS                       17456  19060  15554  17382  16015  17716  17057
# BEBIDAS DE ALTA GRADUACION   8466   9783  13748  14453  12310  11015  10332
# BEBIDAS REFRESCANTES        27634  30772  27948  29583  27330  27977  26852
# CERVEZAS                    20422  33591  37669  40407  33018  31343  32506
# ESPUMOSOS                    1000   1056   1274   1647   1229   1532   1768
# VINO D.O.                   17297  22183  28027  27141  22421  19488  20540
# VINO DE MESA                 2688   3467   4131   4138   3593   3225   3265
# ZUMOS Y NECTARES             4737   5669   4636   4804   4201   4415   4530
#
# MES                           sep    oct
# CATEGORIA
# AGUAS                       19661  18743
# BEBIDAS DE ALTA GRADUACION  10510  11967
# BEBIDAS REFRESCANTES        29673  30154
# CERVEZAS                    30728  31904
# ESPUMOSOS                    1436   1539
# VINO D.O.                   19199  27028
# VINO DE MESA                 3072   3468
# ZUMOS Y NECTARES             5035   5229

# %% [markdown]
# ## 3. Gráficas con una variable discreta y otra continua
# ---
#
# En este caso la biblioteca Seaborn nos da muchas posibilidades que añaden a los gráficos de variables continuas la posibilidad de distinguirse por una variable categórica

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
url = "https://raw.githubusercontent.com/RafaelCaballero/tdm/refs/heads/master/datos/pokemon.csv"
df_pokemon = pd.read_csv(url)
df_pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 12 columns]

# %% [markdown]
# ### 3.1 Gráficos de enjambre

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/RafaelCaballero/tdm/refs/heads/master/datos/f1-Singapur24.csv"
f1 = pd.read_csv(url)
f1
# Out:
#     Driver  LapTime  LapNumber PitInTime  Sector1Time  Sector2Time  \
# 0      NOR  100.424        1.0         0          NaN       41.379
# 1      NOR   98.480        2.0         0       29.268       41.412
# 2      NOR   98.406        3.0         0       29.354       41.262
# 3      NOR   98.446        4.0         0       29.399       41.305
# 4      NOR   97.938        5.0         0       29.034       41.159
# ..     ...      ...        ...       ...          ...          ...
# 242    RUS   97.796       58.0         0       28.659       41.835
# 243    RUS   98.326       59.0         0       28.785       42.103
# 244    RUS   97.872       60.0         0       28.765       41.920
# 245    RUS   98.282       61.0         0       29.034       41.976
# 246    RUS   98.155       62.0         0       28.740       41.954
#
#      Sector3Time  SpeedST Compound  TyreLife      Team  Position  Deleted  \
# 0         27.852    186.0   MEDIUM       1.0   McLaren       1.0    False
# 1         27.800    276.0   MEDIUM       2.0   McLaren       1.0    False
# 2         27.790    270.0   MEDIUM       3.0   McLaren       1.0    False
# 3         27.742    272.0   MEDIUM       4.0   McLaren       1.0    False
# 4         27.745    278.0   MEDIUM       5.0   McLaren       1.0    False
# ..           ...      ...      ...       ...       ...       ...      ...
# 242       27.302    290.0     HARD      31.0  Mercedes       4.0    False
# 243       27.438    289.0     HARD      32.0  Mercedes       4.0    False
# 244       27.187      NaN     HARD      33.0  Mercedes       4.0     True
# 245       27.272    287.0     HARD      34.0  Mercedes       4.0    False
# 246       27.461    290.0     HARD      35.0  Mercedes       4.0    False
#
#                        DeletedReason  FastF1Generated
# 0                                NaN            False
# 1                                NaN            False
# 2                                NaN            False
# 3                                NaN            False
# 4                                NaN            False
# ..                               ...              ...
# 242                              NaN            False
# 243                              NaN            False
# 244  TRACK LIMITS AT TURN 19 LAP 60             False
# 245                              NaN            False
# 246                              NaN            False
#
# [247 rows x 15 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, eje = plt.subplots(figsize=(14, 6))
sns.swarmplot(data=f1, x="Driver", y="LapTime",ax=eje)
# Out:
# <Axes: xlabel='Driver', ylabel='LapTime'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, eje = plt.subplots(figsize=(14, 6))
sns.swarmplot(data=f1, x="Driver", y="LapTime", hue="Compound",ax=eje)
# Out:
# <Axes: xlabel='Driver', ylabel='LapTime'>

# %% [markdown]
# ### 3.2 Gráficos de violín
#
# Una alternativa a los boxplots
#
# - Punto blanco: mediana
# - Línea negra: rango intercuartílico
# - Anchura: densidad de probabilidad
# - Todo lo largo que sea necesario para incluir toodos los puntos

# %%
import seaborn as sns
fig, eje = plt.subplots(figsize=(14, 6))
sns.violinplot(data=f1, x="Driver", y="LapTime", hue="Compound",  ax=eje)
# Out:
# <Axes: xlabel='Driver', ylabel='LapTime'>

# %% [markdown]
# ### 3.3 Diagramas de barras con IC

# %% [markdown]
# Supongamos que, en `df_ventas` queremos obtener un diagrama de VENTAS por N.Mes con intervalo de confianza del 90% forma rápida. Decididmos usar la fórmula:
#
# $$\mu \pm  Z \frac{\sigma}{\sqrt{n}}$$
#
# para las ventas de cada mes por separado

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

ci = 90
z = norm.ppf(1 - (1 - ci / 100) / 2)  # es feo, sí, pero así se obtiene z

# Agrupamos las ventas por meses
summary = df_ventas.groupby(['N.Mes'])['VENTAS'].agg(['mean', 'count', 'std'])

# Ahora obtenemos el error que usaremos para el intervalo de confianza
summary['error'] = z * (summary['std'] / np.sqrt(summary['count'])) # teorema entral del límite

# Preparar datos para el gráfico
meses  = summary.index
means = summary['mean']
errors = summary['error']

# Crear el diagrama de barras
fig, ax = plt.subplots(figsize=(14, 6))
plt.bar(meses, means, yerr=errors, capsize=5, alpha=0.7, color='skyblue')
plt.ylabel('Ventas')
plt.xlabel('Mes')
plt.title('Ventas por mes con intervalo de confianza')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.grid(True)
# Personalizar el grid
ax.grid(which='major', color='black', linestyle='-', linewidth=0.75)  # Rejilla principal
ax.grid(which='minor', color='gray', linestyle=':', linewidth=0.5)    # Rejilla secundaria

# Añadir ticks secundarios
ax.minorticks_on()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## 4. Correlaciones
# ---

# %% [markdown]
# ### 4.1 Introducción
#
# Hasta ahora hemos considerado cada columna (cada variable) de forma independiente, viendo histogramas, outliers, etc. de forma individual. Solo hemos comparado columnas por ejemplo al hablar de los tests que nos permiten ver si tienen la misma media o si son muestras de la misma variable.
#
# Ahora vamos a estudiar la *correlación* entre las columnas por pares. La idea es ver si dos variables tienen *relación lineal*: si cuando una crece la otra en general también (correlación positiva) o si cuando una crece la otra decrece (correlación negativa).
#
# Una correlación alta indica que las variables están muy relacionadas (contienen información muy similar). Esto implica:
#
# - Si una de las variables es una variable a predecir se podrá hacer muy bien a partir de la otra (por ejemplo con regresión lineal)
#
# - Si las dos variables son características de un objeto puede que nos interese quitar una porque estamos "reforzando" o "duplicando" la misma información y eso puede tener influencia negativa en algunos métodos de aprendizaje automático.
#
# ### 4.2 Definición
#
# Para estudiar la correlación entre dos variables se suele utilizar el *coeficiente de correlación de Pearson*
#
# $$
# r = \frac{\sum(x_i - \overline{x})(y_i - \overline{y})}{\sum(x_i - \overline{x})^2(y_i - \overline{y})^2}
# $$
#
# Es un valor que está entre -1 y +1. Algunos ejemplos:
#
#
# <img src="https://www.statlect.com/images/linear-correlation-coefficient.png" />
#
# ### 4.3 Ejemplo
#
# Por fortuna no tenemos que calcular las correlaciones; Pandas ya incluye un método [df.corr](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html)
#
# Supongamos que queremos saber qué dos comunidades tienen mayor correlación en sus datos de paro

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/parocomunidades.csv"


df = pd.read_csv(url, encoding="latin1")
df
# Out:
#       Comunidad  Periodo  Total
# 0     Andalucía     2023  18.67
# 1     Andalucía     2022  19.00
# 2     Andalucía     2021  20.18
# 3     Andalucía     2020  22.74
# 4     Andalucía     2019  20.80
# ..          ...      ...    ...
# 413     Melilla     2006   9.86
# 414     Melilla     2005  12.33
# 415     Melilla     2004  12.49
# 416     Melilla     2003  19.88
# 417     Melilla     2002   3.57
#
# [418 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Comunidad  418 non-null    object
#  1   Periodo    418 non-null    int64
#  2   Total      418 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 9.9+ KB

# %%
df.Comunidad.unique()
# Out:
# array([' Andalucía', ' Aragón', ' Asturias, Principado de',
#        ' Balears, Illes', ' Canarias', ' Cantabria', ' Castilla y León',
#        ' Castilla - La Mancha', ' Cataluña', ' Comunitat Valenciana',
#        ' Extremadura', ' Galicia', ' Madrid, Comunidad de',
#        ' Murcia, Región de', ' Navarra, Comunidad Foral de',
#        ' País Vasco', ' Rioja, La', ' Ceuta', ' Melilla'], dtype=object)

# %%
df["Comunidad"] = df["Comunidad"].str.strip()
df.Comunidad.unique()
# Out:
# array(['Andalucía', 'Aragón', 'Asturias, Principado de', 'Balears, Illes',
#        'Canarias', 'Cantabria', 'Castilla y León', 'Castilla - La Mancha',
#        'Cataluña', 'Comunitat Valenciana', 'Extremadura', 'Galicia',
#        'Madrid, Comunidad de', 'Murcia, Región de',
#        'Navarra, Comunidad Foral de', 'País Vasco', 'Rioja, La', 'Ceuta',
#        'Melilla'], dtype=object)

# %%
df.Periodo.unique()
# Out:
# array([2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013,
#        2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002])

# %% [markdown]
# Vaya...las correlaciones se calculan entre columnas, así que las comunidades deberían ser columnas, ¿qué hacer?

# %%
df_ancho = df.pivot(index='Periodo', columns='Comunidad', values='Total')
df_ancho.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_628b4_row0_col0, #T_628b4_row6_col10, #T_628b4_row6_col18, #T_628b4_row16_col5, #T_628b4_row19_col0 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_628b4_row0_col1, #T_628b4_row0_col16, #T_628b4_row1_col1 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_628b4_row0_col2, #T_628b4_row1_col2, #T_628b4_row1_col18 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_628b4_row0_col3, #T_628b4_row1_col15, #T_628b4_row6_col12 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_628b4_row0_col4, #T_628b4_row4_col16 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_628b4_row0_col5, #T_628b4_row7_col2, #T_628b4_row16_col13, #T_628b4_row21_col16 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_628b4_row0_col6, #T_628b4_row1_col6 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_628b4_row0_col7, #T_628b4_row17_col3, #T_628b4_row19_col8 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_628b4_row0_col8, #T_628b4_row2_col7, #T_628b4_row19_col17 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_628b4_row0_col9, #T_628b4_row0_col14, #T_628b4_row2_col4, #T_628b4_row2_col18, #T_628b4_row3_col10, #T_628b4_row3_col13, #T_628b4_row3_col15, #T_628b4_row4_col0, #T_628b4_row4_col1, #T_628b4_row4_col6, #T_628b4_row4_col8, #T_628b4_row4_col11, #T_628b4_row5_col2, #T_628b4_row5_col5, #T_628b4_row5_col6, #T_628b4_row5_col7, #T_628b4_row5_col8, #T_628b4_row5_col12, #T_628b4_row5_col16, #T_628b4_row5_col17, #T_628b4_row21_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_628b4_row0_col10, #T_628b4_row1_col10, #T_628b4_row3_col18 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_628b4_row0_col11, #T_628b4_row6_col13, #T_628b4_row16_col7, #T_628b4_row17_col7, #T_628b4_row20_col0, #T_628b4_row20_col1 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_628b4_row0_col12, #T_628b4_row16_col2, #T_628b4_row17_col10 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_628b4_row0_col13, #T_628b4_row4_col5, #T_628b4_row5_col18 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_628b4_row0_col15, #T_628b4_row21_col5 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_628b4_row0_col17, #T_628b4_row15_col3, #T_628b4_row18_col2 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_628b4_row0_col18, #T_628b4_row3_col6 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_628b4_row1_col0 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_628b4_row1_col3, #T_628b4_row3_col5 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_628b4_row1_col4 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_628b4_row1_col5, #T_628b4_row1_col17, #T_628b4_row16_col0 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_628b4_row1_col7, #T_628b4_row6_col5, #T_628b4_row21_col15 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_628b4_row1_col8, #T_628b4_row5_col3 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_628b4_row1_col9, #T_628b4_row3_col16, #T_628b4_row6_col2, #T_628b4_row19_col2, #T_628b4_row20_col7, #T_628b4_row21_col12 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_628b4_row1_col11, #T_628b4_row21_col4 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_628b4_row1_col12, #T_628b4_row6_col14, #T_628b4_row14_col2, #T_628b4_row15_col16 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_628b4_row1_col13, #T_628b4_row5_col11 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_628b4_row1_col14, #T_628b4_row7_col14, #T_628b4_row14_col5, #T_628b4_row15_col13 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_628b4_row1_col16 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_628b4_row2_col0 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_628b4_row2_col1, #T_628b4_row4_col13, #T_628b4_row5_col15 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_628b4_row2_col2, #T_628b4_row4_col18 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_628b4_row2_col3 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_628b4_row2_col5, #T_628b4_row18_col6, #T_628b4_row18_col8, #T_628b4_row18_col10 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_628b4_row2_col6, #T_628b4_row4_col17 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_628b4_row2_col8 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_628b4_row2_col9, #T_628b4_row4_col4, #T_628b4_row4_col12 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_628b4_row2_col10, #T_628b4_row3_col7 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_628b4_row2_col11, #T_628b4_row19_col7, #T_628b4_row21_col17 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_628b4_row2_col12, #T_628b4_row16_col17 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_628b4_row2_col13, #T_628b4_row5_col0 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_628b4_row2_col14, #T_628b4_row6_col7, #T_628b4_row17_col12 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_628b4_row2_col15, #T_628b4_row3_col12, #T_628b4_row21_col8 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_628b4_row2_col16, #T_628b4_row4_col2 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_628b4_row2_col17 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_628b4_row3_col0 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_628b4_row3_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_628b4_row3_col2 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_628b4_row3_col3 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_628b4_row3_col4, #T_628b4_row3_col8, #T_628b4_row5_col4 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_628b4_row3_col9, #T_628b4_row17_col16, #T_628b4_row18_col18, #T_628b4_row19_col4 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_628b4_row3_col11 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_628b4_row3_col14, #T_628b4_row18_col12, #T_628b4_row19_col13 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_628b4_row3_col17 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_628b4_row4_col3, #T_628b4_row5_col13 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_628b4_row4_col7, #T_628b4_row5_col10 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_628b4_row4_col9, #T_628b4_row17_col13 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_628b4_row4_col10, #T_628b4_row4_col15 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_628b4_row4_col14 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_628b4_row5_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_628b4_row5_col9, #T_628b4_row5_col14, #T_628b4_row6_col4 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_628b4_row6_col0, #T_628b4_row7_col11, #T_628b4_row16_col1, #T_628b4_row17_col15 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_628b4_row6_col1, #T_628b4_row6_col8, #T_628b4_row16_col8 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_628b4_row6_col3, #T_628b4_row6_col6, #T_628b4_row6_col9, #T_628b4_row16_col10, #T_628b4_row16_col12, #T_628b4_row17_col1, #T_628b4_row21_col13, #T_628b4_row21_col18 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_628b4_row6_col11 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_628b4_row6_col15, #T_628b4_row17_col0 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_628b4_row6_col16, #T_628b4_row17_col17 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_628b4_row6_col17, #T_628b4_row19_col6 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_628b4_row7_col0, #T_628b4_row7_col17, #T_628b4_row7_col18, #T_628b4_row16_col9, #T_628b4_row20_col14 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_628b4_row7_col1, #T_628b4_row14_col1 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_628b4_row7_col3, #T_628b4_row17_col9 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_628b4_row7_col4, #T_628b4_row7_col10, #T_628b4_row13_col4, #T_628b4_row13_col16 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_628b4_row7_col5, #T_628b4_row14_col9, #T_628b4_row15_col6 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_628b4_row7_col6, #T_628b4_row14_col15, #T_628b4_row15_col0 {
#   background-color: #68acd5;

# %%
correlaciones = df_ancho.corr()
correlaciones.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_bd21a_row0_col0, #T_bd21a_row1_col1, #T_bd21a_row2_col2, #T_bd21a_row3_col3, #T_bd21a_row4_col4, #T_bd21a_row5_col5, #T_bd21a_row6_col6, #T_bd21a_row7_col7, #T_bd21a_row8_col8, #T_bd21a_row9_col9, #T_bd21a_row10_col10, #T_bd21a_row11_col11, #T_bd21a_row12_col12, #T_bd21a_row13_col13, #T_bd21a_row14_col14, #T_bd21a_row15_col15, #T_bd21a_row16_col16, #T_bd21a_row17_col17, #T_bd21a_row18_col18 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_bd21a_row0_col1, #T_bd21a_row0_col17, #T_bd21a_row15_col7 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_bd21a_row0_col2, #T_bd21a_row10_col11, #T_bd21a_row11_col15, #T_bd21a_row16_col7 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_bd21a_row0_col3, #T_bd21a_row4_col17, #T_bd21a_row12_col15 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_bd21a_row0_col4, #T_bd21a_row2_col17, #T_bd21a_row4_col18, #T_bd21a_row18_col13 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_bd21a_row0_col5, #T_bd21a_row1_col18, #T_bd21a_row7_col15, #T_bd21a_row10_col18, #T_bd21a_row11_col6 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_bd21a_row0_col6, #T_bd21a_row1_col13, #T_bd21a_row4_col1, #T_bd21a_row6_col1, #T_bd21a_row10_col0, #T_bd21a_row13_col10, #T_bd21a_row15_col1 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_bd21a_row0_col7, #T_bd21a_row0_col8 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_bd21a_row0_col9, #T_bd21a_row14_col0 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_bd21a_row0_col10, #T_bd21a_row7_col8, #T_bd21a_row10_col4 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_bd21a_row0_col11, #T_bd21a_row0_col12, #T_bd21a_row1_col7, #T_bd21a_row4_col8, #T_bd21a_row5_col17, #T_bd21a_row8_col17, #T_bd21a_row11_col0, #T_bd21a_row13_col8, #T_bd21a_row17_col5 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_bd21a_row0_col13, #T_bd21a_row6_col5, #T_bd21a_row7_col11, #T_bd21a_row8_col12, #T_bd21a_row18_col4 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_bd21a_row0_col14 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_bd21a_row0_col15, #T_bd21a_row5_col12, #T_bd21a_row7_col0, #T_bd21a_row12_col17 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_bd21a_row0_col16, #T_bd21a_row3_col7, #T_bd21a_row11_col13, #T_bd21a_row16_col3 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_bd21a_row0_col18, #T_bd21a_row17_col6 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_bd21a_row1_col0, #T_bd21a_row1_col4, #T_bd21a_row1_col6, #T_bd21a_row10_col1, #T_bd21a_row12_col5 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_bd21a_row1_col2, #T_bd21a_row2_col10, #T_bd21a_row5_col6, #T_bd21a_row13_col12 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_bd21a_row1_col3, #T_bd21a_row2_col11, #T_bd21a_row2_col13, #T_bd21a_row13_col17 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_bd21a_row1_col5, #T_bd21a_row4_col7, #T_bd21a_row5_col11, #T_bd21a_row16_col10 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_bd21a_row1_col8, #T_bd21a_row6_col15, #T_bd21a_row7_col5, #T_bd21a_row8_col7 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_bd21a_row1_col9, #T_bd21a_row17_col18 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_bd21a_row1_col10, #T_bd21a_row1_col15, #T_bd21a_row6_col0, #T_bd21a_row7_col17, #T_bd21a_row8_col15, #T_bd21a_row15_col0, #T_bd21a_row17_col12 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_bd21a_row1_col11, #T_bd21a_row8_col13, #T_bd21a_row17_col11 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_bd21a_row1_col12, #T_bd21a_row8_col11, #T_bd21a_row15_col2 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_bd21a_row1_col14 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_bd21a_row1_col16, #T_bd21a_row6_col18, #T_bd21a_row13_col5, #T_bd21a_row16_col4 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_bd21a_row1_col17, #T_bd21a_row7_col1, #T_bd21a_row13_col2, #T_bd21a_row16_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_bd21a_row2_col0, #T_bd21a_row3_col10, #T_bd21a_row18_col0 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_bd21a_row2_col1 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_bd21a_row2_col3, #T_bd21a_row6_col14 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_bd21a_row2_col4 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_bd21a_row2_col5, #T_bd21a_row2_col12, #T_bd21a_row7_col10, #T_bd21a_row8_col4, #T_bd21a_row13_col7, #T_bd21a_row15_col17 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_bd21a_row2_col6, #T_bd21a_row6_col17, #T_bd21a_row12_col11, #T_bd21a_row13_col18 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_bd21a_row2_col7, #T_bd21a_row8_col6, #T_bd21a_row18_col8 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_bd21a_row2_col8, #T_bd21a_row2_col15, #T_bd21a_row16_col6 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_bd21a_row2_col9 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_bd21a_row2_col14 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_bd21a_row2_col16, #T_bd21a_row5_col15, #T_bd21a_row8_col2 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_bd21a_row2_col18, #T_bd21a_row3_col1, #T_bd21a_row15_col16 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_bd21a_row3_col0 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_bd21a_row3_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_bd21a_row3_col4 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_bd21a_row3_col5 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_bd21a_row3_col6, #T_bd21a_row16_col14 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_bd21a_row3_col8, #T_bd21a_row5_col0, #T_bd21a_row6_col2, #T_bd21a_row6_col12, #T_bd21a_row8_col3 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_bd21a_row3_col9, #T_bd21a_row12_col16, #T_bd21a_row14_col1 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_bd21a_row3_col11 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_bd21a_row3_col12, #T_bd21a_row5_col3 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_bd21a_row3_col13 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_bd21a_row3_col14, #T_bd21a_row9_col0, #T_bd21a_row9_col1, #T_bd21a_row9_col2, #T_bd21a_row9_col3, #T_bd21a_row9_col4, #T_bd21a_row9_col5, #T_bd21a_row9_col6, #T_bd21a_row9_col7, #T_bd21a_row9_col8, #T_bd21a_row9_col10, #T_bd21a_row9_col11, #T_bd21a_row9_col12, #T_bd21a_row9_col13, #T_bd21a_row9_col15, #T_bd21a_row9_col17, #T_bd21a_row12_col9, #T_bd21a_row14_col16, #T_bd21a_row14_col18 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_bd21a_row3_col15, #T_bd21a_row4_col11 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_bd21a_row3_col16 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_bd21a_row3_col17 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_bd21a_row3_col18, #T_bd21a_row4_col12, #T_bd21a_row6_col3 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_bd21a_row4_col0, #T_bd21a_row4_col6 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_bd21a_row4_col2 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_bd21a_row4_col3, #T_bd21a_row10_col17, #T_bd21a_row11_col8 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_bd21a_row4_col5, #T_bd21a_row7_col13, #T_bd21a_row12_col2, #T_bd21a_row18_col5, #T_bd21a_row18_col12 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_bd21a_row4_col9, #T_bd21a_row9_col14, #T_bd21a_row11_col14 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_bd21a_row4_col10, #T_bd21a_row13_col6 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_bd21a_row4_col13, #T_bd21a_row11_col7 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_bd21a_row4_col14 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_bd21a_row4_col15, #T_bd21a_row10_col6 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_bd21a_row4_col16, #T_bd21a_row5_col1, #T_bd21a_row16_col9 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_bd21a_row5_col2, #T_bd21a_row10_col2, #T_bd21a_row11_col10, #T_bd21a_row17_col10 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;

# %% [markdown]
# ### 4.4 A tener en cuenta
#
# En el caso de las correlaciones (como en todos) no hay que precipitarse en sacar conclusiones. En particular:
#
# - Que haya correlación no significa que los valores sean "parecidos" sino que se mueven a la vez (en la misma dirección o contraria)
#
# - Correlación no implica causalidad, en ocasiones puede haber otra variable que esté "moviendo" las dos variables correlaciones
#
# - Ya hemos visto que puede haber correlación de otros tipos que no está detectada por nuestro método (la correlación de Pearson); pero es que también sucede al revés, podemos encontrar correlación y que no signifique lo que creemos:
#
# <img src="https://github.com/RafaelCaballero/tdm/raw/master/images/Situations-in-which-linear-correlation-should-not-be-used-a-two-variables-have-a.png" />
#
# Vamos a mostrar los gráficos de dos comunidades muy relacionadas

# %%
df_ancho.columns
# Out:
# Index(['Andalucía', 'Aragón', 'Asturias, Principado de', 'Balears, Illes',
#        'Canarias', 'Cantabria', 'Castilla - La Mancha', 'Castilla y León',
#        'Cataluña', 'Ceuta', 'Comunitat Valenciana', 'Extremadura', 'Galicia',
#        'Madrid, Comunidad de', 'Melilla', 'Murcia, Región de',
#        'Navarra, Comunidad Foral de', 'País Vasco', 'Rioja, La'],
#       dtype='object', name='Comunidad')

# %%
from matplotlib import pyplot as plt
fig, ax = plt.subplots(figsize=(10, 6))

ax.scatter(df_ancho["Comunitat Valenciana"],df_ancho['Murcia, Región de'])
ax.plot([0,30],[0,30],color="red")
plt.show()

# %%
# otra forma
fig, ax = plt.subplots(figsize=(10, 6))
cs = ["Comunitat Valenciana",'Murcia, Región de']
for c in cs:
    df_ancho[c].plot(ax=ax,label=c)
ax.legend()
plt.show()

# %% [markdown]
# ### 4.5 Representación gráfica
#
# **Seaborn**

# %%
import seaborn as sns
plt.figure(figsize=(11,8))
sns.heatmap(correlaciones, cmap="Greens",annot=True)
plt.show()

# %% [markdown]
# Hay otras posibilidades más complejas que por ejemplo crean grupos (clústers) de atributos correlacionados

# %%
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.clustermap(ventas_pivot.T.corr(),
                   method = 'complete',
                   cmap   = 'RdBu',
                   annot  = True,
                   annot_kws = {'size': 8})

# %% [markdown]
# ### 4.6 Variables nominales
#
# Si una variable es categórica vamos a tener dos posibilidades:
#
# a) Convertir la variable a numérica (one-hot-encoding)
#
# b) Utilizar un test como de la $\chi^2$ (en otra clase posterior)
#
# Ejemplo:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
url = "https://raw.githubusercontent.com/RafaelCaballero/tdm/refs/heads/master/datos/pokemon.csv"
df_pokemon = pd.read_csv(url)[["Type 1","Attack", "Defense", "Speed","Legendary"]].dropna()
df_pokemon
# Out:
#       Type 1  Attack  Defense  Speed  Legendary
# 0      Grass      49       49     45      False
# 1      Grass      62       63     60      False
# 2      Grass      82       83     80      False
# 3      Grass     100      123     80      False
# 4       Fire      52       43     65      False
# ..       ...     ...      ...    ...        ...
# 795     Rock     100      150     50       True
# 796     Rock     160      110    110       True
# 797  Psychic     110       60     70       True
# 798  Psychic     160       60     80       True
# 799     Fire     110      120     70       True
#
# [800 rows x 5 columns]

# %% [markdown]
# Antes de aplicar el método one-hot-encoding, vamos a dejar el mismo tipo de Pokemon de cada tipo, tener clases categóricas poco equilibrada podría confundir al método

# %%
df2 = df_pokemon  #.groupby('Type 1', group_keys=False).sample(n=df_pokemon["Type 1"].value_counts().min())
pok = pd.get_dummies(df2[["Type 1","Defense","Speed"]])

# %%
g = sns.clustermap(pok.corr(),
                   method = 'complete',
                   cmap   = 'RdBu',
                   annot  = True,
                   annot_kws = {'size': 8})

fig =g.figure
fig.savefig('pokemon.pdf')

# %% [markdown]
# En el caso de las variables dummy las correlaciones suelen ser pequeñas, pero aun así son indicativas, así vemos que los poquemos de tipo 'Steel' y 'Rock' parecen tener más defensa. Ahora podemos confirmarlo

# %%
df2.groupby('Type 1')['Defense'].mean()
# Out:
# Type 1
# Bug          70.724638
# Dark         70.225806
# Dragon       86.375000
# Electric     66.295455
# Fairy        65.705882
# Fighting     65.925926
# Fire         67.769231
# Flying       66.250000
# Ghost        81.187500
# Grass        70.800000
# Ground       84.843750
# Ice          71.416667
# Normal       59.846939
# Poison       68.821429
# Psychic      67.684211
# Rock        100.795455
# Steel       126.370370
# Water        72.946429
# Name: Defense, dtype: float64

# %%
df_aux = df_pokemon[df_pokemon['Type 1']=="Dragon"]
df_aux.Defense.hist(label="Dragon",alpha=0.5)
df_aux = df_pokemon[df_pokemon['Type 1']=="Ghost"]
df_aux.Defense.hist(label="Ghost",alpha=0.5)
plt.legend()
plt.show()

# %% [markdown]
# ### 4.7 Pearson y Spearman
#
# Si bien la correlación de Pearson es la más común, también disponemos de otros métodos como la correlación de Spearman
#
# - Pearson: busca una relación lineal entre datos
#
# - Spearman: busca una relación lineal entre los rangos de los datos, entendidos como posición que ocupan dentro de la serie

# %%
import numpy as np
import pandas as pd

x = np.arange(1, 21)
y = np.exp(x / 3)

df1 = pd.DataFrame({"x": x, "y": y})

print("Pearson \n",df1.corr(method="pearson"))
print()
print("Spearman \n",df1.corr(method="spearman"))
# Out:
# Pearson
#            x         y
# x  1.000000  0.798256
# y  0.798256  1.000000
#
# Spearman
#       x    y
# x  1.0  1.0
# y  1.0  1.0

# %% [markdown]
# Es más raro que suceda lo contrario

# %%
import numpy as np
import pandas as pd

rng = np.random.default_rng(0)

x = np.concatenate([rng.normal(0, 1, 19), [20]])
y = np.concatenate([rng.normal(0, 1, 19), [20]])

df2 = pd.DataFrame({"x": x, "y": y})

print("Pearson \n",df2.corr(method="pearson"))
print()
print("Spearman \n",df2.corr(method="spearman"))
# Out:
# Pearson
#            x         y
# x  1.000000  0.976688
# y  0.976688  1.000000
#
# Spearman
#            x         y
# x  1.000000  0.227068
# y  0.227068  1.000000

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].scatter(df1["x"], df1["y"])
axes[0].set_title("Ejemplo 1: monotóna no lineal")
axes[0].set_xlabel("x")
axes[0].set_ylabel("y")

axes[1].scatter(df2["x"], df2["y"])
axes[1].set_title("Ejemplo 2: outlier extremo")
axes[1].set_xlabel("x")
axes[1].set_ylabel("y")

plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd

x = df_bolsa["Alphabet"]
y = df_bolsa["Nvidia"]

df1 = pd.DataFrame({"x": x, "y": y})

print("Pearson \n",df1.corr(method="pearson"))
print()
print("Spearman \n",df1.corr(method="spearman"))
# Out:
# Pearson
#            x         y
# x  1.000000  0.912893
# y  0.912893  1.000000
#
# Spearman
#            x         y
# x  1.000000  0.981732
# y  0.981732  1.000000

# %% [markdown]
# ## 5. Referencias
# ---
#
# [Gráficos en Python](https://python-graph-gallery.com/)<br>
#
# [Variables categóricas en Seaborn](https://seaborn.pydata.org/tutorial/categorical.html)<br>
#
# Una explicación matemática sencilla de donde he tomado alguna imagen:
# *Taboga, Marco (2021). "Linear correlation", Lectures on probability theory and mathematical statistics. Kindle Direct Publishing. Online appendix.* https://www.statlect.com/fundamentals-of-probability/linear-correlation.
#
#
#
# Sobre correlación y causalidad:
#  [Why correlation does not imply causation?](https://medium.com/@seema.singh/why-correlation-does-not-imply-causation-5b99790df07e)
#
#
#
# Descripción de los distintos tipos de tests para variables categóricas y numéricas:
# *Data Preprocessing in Data Mining*. Intelligent Systems Reference Library №72. Salvador García, Julián Luengo, Francisco Herrera. Spring, 2015.  Ver en particular: *3.2.1 Finding Redundant Attributes*
